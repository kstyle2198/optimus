# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from random import random, randrange, choice, shuffle
from datetime import datetime, timedelta, date
from itertools import combinations
from pprint import pprint
import calendar
import plotly.express as px

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # Cell의 모든 반환값 출력

pd.set_option('display.max_rows', None)

# %% [markdown]
# # 기본 데이터 세팅

# %%
블록원데이터 = pd.DataFrame({"블록명":["S1", "S2", "S3", "S4"], 
                    "중량": [50, 60, 30, 20], 
                    "가로": [10, 10, 5, 5], 
                    "세로":[10, 12, 6, 6], 
                    "표준공기":[2, 3, 1, 2], 
                    "납기":["2024-02-15", "2024-02-15", "2024-02-15", "2024-02-15"],
                    })
블록원데이터.head()
# Out:
#   블록명  중량  가로  세로  표준공기          납기
# 0  S1  50  10  10     2  2024-02-15
# 1  S2  60  10  12     3  2024-02-15
# 2  S3  30   5   6     1  2024-02-15
# 3  S4  20   5   6     2  2024-02-15

# %%
정반원데이터 = pd.DataFrame({"정반명":["A", "B", "C"],
                   "가능중량":[100, 100, 30],
                   "가로":[10, 10, 5],
                   "세로":[20, 10, 10],
                   })
정반원데이터.head()
# Out:
#   정반명  가능중량  가로  세로
# 0   A   100  10  20
# 1   B   100  10  10
# 2   C    30   5  10

# %%
정반원데이터.index[정반원데이터["정반명"]=="B"].values[0]
# Out:
# 1

# %%
start_date = datetime(2024, 2, 1)
end_date = datetime(2024, 2, 28)
날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
날짜집합
# Out:
# DatetimeIndex(['2024-02-01', '2024-02-02', '2024-02-03', '2024-02-04',
#                '2024-02-05', '2024-02-06', '2024-02-07', '2024-02-08',
#                '2024-02-09', '2024-02-10', '2024-02-11', '2024-02-12',
#                '2024-02-13', '2024-02-14', '2024-02-15', '2024-02-16',
#                '2024-02-17', '2024-02-18', '2024-02-19', '2024-02-20',
#                '2024-02-21', '2024-02-22', '2024-02-23', '2024-02-24',
#                '2024-02-25', '2024-02-26', '2024-02-27', '2024-02-28'],
#               dtype='datetime64[ns]', freq='D')

# %%
블록집합 = 블록원데이터["블록명"].unique().tolist()
블록집합
# Out:
# ['S1', 'S2', 'S3', 'S4']

# %%
최초정반집합 = 정반원데이터["정반명"].unique().tolist()
최초정반집합
# Out:
# ['A', 'B', 'C']

# %% [markdown]
# # 블록 데이터 전처리 함수

# %%
import functools
def unpack_df_columns(func):
    @functools.wraps(func)
    def _unpack_df_columns(*args, **kwargs):
        series = args[0]
        return func(*series.values)
    return _unpack_df_columns

# %%
@unpack_df_columns
def 최소착수요구일구하기(납기, 공기):
    result = pd.to_datetime(납기) - timedelta(days=int(공기))
    return result.date()

# %%
착수일가중치, 공기가중치, 크기가중치 = 0.7, 0.5, 0.5

@unpack_df_columns
def 블록우선순위구하기(날순, 공순, 크순):
    global 착수일가중치, 공기가중치, 크기가중치
    result = np.round((날순*float(착수일가중치) + 공순*float(공기가중치) + 크순*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 블록사이즈튜플만들기(가로, 세로):
    길이2 = max(가로, 세로)  
    길이1 = min(가로, 세로)
    result = (길이2, 길이1)
    return result

# %%
def 블록데이터전처리(블록원데이터):
    df1 = 블록원데이터.copy()
    df1["사이즈"] = df1[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
    df1["최대길이"] = df1["사이즈"].apply(lambda x: max(x))
    df1["납기"] = pd.to_datetime(df1["납기"])
    df1["면적"] = df1.eval("가로*세로")
    df1["최소착수요구일"] = df1[["납기", "표준공기"]].apply(최소착수요구일구하기, axis=1)
    df1["날짜순서"] = df1["최소착수요구일"].rank()
    df1["공기순서"] = df1["표준공기"].rank(ascending=False)
    df1["크기순서"] = df1["면적"].rank(ascending=False)
    df1["우선순위"] = df1[["날짜순서", "공기순서", "크기순서"]].apply(블록우선순위구하기, axis=1)
    
    df1 = df1.drop(['가로', '세로'], axis=1)
    df1 = df1.sort_values(by=["우선순위"])
    return df1

# %%
df1 = 블록데이터전처리(블록원데이터)
df1
# Out:
#   블록명  중량  표준공기         납기       사이즈  최대길이   면적     최소착수요구일  날짜순서  공기순서  크기순서  \
# 1  S2  60     3 2024-02-15  (12, 10)    12  120  2024-02-12   1.0   1.0   1.0
# 0  S1  50     2 2024-02-15  (10, 10)    10  100  2024-02-13   2.5   2.5   2.0
# 3  S4  20     2 2024-02-15    (6, 5)     6   30  2024-02-13   2.5   2.5   3.5
# 2  S3  30     1 2024-02-15    (6, 5)     6   30  2024-02-14   4.0   4.0   3.5
#
#    우선순위
# 1   0.6
# 0   1.3
# 3   1.6
# 2   2.2

# %%
공기가중치 = [9, 0.5]
크기가중치 = [0.5, 9]
착수일가중치 = 0.5
for 공기가중치, 크기가중치 in zip(공기가중치, 크기가중치):
    df2 = 블록데이터전처리(블록원데이터)
    print(df2[["블록명", "우선순위"]])
# Out:
#   블록명  우선순위
# 1  S2   3.3
# 0  S1   8.2
# 3  S4   8.5
# 2  S3  13.2
#   블록명  우선순위
# 1  S2   3.3
# 0  S1   6.8
# 3  S4  11.3
# 2  S3  11.8

# %% [markdown]
# # 정반 데이터 전처리 함수

# %%
중량가중치, 크기가중치 = 0.5, 0.7

@unpack_df_columns
def 정반우선순위구하기(중순, 크순):
    global 중량가중치, 크기가중치
    result = np.round((중순*float(중량가중치) + 크순*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 정반사이즈튜플만들기(가로, 세로):
    길이1 = max(가로, 세로)  
    길이2 = min(가로, 세로)
    result = (길이1, 길이2)
    return result

# %%
def 정반데이터전처리(정반원데이터):
    df = 정반원데이터.copy()
    
    df["사이즈"] = df[["가로", "세로"]].apply(정반사이즈튜플만들기, axis=1)
    df["면적"] = df.eval("가로*세로")
    df["최대길이"] = df["사이즈"].apply(lambda x: max(x))
    df["중량순서"] = df["가능중량"].rank(ascending=False)
    df["크기순서"] = df["면적"].rank(ascending=False)
    df["우선순위"] = df[["중량순서", "크기순서"]].apply(정반우선순위구하기, axis=1)
    
    df = df.drop(['가로', '세로'], axis=1)
    df = df.sort_values(by=["우선순위"])
    return df

# %%
df2 = 정반데이터전처리(정반원데이터)
df2
# Out:
#   정반명  가능중량       사이즈   면적  최대길이  중량순서  크기순서  우선순위
# 0   A   100  (20, 10)  200    20   1.5   1.0   0.5
# 1   B   100  (10, 10)  100    10   1.5   2.0   0.7
# 2   C    30   (10, 5)   50    10   3.0   3.0   1.2

# %%
중량가중치들 = [0.9, 0.01]
크기가중치들 = [0.01, 3]

for 중량가중치, 크기가중치 in zip(중량가중치들, 크기가중치들):
    df2 = 정반데이터전처리(정반원데이터)
    print(df2[["정반명", "우선순위"]])
# Out:
#   정반명  우선순위
# 0   A   0.5
# 1   B   0.5
# 2   C   0.9
#   정반명  우선순위
# 0   A   1.0
# 1   B   2.0
# 2   C   3.0

# %% [markdown]
# # 변수정리함수

# %%
def 블록변수정리(블록데이터, target_block):
    블록 = dict()
    블록["블록명"] = target_block
    블록["인덱스"] =  블록데이터[블록데이터["블록명"]==target_block].index.values[0]
    블록["중량"] = 블록데이터[블록데이터["블록명"]==target_block]["중량"].values[0]
    블록["사이즈"] = 블록데이터[블록데이터["블록명"]==target_block]["사이즈"].values[0]
    블록["최대길이"] = 블록데이터[블록데이터["블록명"]==target_block]["최대길이"].values[0]
    블록["면적"] = 블록데이터[블록데이터["블록명"]==target_block]["면적"].values[0]
    블록["납기"] = 블록데이터[블록데이터["블록명"]==target_block]["납기"].values[0]
    블록["표준공기"] = 블록데이터[블록데이터["블록명"]==target_block]["표준공기"].values[0]
    블록["최소착수요구일"] = 블록데이터[블록데이터["블록명"]==target_block]["최소착수요구일"].values[0]
    return 블록

# %%
블록변수정리(df1, "S1")
# Out:
# {'블록명': 'S1',
#  '인덱스': 0,
#  '중량': 50,
#  '사이즈': (10, 10),
#  '최대길이': 10,
#  '면적': 100,
#  '납기': numpy.datetime64('2024-02-15T00:00:00.000000000'),
#  '표준공기': 2,
#  '최소착수요구일': datetime.date(2024, 2, 13)}

# %%
def 정반변수정리(정반데이터, 정반명):
    정반 = dict()
    정반["정반명"] = 정반명
    정반["가능중량"] = 정반데이터[정반데이터["정반명"]==정반명]["가능중량"].values[0]
    정반["사이즈"] = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    정반["최대길이"] = 정반데이터[정반데이터["정반명"]==정반명]["최대길이"].values[0]
    정반["면적"] = 정반데이터[정반데이터["정반명"]==정반명]["면적"].values[0]
    
    return 정반

# %%
A = 정반변수정리(df2, "A")
A
# Out:
# {'정반명': 'A', '가능중량': 100, '사이즈': (20, 10), '최대길이': 20, '면적': 200}

# %% [markdown]
# # 정반가능중량 조건 적합도 검토

# %%
# 정반가능중량에 안전고려하여 감률 적용?????

def 정반가능중량검토(target_block, 블록데이터, 정반, 정반데이터):
    블록중량 = 블록데이터[블록데이터["블록명"]==target_block]["중량"].values[0]
    정반가능중량 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
    
    if 정반가능중량 > 블록중량: 
        return "적합"
    else:
        return "부적합"

# %%
정반가능중량검토("S1", df1, "A", df2)
# Out:
# '적합'

# %% [markdown]
# # 최장길이 조건 적합도 검토

# %%
def 정반최대길이검토(target_block, 블록데이터, 정반, 정반데이터):
    블록최대길이 = 블록데이터[블록데이터["블록명"]==target_block]["최대길이"].values[0]
    정반최대길이 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
    
    if 정반최대길이 > 블록최대길이: 
        return "적합"
    else:
        return "부적합"

# %%
정반최대길이검토("S1", df1, "A", df2)
# Out:
# '적합'

# %% [markdown]
# # 면적 달력

# %%
def get_end_date_of_month(year, month):
    # Get the number of days in the given month
    num_days = calendar.monthrange(year, month)[1]
    # Return the last day of the month as a datetime object
    return date(year, month, num_days)

# %%
def create_면적달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터):
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    면적달력 = pd.DataFrame()
    면적달력.index = 날짜집합
   
    for 정반 in 정반집합:
        면적달력[f"{정반}"] = 정반데이터[정반데이터["정반명"]==정반]["면적"].values[0]

    return 면적달력

# %%
면적달력 = create_면적달력(2024, 2, 1, 2024, 2, df2)
면적달력.head()
# Out:
#               A    B   C
# 2024-02-01  200  100  50
# 2024-02-02  200  100  50
# 2024-02-03  200  100  50
# 2024-02-04  200  100  50
# 2024-02-05  200  100  50

# %% [markdown]
# # 최선조기착수일 후보/착수대상 지정

# %%
def get_최선조기착수일후보_가중(면적달력, 정반리스트, 대상블록, 블록데이터, 시점후퇴계수,  면적가중비율, 조기착수금지일수):
    '''
    최소착수요구일 보다 7일 이상 조기 착수 금지 로직 반영
    '''
    result_dict = dict()
    
    블록면적 = 블록데이터[블록데이터["블록명"]==대상블록]["면적"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==대상블록]["표준공기"].values[0]
    최소착수요구일_datetime = 블록데이터[블록데이터["블록명"]==대상블록]["최소착수요구일"].values[0]
    면적달력날짜리스트_datetime = list(면적달력.index)
    
    최소착수요구일 = 최소착수요구일_datetime.strftime("%Y-%m-%d")
    면적달력날짜리스트 = [date_obj.strftime("%Y-%m-%d") for date_obj in 면적달력날짜리스트_datetime]
    
    최소착수요구일달력인덱스 = 면적달력날짜리스트.index(최소착수요구일)
    
    한계시점인덱스 = max(0, 최소착수요구일달력인덱스 - 조기착수금지일수)  #### 최소요구착수일보다 7일이상 조기 착수하지 않도록!!
    print(f"*** 최소착수요구일달력인덱스: {최소착수요구일달력인덱스}, 최소착수요구일: {최소착수요구일}, 한계시점인덱스: {한계시점인덱스}, 한계시점날짜: {면적달력날짜리스트_datetime[한계시점인덱스].strftime('%Y-%m-%d')}")

    for 대상정반 in 정반리스트:
        대상정반면적리스트 = 면적달력[f"{대상정반}"].iloc[:최소착수요구일달력인덱스+표준공기*3].values   # 표준공기의 3배수 범위내로 한정
        
        for i in range(len(대상정반면적리스트)):
            조회시점인덱스 = 한계시점인덱스 + i + 시점후퇴계수
            # 조회시점날짜 = 면적달력날짜리스트_datetime[조회시점인덱스].date() 

            # if 조회시점날짜 <= 최소착수요구일_datetime:

            조회구간면적리스트 = 대상정반면적리스트[조회시점인덱스:조회시점인덱스+표준공기]
            조회기간최소면적 = min(조회구간면적리스트)
            print(f"{i}- 정반명: {대상정반}, 블록면적: {블록면적}, 조회시점인덱스: {조회시점인덱스}, 조회시점날짜: {면적달력날짜리스트[조회시점인덱스]}, 최소착수요구일: {최소착수요구일_datetime}, 조회기간최소면적: {조회기간최소면적}")
            
            if 조회기간최소면적 >= 블록면적 * 면적가중비율:
                최선조기착수일 = 면적달력.index[조회시점인덱스]
                result_dict[대상정반] = 최선조기착수일
                break
        
    return result_dict

# %%
정반리스트 = ["A"]
최선조기착수일후보 = get_최선조기착수일후보_가중(면적달력, 정반리스트, "S2", df1, 1, 1, 7)
최선조기착수일후보
# Out:
# *** 최소착수요구일달력인덱스: 11, 최소착수요구일: 2024-02-12, 한계시점인덱스: 4, 한계시점날짜: 2024-02-05
# 0- 정반명: A, 블록면적: 120, 조회시점인덱스: 5, 조회시점날짜: 2024-02-06, 조회기간최소면적: 200
# {'A': Timestamp('2024-02-06 00:00:00')}

# %%
def get_최선조기착수대상(최선조기착수일후보, 최소요구착수일):
    # 복수의 경우 셔플후 얼리스트 선택
    temp_list = list(최선조기착수일후보.items())
    shuffle(temp_list)
    최선조기착수일후보 = dict(temp_list)
    
    최소요구착수일 = pd.Timestamp(최소요구착수일)
        
    최소요구납기충족리스트 = []
    for 후보날짜 in temp_list:
        
        if 후보날짜[1] <= 최소요구착수일:
            최소요구납기충족리스트.append(후보날짜)
                
    if 최소요구납기충족리스트 != []:
        최소요구납기충족리스트 = dict(최소요구납기충족리스트)

        earliest_item = min(최소요구납기충족리스트.items(), key=lambda x: x[1])
        최선정반 = earliest_item[0]
        최선착수일 = earliest_item[1].strftime('%Y-%m-%d')
        return 최선정반, 최선착수일
    
    else:
        return None, None

# %%
최선조기착수대상 = get_최선조기착수대상(최선조기착수일후보, "2024-02-10")
최선조기착수대상
# Out:
# ('A', '2024-02-06')

# %%
def update_면적달력(면적달력, 최선조기착수대상, 배치블록명, 블록데이터):
    
    정반리스트 = 면적달력.columns.tolist()
    블록면적 = 블록데이터[블록데이터["블록명"]==배치블록명]["면적"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==배치블록명]["표준공기"].values[0]
    블록착수일 = 최선조기착수대상[1]
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)
    정반 = 최선조기착수대상[0]
        

    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values

    if min(조회기간면적리스트) >= 블록면적:
        for idx, 대상일면적 in enumerate(조회기간면적리스트):
            수정면적 = 대상일면적 - 블록면적
            대상일인덱스 = 시점인덱스 + idx
            면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
            
        return 면적달력

# %%
면적달력 = update_면적달력(면적달력, 최선조기착수대상, "S1", df1)
면적달력.head(10)
# Out:
#               A    B   C
# 2024-02-01  200  100  50
# 2024-02-02  200  100  50
# 2024-02-03  200  100  50
# 2024-02-04  200  100  50
# 2024-02-05  200  100  50
# 2024-02-06  100  100  50
# 2024-02-07  100  100  50
# 2024-02-08  200  100  50
# 2024-02-09  200  100  50
# 2024-02-10  200  100  50

# %% [markdown]
# # 블록명 달력

# %%
def create_블록명달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터):
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
블록명달력 = create_블록명달력(2024, 2, 1, 2024, 2, df2)
블록명달력.head()
# Out:
#              A   B   C
# 2024-02-01  []  []  []
# 2024-02-02  []  []  []
# 2024-02-03  []  []  []
# 2024-02-04  []  []  []
# 2024-02-05  []  []  []

# %%
def update_블록명달력(블록명달력, 최선정반, 블록데이터, block_names, best_st_date):
    
    달력 = 블록명달력
    날짜집합 = 블록명달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]

    for block_name, 블록착수일 in zip(block_names, best_st_date):

        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        표준공기 = 블록데이터[블록데이터["블록명"]==block_name]["표준공기"].values[0]

        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(block_name)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %%
block_names = ["S1"]
block_sizes = [(2, 5)]
best_st_date = ["2024-02-01"]
블록명달력 = update_블록명달력(블록명달력, "A", df1, block_names, best_st_date)
블록명달력.head()
# Out:
#                A   B   C
# 2024-02-01  [S1]  []  []
# 2024-02-02  [S1]  []  []
# 2024-02-03    []  []  []
# 2024-02-04    []  []  []
# 2024-02-05    []  []  []

# %%
block_names = ["S1", "S2"]
block_sizes = [(2, 5), (3, 4)]
best_st_date = ["2024-02-01", "2024-02-02"]
블록명달력 = update_블록명달력(블록명달력, "A", df1, block_names, best_st_date)
블록명달력.head()
# Out:
#                    A   B   C
# 2024-02-01      [S1]  []  []
# 2024-02-02  [S1, S2]  []  []
# 2024-02-03      [S2]  []  []
# 2024-02-04      [S2]  []  []
# 2024-02-05        []  []  []

# %% [markdown]
# # 사이즈 달력

# %%
def create_사이즈달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터):
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
사이즈달력 = create_사이즈달력(2024, 2, 1, 2024, 2, df2)
사이즈달력
# Out:
#              A   B   C
# 2024-02-01  []  []  []
# 2024-02-02  []  []  []
# 2024-02-03  []  []  []
# 2024-02-04  []  []  []
# 2024-02-05  []  []  []
# 2024-02-06  []  []  []
# 2024-02-07  []  []  []
# 2024-02-08  []  []  []
# 2024-02-09  []  []  []
# 2024-02-10  []  []  []
# 2024-02-11  []  []  []
# 2024-02-12  []  []  []
# 2024-02-13  []  []  []
# 2024-02-14  []  []  []
# 2024-02-15  []  []  []
# 2024-02-16  []  []  []
# 2024-02-17  []  []  []
# 2024-02-18  []  []  []
# 2024-02-19  []  []  []
# 2024-02-20  []  []  []
# 2024-02-21  []  []  []
# 2024-02-22  []  []  []
# 2024-02-23  []  []  []
# 2024-02-24  []  []  []
# 2024-02-25  []  []  []
# 2024-02-26  []  []  []
# 2024-02-27  []  []  []
# 2024-02-28  []  []  []
# 2024-02-29  []  []  []

# %%
def update_사이즈달력(사이즈달력, 최선정반, 블록데이터, block_names, block_sizes, best_st_date):
    
    달력 = 사이즈달력
    날짜집합 = 달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]
        
    for i in range(len(block_names)):
        블록명 = block_names[i]
        블록사이즈 = block_sizes[i]
        블록착수일 = best_st_date[i]
        
        표준공기 = 블록데이터[블록데이터["블록명"]==블록명]["표준공기"].values[0]
        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        
        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(블록사이즈)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %%
block_names = ["S1", "S2", "S3"]
block_sizes = [(2, 5), (3, 4), (2, 5)]
best_st_date = ["2024-02-01", "2024-02-03", "2024-02-06"]
사이즈달력 = update_사이즈달력(사이즈달력, "B", df1, block_names,block_sizes, best_st_date)
사이즈달력
# Out:
#              A         B   C
# 2024-02-01  []  [(2, 5)]  []
# 2024-02-02  []  [(2, 5)]  []
# 2024-02-03  []  [(3, 4)]  []
# 2024-02-04  []  [(3, 4)]  []
# 2024-02-05  []  [(3, 4)]  []
# 2024-02-06  []  [(2, 5)]  []
# 2024-02-07  []        []  []
# 2024-02-08  []        []  []
# 2024-02-09  []        []  []
# 2024-02-10  []        []  []
# 2024-02-11  []        []  []
# 2024-02-12  []        []  []
# 2024-02-13  []        []  []
# 2024-02-14  []        []  []
# 2024-02-15  []        []  []
# 2024-02-16  []        []  []
# 2024-02-17  []        []  []
# 2024-02-18  []        []  []
# 2024-02-19  []        []  []
# 2024-02-20  []        []  []
# 2024-02-21  []        []  []
# 2024-02-22  []        []  []
# 2024-02-23  []        []  []
# 2024-02-24  []        []  []
# 2024-02-25  []        []  []
# 2024-02-26  []        []  []
# 2024-02-27  []        []  []
# 2024-02-28  []        []  []
# 2024-02-29  []        []  []

# %%
block_names = ["S1", "S2", "S3", "S4"]
block_sizes = [(2, 5), (3, 4), (2, 5), (4, 5)]
best_st_date = ["2024-02-01", "2024-02-03", "2024-02-06", "2024-02-02"]
사이즈달력 = update_사이즈달력(사이즈달력, "B", df1, block_names, block_sizes, best_st_date)
사이즈달력
# Out:
#              A                 B   C
# 2024-02-01  []          [(2, 5)]  []
# 2024-02-02  []  [(2, 5), (4, 5)]  []
# 2024-02-03  []  [(3, 4), (4, 5)]  []
# 2024-02-04  []          [(3, 4)]  []
# 2024-02-05  []          [(3, 4)]  []
# 2024-02-06  []          [(2, 5)]  []
# 2024-02-07  []                []  []
# 2024-02-08  []                []  []
# 2024-02-09  []                []  []
# 2024-02-10  []                []  []
# 2024-02-11  []                []  []
# 2024-02-12  []                []  []
# 2024-02-13  []                []  []
# 2024-02-14  []                []  []
# 2024-02-15  []                []  []
# 2024-02-16  []                []  []
# 2024-02-17  []                []  []
# 2024-02-18  []                []  []
# 2024-02-19  []                []  []
# 2024-02-20  []                []  []
# 2024-02-21  []                []  []
# 2024-02-22  []                []  []
# 2024-02-23  []                []  []
# 2024-02-24  []                []  []
# 2024-02-25  []                []  []
# 2024-02-26  []                []  []
# 2024-02-27  []                []  []
# 2024-02-28  []                []  []
# 2024-02-29  []                []  []

# %% [markdown]
# # 진행중 블록 면적달력에 반영

# %%
def update_init_면적달력(면적달력, 블록착수일, 정반, 배치블록명, 블록면적, 표준공기):
    
    정반리스트 = 면적달력.columns.tolist()
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)   
    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values

    for idx, 대상일면적 in enumerate(조회기간면적리스트):
        수정면적 = 대상일면적 - 블록면적
        대상일인덱스 = 시점인덱스 + idx
        면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
            
    return 면적달력

# %% [markdown]
# # 정반 레이아웃 배치 적합도 검토

# %%
def 정반세팅(사이즈):  #사이즈 = (10, 10)
    surface_width, surface_height = 사이즈[0], 사이즈[1]  # Adjusted to match the provided image for demonstration
    surface = np.zeros((surface_height, surface_width), dtype=int)
    return surface, surface_width, surface_height

# %%
def can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, start_row, start_col, thresh):
    new_width = surface_width - thresh
    new_height = surface_height - thresh
    
#     block_height, block_width = block_height, block_width
    if start_row + block_height > surface_height or start_col + block_width > surface_width:
        return False

    block_area = surface[start_row:start_row+block_height, start_col:start_col+block_width]
    if np.any(block_area != 0):
        return False
    
    if start_row > 0 and np.any(surface[start_row-thresh: start_row, start_col:start_col+block_width] != 0):
        return False
    if start_col > 0 and np.any(surface[start_row: start_row+block_height, start_col-thresh: start_col] != 0):
        return False
    
    return True



# Function to place a block on the surface, if possible
def place_block(surface, block_height, block_width, start_row, start_col, block_id):
    block_height, block_width = block_height, block_width
    surface[start_row:start_row + block_height, start_col:start_col + block_width] = block_id

# Function to find the best fit for a block on the surface
def find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh):
    best_fit_score = float('inf')
    best_position = None
    block_height, block_width = block_height, block_width

    # Iterate over all possible positions on the surface
    for y in range(surface_height - block_height + 1):
        for x in range(surface_width - block_width + 1):
            if can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, y, x, thresh):
                # Calculate a score; here we use the top-left corner (y, x) as the score
                # A lower score means the block is closer to the top-left
                score = y + x
                if score < best_fit_score:
                    best_fit_score = score
                    best_position = (y, x)

    # If a best position was found, place the block there
    if best_position:
        place_block(surface, block_height, block_width, *best_position, block_id)
        return True

    return False  # No fit found

# Function to fit blocks on the surface in order
def fit_blocks_with_thresh(surface, surface_width, surface_height, blocks, names, thresh):
    result = ""
    block_id = max(map(max, surface))+1  # Start numbering blocks from 1
    for name, block in zip(names, blocks):
        
        block_height, block_width = block
        
        if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
            print(f"1차검토 - Block {name} of height {block_height} width {block_width} could not be placed.")
            result = "부적합"
            
            if block_height != block_width:  # 가로 세로 길이가 같지 않다면...
                
                ## 가로 세로 길이 바꿔서 검토 -------------------------------------
                block_height, block_width = block_width, block_height
                if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
                    print(f"2차검토 - Block {name} of height {block_height} width {block_width} could not be placed.")
                    result = "부적합"
            
        else:
            result = "적합"
        block_id += 1  # Increment block_id for the next block
    return surface, result

# %%
def draw1(surface, block_names):
    fig, ax = plt.subplots(figsize=(8, 8))

    cmap = mcolors.ListedColormap(['white'] + ['C{}'.format(i) for i in range(len(block_names))])
    norm = mcolors.BoundaryNorm(np.arange(0.5, len(block_names) + 2), cmap.N)

    ax.imshow(surface, cmap=cmap, norm=norm)

    for y in range(surface.shape[0]):
        for x in range(surface.shape[1]):
            if surface[y, x] != 0:
                ax.text(x, y, str(block_names[surface[y, x]-1]), ha='center', va='center', color='black', fontsize=6)
                
    ax.set_xticks(np.arange(-.5, surface.shape[1], 1), minor=True)
    ax.set_yticks(np.arange(-.5, surface.shape[0], 1), minor=True)
    ax.grid(which="minor", color="black", linestyle='-', linewidth=1)
    ax.tick_params(which="minor", size=0)

    ax.set_xticks([])
    ax.set_yticks([])

    plt.show()

# %%
thresh = 2

def 정반배치레이아웃적합도(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
        
    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    적합도 = 배치결과[1]
    
    return 적합도

# %%
적합도 = 정반배치레이아웃적합도("A", df2, "2024-02-03", 블록명달력, 사이즈달력)
적합도
# Out:
# ''

# %%
def check_if_value_in_list(my_list, value_to_check):
    if value_to_check in my_list:
        return "부적합"
    else:
        return "적합"

# %% [markdown]
# # 생산계획수립

# %%
def 생산계획수립(블록데이터, 정반데이터, 면적달력, 블록명달력, 사이즈달력, 조기착수금지일수):
    
    블록리스트 = 블록데이터["블록명"].tolist()
    정반리스트 = 정반데이터["정반명"].tolist()
    
    면적달력 = 면적달력
    블록명달력 = 블록명달력
    사이즈달력 = 사이즈달력
    
    결론_정반_dict = {key: [] for key in 정반리스트}
    결론_블록_dict = {key: [] for key in 정반리스트}
    결론_블록사이즈_dict = {key: [] for key in 정반리스트}
    결론_정반_dict = {key: [] for key in 정반리스트}
    결론_착수일자_dict = {key: [] for key in 정반리스트}
    
    df_블록리스트 = []
    df_블록사이즈리스트 = []
    df_정반리스트 = []
    df_착수일자 = []
    df_상태정보 = []
    
    레이아웃배치실패 = []
    
    for _ in tqdm(range(len(블록리스트))):
                
        if 블록리스트:
            target_block = 블록리스트[0]
        else:
            print("수정블록리스트에 검토대상 잔여블록이 없습니다.")
            break        
        
        블록 = 블록변수정리(블록데이터, target_block)
        블록명 = 블록["블록명"]
        블록사이즈 = 블록["사이즈"]
        납기 = 블록["납기"]
        표준공기 = 블록["표준공기"]
        최소착수요구일 = 블록["최소착수요구일"]
        
        print(f"*** 검토대상블록: {블록명}, 사이즈: {블록사이즈}, 납기: {np.datetime_as_string(납기, unit='D')}, 표준공기: {표준공기}, 최소착수요구일:{최소착수요구일}")
        
        ## 정반가능중량 조건 적합도 검토 ----------------------------------------------------------
        중량조건적합정반들 = []
        정반리스트_iter = iter(정반리스트)
        
        try:
            while True:
                정반 = next(정반리스트_iter)
                중량적합도 = 정반가능중량검토(블록명, 블록데이터, 정반, 정반데이터)
                if 중량적합도 == "적합":
                    중량조건적합정반들.append(정반)
        except StopIteration:
            pass
                       

        print(f"*** 중량조건적합정반들: {중량조건적합정반들}")
        
        ## 최장길이적합 조건 검토 ---------------------------------------
        최장길이조건적합정반들 = []
        중량조건적합_iter = iter(중량조건적합정반들)
        
        try:
            while True:
                정반 = next(중량조건적합_iter)
                최장길이적합도 = 정반최대길이검토(target_block, 블록데이터, 정반, 정반데이터)
                if 최장길이적합도 == "적합":
                    최장길이조건적합정반들.append(정반)
        except StopIteration:
            pass
                    
        print(f"*** 최장길이조건적합정반들: {최장길이조건적합정반들}")
        
        ## 면적달력으로 최선조기착수일 검토 ---------------------------------------------------------------------
        if 최장길이조건적합정반들 != []:
            
            ####------------------------------------------------------------------------------------
            레이아웃배치순환 = [a for a in range(1, 31)]
            레이아웃배치순환_iterator = iter(레이아웃배치순환)
            
            try:     
                while True:
                    i = next(레이아웃배치순환_iterator)
                    print()
                    print(f">>> 제{i}차 레이아웃 적합도 검토")

                    # get_최선조기착수일후보_가중(면적달력, 정반리스트, 대상블록, 블록데이터, 시점후퇴계수,  면적가중비율, 조기착수금지일수)
                    최선조기착수일후보 = get_최선조기착수일후보_가중(면적달력, 최장길이조건적합정반들, 블록명, 블록데이터, i-1, 1, 조기착수금지일수) 
                    print(f"*** 최선조기착수일후보: {최선조기착수일후보}")

                    최선조기착수대상 = get_최선조기착수대상(최선조기착수일후보, 최소착수요구일)  ##랜덤 셀렉트 적용
                    print(f"*** 최선조기착수대상: {최선조기착수대상}")


                    if 최선조기착수대상[0] == None:
                        df_상태정보.append('최선조기착수 후보날짜가 없음')
                        블록리스트.remove(블록명)
                        print(">>> 최선조기착수 후보날짜가 없습니다.")

                        break


                    else:      #  최선조기착수대상[0] != None:
                        최선정반명 = 최선조기착수대상[0]
                        최선조기착수일 = 최선조기착수대상[1]

                        print(f"*** 랜덤선택 최선정반명:{최선정반명}, 최선조기착수일:{최선조기착수일}")

                        결론_블록_dict[최선정반명].append(블록명)
                        결론_블록사이즈_dict[최선정반명].append(블록사이즈)
                        결론_정반_dict[최선정반명].append(최선정반명)
                        결론_착수일자_dict[최선정반명].append(최선조기착수일)

                        df_블록리스트.append(블록명)
                        df_블록사이즈리스트.append(블록사이즈)
                        df_정반리스트.append(최선정반명)
                        df_착수일자.append(최선조기착수일)

                        임시_블록명달력 = update_블록명달력(블록명달력, 최선정반명, 블록데이터, 결론_블록_dict[최선정반명], 결론_착수일자_dict[최선정반명])
                        임시_사이즈달력 = update_사이즈달력(사이즈달력, 최선정반명, 블록데이터, 결론_블록_dict[최선정반명], 결론_블록사이즈_dict[최선정반명], 결론_착수일자_dict[최선정반명])

                        ### 나중에 함수로 빼야...
                        레이아웃적합도리스트 = []
                        for k in range(표준공기):
                            date_object = datetime.strptime(최선조기착수일, "%Y-%m-%d") + timedelta(days=i-1)
                            new_date = date_object + timedelta(days=k)
                            레이아웃검토날짜 = new_date.strftime("%Y-%m-%d")   
                            print(f"i: {i}, k: {k}, date_object: {date_object}, 레이아웃검토날짜: {레이아웃검토날짜}")

                            적합도 = 정반배치레이아웃적합도(최선정반명, 정반데이터, 레이아웃검토날짜, 임시_블록명달력, 임시_사이즈달력)

                            레이아웃적합도리스트.append(적합도)

                        적합도리스트체크 = check_if_value_in_list(레이아웃적합도리스트, "부적합")
                        print(f"*** 레이아웃 적합도리스트 체크: {적합도리스트체크}")

                        ### -----------------------------------------------------------------------------------------------------
                        if 적합도리스트체크 == "부적합":

                            결론_블록_dict[최선정반명] = 결론_블록_dict[최선정반명][:-1]                    
                            결론_블록사이즈_dict[최선정반명] = 결론_블록사이즈_dict[최선정반명][:-1]
                            결론_정반_dict[최선정반명] = 결론_정반_dict[최선정반명][:-1]
                            결론_착수일자_dict[최선정반명] = 결론_착수일자_dict[최선정반명][:-1]

                            df_블록리스트 = df_블록리스트[:-1]
                            df_블록사이즈리스트 = df_블록사이즈리스트[:-1]
                            df_정반리스트 = df_정반리스트[:-1]
                            df_착수일자 = df_착수일자[:-1]

                            임시_블록명달력 = None
                            임시_사이즈달력 = None

                            pass

                        else:
                            블록명달력 = 임시_블록명달력
                            사이즈달력 = 임시_사이즈달력
                            면적달력 = update_면적달력(면적달력, 최선조기착수대상, 블록명, 블록데이터)
                            블록리스트.remove(블록명)

                            df_상태정보.append('정상배치완료')
                            print(f"*** 정상배치 완료, 착수일자: {df_착수일자[-1]}")
                            break
            except StopIteration:
                print("End of 정반레이아웃 iteration")

        else:
            df_상태정보.append('중량 또는 최장길이 조건 충족 불가능')
            블록리스트.remove(블록명)
            print(">>>중량 또는 최장길이 충족 정반이 없습니다.")
        
        print("="*120)
        print()
    
    return df_블록리스트, df_정반리스트, df_착수일자, df_상태정보, 면적달력, 블록명달력, 사이즈달력

# %% [markdown]
# # 시뮬레이션

# %%
data_num = "_실행계획"
# data_num = "_실행계획_small"
시작년, 시작월, 시작일, 종료년, 종료월 = 2023, 10, 1, 2024, 3

thresh = 1  # 블록 간격(m)
조기착수금지일수 = 7

블록원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="블록데이터")
기배치블록 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="기배치블록")
정반원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="정반데이터")
블록원데이터.shape
# Out:
# (123, 6)

# %%
착수일가중치, 공기가중치, 크기가중치 = 1, 0.2, 0.1
블록데이터 = 블록데이터전처리(블록원데이터)

중량가중치, 크기가중치 = 0.5, 0.5
정반데이터 = 정반데이터전처리(정반원데이터)
블록데이터.shape, 정반데이터.shape
# Out:
# ((123, 12), (2, 8))

# %%
블록데이터.head()
정반데이터.head()   ## 세로 길이에 안전통로 여분 고려 +2m (원사이즈는 26이었음)
# Out:
#     블록명   중량  표준공기         납기       사이즈  최대길이   면적     최소착수요구일  날짜순서  공기순서  \
# 2   S15  139    10 2023-11-13  (15, 14)    15  210  2023-11-03   4.0  42.0
# 11  S24   56    12 2023-11-21  (18, 14)    18  252  2023-11-09   9.5  22.0
# 20  S33   33    13 2023-11-27  (19, 15)    19  285  2023-11-14  14.5  12.5
# 6   S19   21    12 2023-11-15   (14, 7)    14   98  2023-11-03   4.0  22.0
# 3   S16   24    11 2023-11-14   (14, 5)    14   70  2023-11-03   4.0  33.0
#
#      크기순서  우선순위
# 2    40.0   5.5
# 11   29.0   5.6
# 20    6.0   5.9
# 6   102.5   6.2
# 3   112.5   7.3
#   정반명  가능중량       사이즈    면적  최대길이  중량순서  크기순서  우선순위
# 1   B   140  (41, 29)  1189    41   1.5   1.0   0.4
# 0   A   140  (42, 28)  1176    42   1.5   2.0   0.6

# %%
면적달력 = create_면적달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
블록명달력 = create_블록명달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
사이즈달력 = create_사이즈달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)

기배치블록["블록면적"] = 기배치블록.eval("가로*세로")
기배치블록["사이즈"] = 기배치블록[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
기배치블록["착수일"] = 기배치블록["착수일"].dt.strftime('%Y-%m-%d')
기배치블록["종료일"] = 기배치블록["종료일"].dt.strftime('%Y-%m-%d')
for 블록착수일, 배치블록명, 블록면적, 표준공기, 배치정반 in zip(기배치블록["착수일"], 기배치블록["블록명"], 기배치블록["블록면적"], 기배치블록["공기"], 기배치블록["배치정반"],):
    면적달력 = update_init_면적달력(면적달력, 블록착수일, 배치정반, 배치블록명, 블록면적, 표준공기)

# %%
생산계획결과 = 생산계획수립(블록데이터, 정반데이터, 면적달력, 블록명달력, 사이즈달력, 조기착수금지일수)
# Out:
#   0%|          | 0/123 [00:00<?, ?it/s]
# *** 검토대상블록: S15, 사이즈: (15, 14), 납기: 2023-11-13, 표준공기: 10, 최소착수요구일:2023-11-03
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 33, 최소착수요구일: 2023-11-03, 한계시점인덱스: 26, 한계시점날짜: 2023-10-27
# 0- 정반명: B, 블록면적: 210, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 467
# 0- 정반명: A, 블록면적: 210, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 241
# *** 최선조기착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-10-27')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-10-27
# i: 1, k: 0, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-27
# i: 1, k: 1, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-28
# i: 1, k: 2, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-29
# i: 1, k: 3, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-30
# i: 1, k: 4, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-31
# i: 1, k: 5, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-01
# i: 1, k: 6, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-02
# i: 1, k: 7, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 8, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 9, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-05
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-10-27
# ========================================================================================================================
#
# *** 검토대상블록: S24, 사이즈: (18, 14), 납기: 2023-11-21, 표준공기: 12, 최소착수요구일:2023-11-09
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 39, 최소착수요구일: 2023-11-09, 한계시점인덱스: 32, 한계시점날짜: 2023-11-02
# 0- 정반명: B, 블록면적: 252, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-09, 조회기간최소면적: 547
# 0- 정반명: A, 블록면적: 252, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-09, 조회기간최소면적: 184
# 1- 정반명: A, 블록면적: 252, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-09, 조회기간최소면적: 589
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-02 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-02')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-02
# i: 1, k: 0, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-02
# i: 1, k: 1, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 2, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 3, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 4, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 5, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 1, k: 6, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 1, k: 7, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 1, k: 8, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-10
# i: 1, k: 9, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 1, k: 10, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 1, k: 11, date_object: 2023-11-02 00:00:00, 레이아웃검토날짜: 2023-11-13
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-11-02
# ========================================================================================================================
#
# *** 검토대상블록: S33, 사이즈: (19, 15), 납기: 2023-11-27, 표준공기: 13, 최소착수요구일:2023-11-14
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 44, 최소착수요구일: 2023-11-14, 한계시점인덱스: 37, 한계시점날짜: 2023-11-07
# 0- 정반명: B, 블록면적: 285, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-14, 조회기간최소면적: 615
# 0- 정반명: A, 블록면적: 285, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-14, 조회기간최소면적: 1007
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-07 00:00:00'), 'A': Timestamp('2023-11-07 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-07')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-07
# i: 1, k: 0, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 1, k: 1, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 1, k: 2, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 1, k: 3, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-10
# i: 1, k: 4, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 1, k: 5, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 1, k: 6, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-13
# i: 1, k: 7, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 1, k: 8, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 1, k: 9, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 1, k: 10, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 1, k: 11, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-18
# i: 1, k: 12, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-19
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-11-07
# ========================================================================================================================
#
# *** 검토대상블록: S19, 사이즈: (14, 7), 납기: 2023-11-15, 표준공기: 12, 최소착수요구일:2023-11-03
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 33, 최소착수요구일: 2023-11-03, 한계시점인덱스: 26, 한계시점날짜: 2023-10-27
# 0- 정반명: B, 블록면적: 98, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 295
# 0- 정반명: A, 블록면적: 98, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 98, 조회시점인덱스: 27, 조회시점날짜: 2023-10-28, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 98, 조회시점인덱스: 28, 조회시점날짜: 2023-10-29, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 3- 정반명: A, 블록면적: 98, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 4- 정반명: A, 블록면적: 98, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 5- 정반명: A, 블록면적: 98, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-03, 조회기간최소면적: 72
# 6- 정반명: A, 블록면적: 98, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-03, 조회기간최소면적: 184
# *** 최선조기착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-11-02 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-10-27')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-10-27
# i: 1, k: 0, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-27
# i: 1, k: 1, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-28
# i: 1, k: 2, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-29
# i: 1, k: 3, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-30
# i: 1, k: 4, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-31
# i: 1, k: 5, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-01
# i: 1, k: 6, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-02
# i: 1, k: 7, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 8, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 9, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 10, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 11, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-07
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-10-27
# ========================================================================================================================
#
# *** 검토대상블록: S16, 사이즈: (14, 5), 납기: 2023-11-14, 표준공기: 11, 최소착수요구일:2023-11-03
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 33, 최소착수요구일: 2023-11-03, 한계시점인덱스: 26, 한계시점날짜: 2023-10-27
# 0- 정반명: B, 블록면적: 70, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 197
# 0- 정반명: A, 블록면적: 70, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 70, 조회시점인덱스: 27, 조회시점날짜: 2023-10-28, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 70, 조회시점인덱스: 28, 조회시점날짜: 2023-10-29, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 3- 정반명: A, 블록면적: 70, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 4- 정반명: A, 블록면적: 70, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-03, 조회기간최소면적: 31
# 5- 정반명: A, 블록면적: 70, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-03, 조회기간최소면적: 72
# *** 최선조기착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-11-01 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-10-27')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-10-27
# i: 1, k: 0, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-27
# i: 1, k: 1, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-28
# i: 1, k: 2, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-29
# i: 1, k: 3, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-30
# i: 1, k: 4, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-10-31
# i: 1, k: 5, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-01
# i: 1, k: 6, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-02
# i: 1, k: 7, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 8, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 9, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 10, date_object: 2023-10-27 00:00:00, 레이아웃검토날짜: 2023-11-06
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-10-27
# ========================================================================================================================
#
# *** 검토대상블록: S25, 사이즈: (19, 13), 납기: 2023-11-21, 표준공기: 11, 최소착수요구일:2023-11-10
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 40, 최소착수요구일: 2023-11-10, 한계시점인덱스: 33, 한계시점날짜: 2023-11-03
# 0- 정반명: B, 블록면적: 247, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-10, 조회기간최소면적: 232
# 1- 정반명: B, 블록면적: 247, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-10, 조회기간최소면적: 232
# 2- 정반명: B, 블록면적: 247, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-10, 조회기간최소면적: 232
# 3- 정반명: B, 블록면적: 247, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-10, 조회기간최소면적: 232
# 4- 정반명: B, 블록면적: 247, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-10, 조회기간최소면적: 232
# 5- 정반명: B, 블록면적: 247, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-10, 조회기간최소면적: 330
# 0- 정반명: A, 블록면적: 247, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-10, 조회기간최소면적: 589
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-03')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-03
# i: 1, k: 0, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 1, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 2, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 3, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 4, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 1, k: 5, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 1, k: 6, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 1, k: 7, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-10
# i: 1, k: 8, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 1, k: 9, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 1, k: 10, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-13
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-11-03
# ========================================================================================================================
#
# *** 검토대상블록: S21, 사이즈: (17, 15), 납기: 2023-11-17, 표준공기: 8, 최소착수요구일:2023-11-09
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 39, 최소착수요구일: 2023-11-09, 한계시점인덱스: 32, 한계시점날짜: 2023-11-02
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-09, 조회기간최소면적: 127
# 1- 정반명: B, 블록면적: 255, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 2- 정반명: B, 블록면적: 255, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 3- 정반명: B, 블록면적: 255, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 4- 정반명: B, 블록면적: 255, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 5- 정반명: B, 블록면적: 255, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 6- 정반명: B, 블록면적: 255, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-09, 조회기간최소면적: 330
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-09, 조회기간최소면적: 184
# 1- 정반명: A, 블록면적: 255, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-09, 조회기간최소면적: 342
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-03')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-03
# i: 1, k: 0, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-03
# 1차검토 - Block S21 of height 17 width 15 could not be placed.
# 2차검토 - Block S21 of height 15 width 17 could not be placed.
# i: 1, k: 1, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-04
# 1차검토 - Block S21 of height 17 width 15 could not be placed.
# 2차검토 - Block S21 of height 15 width 17 could not be placed.
# i: 1, k: 2, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-05
# 1차검토 - Block S21 of height 17 width 15 could not be placed.
# 2차검토 - Block S21 of height 15 width 17 could not be placed.
# i: 1, k: 3, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 4, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 1, k: 5, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 1, k: 6, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 1, k: 7, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-10
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제2차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 39, 최소착수요구일: 2023-11-09, 한계시점인덱스: 32, 한계시점날짜: 2023-11-02
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 1- 정반명: B, 블록면적: 255, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 2- 정반명: B, 블록면적: 255, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 3- 정반명: B, 블록면적: 255, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 4- 정반명: B, 블록면적: 255, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 5- 정반명: B, 블록면적: 255, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-09, 조회기간최소면적: 330
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-09, 조회기간최소면적: 342
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-03')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-03
# i: 2, k: 0, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-04
# 1차검토 - Block S21 of height 17 width 15 could not be placed.
# 2차검토 - Block S21 of height 15 width 17 could not be placed.
# i: 2, k: 1, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-05
# 1차검토 - Block S21 of height 17 width 15 could not be placed.
# 2차검토 - Block S21 of height 15 width 17 could not be placed.
# i: 2, k: 2, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 2, k: 3, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 2, k: 4, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 2, k: 5, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 2, k: 6, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-10
# i: 2, k: 7, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-11
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제3차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 39, 최소착수요구일: 2023-11-09, 한계시점인덱스: 32, 한계시점날짜: 2023-11-02
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 1- 정반명: B, 블록면적: 255, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 2- 정반명: B, 블록면적: 255, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 3- 정반명: B, 블록면적: 255, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-09, 조회기간최소면적: 232
# 4- 정반명: B, 블록면적: 255, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-09, 조회기간최소면적: 330
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-09, 조회기간최소면적: 342
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-04 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-04')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-04
# i: 3, k: 0, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 3, k: 1, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-07
# i: 3, k: 2, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-08
# i: 3, k: 3, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-09
# i: 3, k: 4, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-10
# i: 3, k: 5, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 3, k: 6, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 3, k: 7, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-13
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-11-04
# ========================================================================================================================
#
# *** 검토대상블록: S17, 사이즈: (15, 13), 납기: 2023-11-14, 표준공기: 8, 최소착수요구일:2023-11-06
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 1- 정반명: B, 블록면적: 195, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 2- 정반명: B, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 3- 정반명: B, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 4- 정반명: B, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-06, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-06, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 72
# 3- 정반명: A, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 6- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 7- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-03')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-03
# i: 1, k: 0, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 1, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 2, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 3, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 4, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 1, k: 5, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 1, k: 6, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 1, k: 7, date_object: 2023-11-03 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제2차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 1- 정반명: B, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 2- 정반명: B, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 3- 정반명: B, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-06, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 72
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 6- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-03')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-03
# i: 2, k: 0, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 2, k: 1, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 2, k: 2, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 2, k: 3, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 2, k: 4, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 2, k: 5, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 2, k: 6, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 2, k: 7, date_object: 2023-11-04 00:00:00, 레이아웃검토날짜: 2023-11-11
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제3차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 1- 정반명: B, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 2- 정반명: B, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 72
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-03')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-03
# i: 3, k: 0, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 3, k: 1, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 3, k: 2, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 3, k: 3, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 3, k: 4, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 3, k: 5, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 3, k: 6, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 3, k: 7, date_object: 2023-11-05 00:00:00, 레이아웃검토날짜: 2023-11-12
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제4차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 1- 정반명: B, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-03')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-03
# i: 4, k: 0, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 4, k: 1, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 4, k: 2, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 4, k: 3, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 4, k: 4, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 4, k: 5, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 4, k: 6, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 4, k: 7, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-13
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제5차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-03')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-03
# i: 5, k: 0, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 5, k: 1, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 5, k: 2, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 5, k: 3, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 5, k: 4, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-11
# i: 5, k: 5, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 5, k: 6, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-13
# i: 5, k: 7, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-14
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제6차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 2- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-04 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-04')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-04
# i: 6, k: 0, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 6, k: 1, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 6, k: 2, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-11
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 6, k: 3, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 6, k: 4, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-13
# i: 6, k: 5, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 6, k: 6, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 6, k: 7, date_object: 2023-11-09 00:00:00, 레이아웃검토날짜: 2023-11-16
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제7차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 1- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-05 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-05')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-05
# i: 7, k: 0, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-11
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 7, k: 1, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-12
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 7, k: 2, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-13
# i: 7, k: 3, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 7, k: 4, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 7, k: 5, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 7, k: 6, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 7, k: 7, date_object: 2023-11-11 00:00:00, 레이아웃검토날짜: 2023-11-18
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제8차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-06')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-06
# i: 8, k: 0, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-13
# 1차검토 - Block S17 of height 15 width 13 could not be placed.
# 2차검토 - Block S17 of height 13 width 15 could not be placed.
# i: 8, k: 1, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 8, k: 2, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 8, k: 3, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 8, k: 4, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 8, k: 5, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-18
# i: 8, k: 6, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-19
# i: 8, k: 7, date_object: 2023-11-13 00:00:00, 레이아웃검토날짜: 2023-11-20
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제9차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 195, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-06, 조회기간최소면적: 232
# 0- 정반명: A, 블록면적: 195, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-06, 조회기간최소면적: 505
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-07 00:00:00'), 'A': Timestamp('2023-11-07 00:00:00')}
# *** 최선조기착수대상: (None, None)
# >>> 최선조기착수 후보날짜가 없습니다.
# ========================================================================================================================
#
# *** 검토대상블록: S32, 사이즈: (17, 15), 납기: 2023-11-27, 표준공기: 10, 최소착수요구일:2023-11-17
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 47, 최소착수요구일: 2023-11-17, 한계시점인덱스: 40, 한계시점날짜: 2023-11-10
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 40, 조회시점날짜: 2023-11-10, 최소착수요구일: 2023-11-17, 조회기간최소면적: 582
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 40, 조회시점날짜: 2023-11-10, 최소착수요구일: 2023-11-17, 조회기간최소면적: 674
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-10 00:00:00'), 'A': Timestamp('2023-11-10 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-10')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-10
# i: 1, k: 0, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 1, k: 1, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-11
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 1, k: 2, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-12
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 1, k: 3, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-13
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 1, k: 4, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 1, k: 5, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 1, k: 6, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 1, k: 7, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 1, k: 8, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-18
# i: 1, k: 9, date_object: 2023-11-10 00:00:00, 레이아웃검토날짜: 2023-11-19
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제2차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 47, 최소착수요구일: 2023-11-17, 한계시점인덱스: 40, 한계시점날짜: 2023-11-10
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 41, 조회시점날짜: 2023-11-11, 최소착수요구일: 2023-11-17, 조회기간최소면적: 582
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 41, 조회시점날짜: 2023-11-11, 최소착수요구일: 2023-11-17, 조회기간최소면적: 674
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-11 00:00:00'), 'A': Timestamp('2023-11-11 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-11')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-11
# i: 2, k: 0, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-12
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 2, k: 1, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-13
# 1차검토 - Block S32 of height 17 width 15 could not be placed.
# 2차검토 - Block S32 of height 15 width 17 could not be placed.
# i: 2, k: 2, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 2, k: 3, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 2, k: 4, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 2, k: 5, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 2, k: 6, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-18
# i: 2, k: 7, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-19
# i: 2, k: 8, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-20
# i: 2, k: 9, date_object: 2023-11-12 00:00:00, 레이아웃검토날짜: 2023-11-21
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제3차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 47, 최소착수요구일: 2023-11-17, 한계시점인덱스: 40, 한계시점날짜: 2023-11-10
# 0- 정반명: B, 블록면적: 255, 조회시점인덱스: 42, 조회시점날짜: 2023-11-12, 최소착수요구일: 2023-11-17, 조회기간최소면적: 582
# 0- 정반명: A, 블록면적: 255, 조회시점인덱스: 42, 조회시점날짜: 2023-11-12, 최소착수요구일: 2023-11-17, 조회기간최소면적: 929
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-12 00:00:00'), 'A': Timestamp('2023-11-12 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-11-12')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-11-12
# i: 3, k: 0, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-14
# i: 3, k: 1, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-15
# i: 3, k: 2, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-16
# i: 3, k: 3, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-17
# i: 3, k: 4, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-18
# i: 3, k: 5, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-19
# i: 3, k: 6, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-20
# i: 3, k: 7, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-21
# i: 3, k: 8, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-22
# i: 3, k: 9, date_object: 2023-11-14 00:00:00, 레이아웃검토날짜: 2023-11-23
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-11-12
# ========================================================================================================================
#
# *** 검토대상블록: S18, 사이즈: (14, 7), 납기: 2023-11-15, 표준공기: 9, 최소착수요구일:2023-11-06
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 36, 최소착수요구일: 2023-11-06, 한계시점인덱스: 29, 한계시점날짜: 2023-10-30
# 0- 정반명: B, 블록면적: 98, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-06, 조회기간최소면적: 127
# 0- 정반명: A, 블록면적: 98, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-06, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 98, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-06, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 98, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-06, 조회기간최소면적: 72
# 3- 정반명: A, 블록면적: 98, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 98, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 98, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 6- 정반명: A, 블록면적: 98, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-06, 조회기간최소면적: 87
# 7- 정반명: A, 블록면적: 98, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-06, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-10-30 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-10-30')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-10-30
# i: 1, k: 0, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-10-30
# i: 1, k: 1, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-10-31
# i: 1, k: 2, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-01
# i: 1, k: 3, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-02
# i: 1, k: 4, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-03
# i: 1, k: 5, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-04
# i: 1, k: 6, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-05
# i: 1, k: 7, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-06
# i: 1, k: 8, date_object: 2023-10-30 00:00:00, 레이아웃검토날짜: 2023-11-07
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-10-30
# ========================================================================================================================
#
# *** 검토대상블록: S14, 사이즈: (13, 13), 납기: 2023-11-09, 표준공기: 7, 최소착수요구일:2023-11-02
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 32, 최소착수요구일: 2023-11-02, 한계시점인덱스: 25, 한계시점날짜: 2023-10-26
# 0- 정반명: B, 블록면적: 169, 조회시점인덱스: 25, 조회시점날짜: 2023-10-26, 최소착수요구일: 2023-11-02, 조회기간최소면적: 201
# 0- 정반명: A, 블록면적: 169, 조회시점인덱스: 25, 조회시점날짜: 2023-10-26, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 169, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 169, 조회시점인덱스: 27, 조회시점날짜: 2023-10-28, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 3- 정반명: A, 블록면적: 169, 조회시점인덱스: 28, 조회시점날짜: 2023-10-29, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 4- 정반명: A, 블록면적: 169, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 5- 정반명: A, 블록면적: 169, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 6- 정반명: A, 블록면적: 169, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-02, 조회기간최소면적: 72
# 7- 정반명: A, 블록면적: 169, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 8- 정반명: A, 블록면적: 169, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 9- 정반명: A, 블록면적: 169, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 10- 정반명: A, 블록면적: 169, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 11- 정반명: A, 블록면적: 169, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-02, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-10-26 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('B', '2023-10-26')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2023-10-26
# i: 1, k: 0, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-26
# i: 1, k: 1, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-27
# i: 1, k: 2, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-28
# i: 1, k: 3, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-29
# i: 1, k: 4, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-30
# i: 1, k: 5, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-10-31
# i: 1, k: 6, date_object: 2023-10-26 00:00:00, 레이아웃검토날짜: 2023-11-01
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2023-10-26
# ========================================================================================================================
#
# *** 검토대상블록: S13, 사이즈: (15, 14), 납기: 2023-11-08, 표준공기: 6, 최소착수요구일:2023-11-02
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 32, 최소착수요구일: 2023-11-02, 한계시점인덱스: 25, 한계시점날짜: 2023-10-26
# 0- 정반명: B, 블록면적: 210, 조회시점인덱스: 25, 조회시점날짜: 2023-10-26, 최소착수요구일: 2023-11-02, 조회기간최소면적: 32
# 1- 정반명: B, 블록면적: 210, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-02, 조회기간최소면적: 32
# 2- 정반명: B, 블록면적: 210, 조회시점인덱스: 27, 조회시점날짜: 2023-10-28, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 3- 정반명: B, 블록면적: 210, 조회시점인덱스: 28, 조회시점날짜: 2023-10-29, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 4- 정반명: B, 블록면적: 210, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 5- 정반명: B, 블록면적: 210, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 6- 정반명: B, 블록면적: 210, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 7- 정반명: B, 블록면적: 210, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-02, 조회기간최소면적: 29
# 8- 정반명: B, 블록면적: 210, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-02, 조회기간최소면적: 134
# 9- 정반명: B, 블록면적: 210, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-02, 조회기간최소면적: 134
# 10- 정반명: B, 블록면적: 210, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-02, 조회기간최소면적: 134
# 11- 정반명: B, 블록면적: 210, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-02, 조회기간최소면적: 134
# 12- 정반명: B, 블록면적: 210, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-02, 조회기간최소면적: 134
# 13- 정반명: B, 블록면적: 210, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-02, 조회기간최소면적: 327
# 0- 정반명: A, 블록면적: 210, 조회시점인덱스: 25, 조회시점날짜: 2023-10-26, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 210, 조회시점인덱스: 26, 조회시점날짜: 2023-10-27, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 2- 정반명: A, 블록면적: 210, 조회시점인덱스: 27, 조회시점날짜: 2023-10-28, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 3- 정반명: A, 블록면적: 210, 조회시점인덱스: 28, 조회시점날짜: 2023-10-29, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 4- 정반명: A, 블록면적: 210, 조회시점인덱스: 29, 조회시점날짜: 2023-10-30, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 5- 정반명: A, 블록면적: 210, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-02, 조회기간최소면적: 31
# 6- 정반명: A, 블록면적: 210, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-02, 조회기간최소면적: 72
# 7- 정반명: A, 블록면적: 210, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 8- 정반명: A, 블록면적: 210, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 9- 정반명: A, 블록면적: 210, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 10- 정반명: A, 블록면적: 210, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-02, 조회기간최소면적: 87
# 11- 정반명: A, 블록면적: 210, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-02, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: (None, None)
# >>> 최선조기착수 후보날짜가 없습니다.
# ========================================================================================================================
#
# *** 검토대상블록: S20, 사이즈: (14, 13), 납기: 2023-11-15, 표준공기: 8, 최소착수요구일:2023-11-07
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 37, 최소착수요구일: 2023-11-07, 한계시점인덱스: 30, 한계시점날짜: 2023-10-31
# 0- 정반명: B, 블록면적: 182, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-07, 조회기간최소면적: 29
# 1- 정반명: B, 블록면적: 182, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-07, 조회기간최소면적: 29
# 2- 정반명: B, 블록면적: 182, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-07, 조회기간최소면적: 29
# 3- 정반명: B, 블록면적: 182, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 4- 정반명: B, 블록면적: 182, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 5- 정반명: B, 블록면적: 182, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 6- 정반명: B, 블록면적: 182, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 7- 정반명: B, 블록면적: 182, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 8- 정반명: B, 블록면적: 182, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-07, 조회기간최소면적: 327
# 0- 정반명: A, 블록면적: 182, 조회시점인덱스: 30, 조회시점날짜: 2023-10-31, 최소착수요구일: 2023-11-07, 조회기간최소면적: 31
# 1- 정반명: A, 블록면적: 182, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-07, 조회기간최소면적: 72
# 2- 정반명: A, 블록면적: 182, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 182, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 182, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 182, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 6- 정반명: A, 블록면적: 182, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-07, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-06')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-06
# i: 1, k: 0, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-06
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 1, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 2, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 3, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 4, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 5, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-11
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 1, k: 6, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-12
# i: 1, k: 7, date_object: 2023-11-06 00:00:00, 레이아웃검토날짜: 2023-11-13
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제2차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 37, 최소착수요구일: 2023-11-07, 한계시점인덱스: 30, 한계시점날짜: 2023-10-31
# 0- 정반명: B, 블록면적: 182, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-07, 조회기간최소면적: 29
# 1- 정반명: B, 블록면적: 182, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-07, 조회기간최소면적: 29
# 2- 정반명: B, 블록면적: 182, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 3- 정반명: B, 블록면적: 182, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 4- 정반명: B, 블록면적: 182, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 5- 정반명: B, 블록면적: 182, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 6- 정반명: B, 블록면적: 182, 조회시점인덱스: 37, 조회시점날짜: 2023-11-07, 최소착수요구일: 2023-11-07, 조회기간최소면적: 134
# 7- 정반명: B, 블록면적: 182, 조회시점인덱스: 38, 조회시점날짜: 2023-11-08, 최소착수요구일: 2023-11-07, 조회기간최소면적: 327
# 0- 정반명: A, 블록면적: 182, 조회시점인덱스: 31, 조회시점날짜: 2023-11-01, 최소착수요구일: 2023-11-07, 조회기간최소면적: 72
# 1- 정반명: A, 블록면적: 182, 조회시점인덱스: 32, 조회시점날짜: 2023-11-02, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 2- 정반명: A, 블록면적: 182, 조회시점인덱스: 33, 조회시점날짜: 2023-11-03, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 3- 정반명: A, 블록면적: 182, 조회시점인덱스: 34, 조회시점날짜: 2023-11-04, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 4- 정반명: A, 블록면적: 182, 조회시점인덱스: 35, 조회시점날짜: 2023-11-05, 최소착수요구일: 2023-11-07, 조회기간최소면적: 87
# 5- 정반명: A, 블록면적: 182, 조회시점인덱스: 36, 조회시점날짜: 2023-11-06, 최소착수요구일: 2023-11-07, 조회기간최소면적: 297
# *** 최선조기착수일후보: {'B': Timestamp('2023-11-08 00:00:00'), 'A': Timestamp('2023-11-06 00:00:00')}
# *** 최선조기착수대상: ('A', '2023-11-06')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2023-11-06
# i: 2, k: 0, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-07
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 2, k: 1, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-08
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 2, k: 2, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-09
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 2, k: 3, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-10
# 1차검토 - Block S20 of height 14 width 13 could not be placed.
# 2차검토 - Block S20 of height 13 width 14 could not be placed.
# i: 2, k: 4, date_object: 2023-11-07 00:00:00, 레이아웃검토날짜: 2023-11-11
# ...
# 2차검토 - Block S129 of height 12 width 16 could not be placed.
# i: 3, k: 3, date_object: 2024-03-09 00:00:00, 레이아웃검토날짜: 2024-03-12
# i: 3, k: 4, date_object: 2024-03-09 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 3, k: 5, date_object: 2024-03-09 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 3, k: 6, date_object: 2024-03-09 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 3, k: 7, date_object: 2024-03-09 00:00:00, 레이아웃검토날짜: 2024-03-16
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제4차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 162, 최소착수요구일: 2024-03-11, 한계시점인덱스: 155, 한계시점날짜: 2024-03-04
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 1- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 2- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 3- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 276
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-07 00:00:00')}
# *** 최선조기착수대상: ('A', '2024-03-07')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2024-03-07
# i: 4, k: 0, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-10
# 1차검토 - Block S129 of height 16 width 12 could not be placed.
# 2차검토 - Block S129 of height 12 width 16 could not be placed.
# i: 4, k: 1, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-11
# 1차검토 - Block S129 of height 16 width 12 could not be placed.
# 2차검토 - Block S129 of height 12 width 16 could not be placed.
# i: 4, k: 2, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-12
# i: 4, k: 3, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 4, k: 4, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 4, k: 5, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 4, k: 6, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-16
# i: 4, k: 7, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-17
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제5차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 162, 최소착수요구일: 2024-03-11, 한계시점인덱스: 155, 한계시점날짜: 2024-03-04
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 1- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 2- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 276
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-08 00:00:00')}
# *** 최선조기착수대상: ('A', '2024-03-08')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2024-03-08
# i: 5, k: 0, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-12
# i: 5, k: 1, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 5, k: 2, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 5, k: 3, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 5, k: 4, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-16
# i: 5, k: 5, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-17
# i: 5, k: 6, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-18
# i: 5, k: 7, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-19
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2024-03-08
# ========================================================================================================================
#
# *** 검토대상블록: S123, 사이즈: (16, 12), 납기: 2024-03-11, 표준공기: 7, 최소착수요구일:2024-03-04
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 155, 최소착수요구일: 2024-03-04, 한계시점인덱스: 148, 한계시점날짜: 2024-02-26
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 148, 조회시점날짜: 2024-02-26, 최소착수요구일: 2024-03-04, 조회기간최소면적: 475
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 148, 조회시점날짜: 2024-02-26, 최소착수요구일: 2024-03-04, 조회기간최소면적: 177
# 1- 정반명: A, 블록면적: 192, 조회시점인덱스: 149, 조회시점날짜: 2024-02-27, 최소착수요구일: 2024-03-04, 조회기간최소면적: 177
# 2- 정반명: A, 블록면적: 192, 조회시점인덱스: 150, 조회시점날짜: 2024-02-28, 최소착수요구일: 2024-03-04, 조회기간최소면적: 177
# 3- 정반명: A, 블록면적: 192, 조회시점인덱스: 151, 조회시점날짜: 2024-02-29, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 4- 정반명: A, 블록면적: 192, 조회시점인덱스: 152, 조회시점날짜: 2024-03-01, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 5- 정반명: A, 블록면적: 192, 조회시점인덱스: 153, 조회시점날짜: 2024-03-02, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 6- 정반명: A, 블록면적: 192, 조회시점인덱스: 154, 조회시점날짜: 2024-03-03, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 7- 정반명: A, 블록면적: 192, 조회시점인덱스: 155, 조회시점날짜: 2024-03-04, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 8- 정반명: A, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 9- 정반명: A, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 10- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 11- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 12- 정반명: A, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 13- 정반명: A, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-04, 조회기간최소면적: 369
# *** 최선조기착수일후보: {'B': Timestamp('2024-02-26 00:00:00'), 'A': Timestamp('2024-03-10 00:00:00')}
# *** 최선조기착수대상: ('B', '2024-02-26')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:
 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-04, 조회기간최소면적: 37
# 9- 정반명: B, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-04, 조회기간최소면적: 37
# 10- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-04, 조회기간최소면적: 37
# 11- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-04, 조회기간최소면적: 37
# 12- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-04, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 149, 조회시점날짜: 2024-02-27, 최소착수요구일: 2024-03-04, 조회기간최소면적: 177
# 1- 정반명: A, 블록면적: 192, 조회시점인덱스: 150, 조회시점날짜: 2024-02-28, 최소착수요구일: 2024-03-04, 조회기간최소면적: 177
# 2- 정반명: A, 블록면적: 192, 조회시점인덱스: 151, 조회시점날짜: 2024-02-29, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 3- 정반명: A, 블록면적: 192, 조회시점인덱스: 152, 조회시점날짜: 2024-03-01, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 4- 정반명: A, 블록면적: 192, 조회시점인덱스: 153, 조회시점날짜: 2024-03-02, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 5- 정반명: A, 블록면적: 192, 조회시점인덱스: 154, 조회시점날짜: 2024-03-03, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 6- 정반명: A, 블록면적: 192, 조회시점인덱스: 155, 조회시점날짜: 2024-03-04, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 7- 정반명: A, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 8- 정반명: A, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-04, 조회기간최소면적: 24
# 9- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 10- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 11- 정반명: A, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-04, 조회기간최소면적: 84
# 12- 정반명: A, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-04, 조회기간최소면적: 369
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-10 00:00:00')}
# *** 최선조기착수대상: (None, None)
# >>> 최선조기착수 후보날짜가 없습니다.
# ========================================================================================================================
#
# *** 검토대상블록: S131, 사이즈: (16, 12), 납기: 2024-03-18, 표준공기: 7, 최소착수요구일:2024-03-11
# *** 중량조건적합정반들: ['B', 'A']
# *** 최장길이조건적합정반들: ['B', 'A']
#
# >>> 제1차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 162, 최소착수요구일: 2024-03-11, 한계시점인덱스: 155, 한계시점날짜: 2024-03-04
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 155, 조회시점날짜: 2024-03-04, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 1- 정반명: B, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 2- 정반명: B, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 3- 정반명: B, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 4- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 5- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 6- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 155, 조회시점날짜: 2024-03-04, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 1- 정반명: A, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 2- 정반명: A, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 3- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 4- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 5- 정반명: A, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 6- 정반명: A, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 369
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-10 00:00:00')}
# *** 최선조기착수대상: ('B', '2024-03-10')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2024-03-10
# i: 1, k: 0, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-10
# 1차검토 - Block S122 of height 27 width 15 could not be placed.
# 2차검토 - Block S122 of height 15 width 27 could not be placed.
# 1차검토 - Block S131 of height 16 width 12 could not be placed.
# 2차검토 - Block S131 of height 12 width 16 could not be placed.
# i: 1, k: 1, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-11
# 1차검토 - Block S131 of height 16 width 12 could not be placed.
# 2차검토 - Block S131 of height 12 width 16 could not be placed.
# i: 1, k: 2, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-12
# 1차검토 - Block S131 of height 16 width 12 could not be placed.
# 2차검토 - Block S131 of height 12 width 16 could not be placed.
# i: 1, k: 3, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 1, k: 4, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 1, k: 5, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 1, k: 6, date_object: 2024-03-10 00:00:00, 레이아웃검토날짜: 2024-03-16
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제2차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 162, 최소착수요구일: 2024-03-11, 한계시점인덱스: 155, 한계시점날짜: 2024-03-04
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 1- 정반명: B, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 2- 정반명: B, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 3- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 4- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 5- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 156, 조회시점날짜: 2024-03-05, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 1- 정반명: A, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 2- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 3- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 4- 정반명: A, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 5- 정반명: A, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 369
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-10 00:00:00')}
# *** 최선조기착수대상: ('B', '2024-03-10')
# *** 랜덤선택 최선정반명:B, 최선조기착수일:2024-03-10
# i: 2, k: 0, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-11
# 1차검토 - Block S131 of height 16 width 12 could not be placed.
# 2차검토 - Block S131 of height 12 width 16 could not be placed.
# i: 2, k: 1, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-12
# 1차검토 - Block S131 of height 16 width 12 could not be placed.
# 2차검토 - Block S131 of height 12 width 16 could not be placed.
# i: 2, k: 2, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 2, k: 3, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 2, k: 4, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 2, k: 5, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-16
# i: 2, k: 6, date_object: 2024-03-11 00:00:00, 레이아웃검토날짜: 2024-03-17
# *** 레이아웃 적합도리스트 체크: 부적합
#
# >>> 제3차 레이아웃 적합도 검토
# *** 최소착수요구일달력인덱스: 162, 최소착수요구일: 2024-03-11, 한계시점인덱스: 155, 한계시점날짜: 2024-03-04
# 0- 정반명: B, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 1- 정반명: B, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 2- 정반명: B, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 3- 정반명: B, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 37
# 4- 정반명: B, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 289
# 0- 정반명: A, 블록면적: 192, 조회시점인덱스: 157, 조회시점날짜: 2024-03-06, 최소착수요구일: 2024-03-11, 조회기간최소면적: 24
# 1- 정반명: A, 블록면적: 192, 조회시점인덱스: 158, 조회시점날짜: 2024-03-07, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 2- 정반명: A, 블록면적: 192, 조회시점인덱스: 159, 조회시점날짜: 2024-03-08, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 3- 정반명: A, 블록면적: 192, 조회시점인덱스: 160, 조회시점날짜: 2024-03-09, 최소착수요구일: 2024-03-11, 조회기간최소면적: 84
# 4- 정반명: A, 블록면적: 192, 조회시점인덱스: 161, 조회시점날짜: 2024-03-10, 최소착수요구일: 2024-03-11, 조회기간최소면적: 369
# *** 최선조기착수일후보: {'B': Timestamp('2024-03-10 00:00:00'), 'A': Timestamp('2024-03-10 00:00:00')}
# *** 최선조기착수대상: ('A', '2024-03-10')
# *** 랜덤선택 최선정반명:A, 최선조기착수일:2024-03-10
# i: 3, k: 0, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-12
# i: 3, k: 1, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-13
# i: 3, k: 2, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-14
# i: 3, k: 3, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-15
# i: 3, k: 4, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-16
# i: 3, k: 5, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-17
# i: 3, k: 6, date_object: 2024-03-12 00:00:00, 레이아웃검토날짜: 2024-03-18
# *** 레이아웃 적합도리스트 체크: 적합
# *** 정상배치 완료, 착수일자: 2024-03-10
# ========================================================================================================================

# %%
결론_블록리스트 = 생산계획결과[0]
결론_정반리스트 = 생산계획결과[1]
결론_착수일자 = 생산계획결과[2]
결론_상태정보 = 생산계획결과[3]
면적달력 = 생산계획결과[4]
블록명달력 = 생산계획결과[5]
사이즈달력 = 생산계획결과[6]
print(f">>> 총블록개수: {len(결론_상태정보)}, 정상배치개수: {결론_상태정보.count('정상배치완료')}, 미배치개수: {len(결론_상태정보)-결론_상태정보.count('정상배치완료')}")
# Out:
# >>> 총블록개수: 123, 정상배치개수: 108, 미배치개수: 15

# %%
len(결론_상태정보), len(결론_블록리스트)
결론_블록리스트
결론_정반리스트
결론_착수일자
결론_상태정보
면적달력.head()
사이즈달력.head()
블록명달력
# Out:
# (123, 108)
# ['S15',
#  'S24',
#  'S33',
#  'S19',
#  'S16',
#  'S25',
#  'S21',
#  'S32',
#  'S18',
#  'S14',
#  'S20',
#  'S22',
#  'S23',
#  'S26',
#  'S36',
#  'S27',
#  'S35',
#  'S45',
#  'S49',
#  'S41',
#  'S34',
#  'S39',
#  'S46',
#  'S40',
#  'S47',
#  'S52',
#  'S38',
#  'S51',
#  'S50',
#  'S57',
#  'S67',
#  'S62',
#  'S30',
#  'S28',
#  'S29',
#  'S31',
#  'S43',
#  'S44',
#  'S37',
#  'S64',
#  'S63',
#  'S42',
#  'S58',
#  'S55',
#  'S59',
#  'S70',
#  'S56',
#  'S68',
#  'S65',
#  'S66',
#  'S69',
#  'S81',
#  'S82',
#  'S71',
#  'S86',
#  'S75',
#  'S74',
#  'S83',
#  'S73',
#  'S72',
#  'S94',
#  'S77',
#  'S97',
#  'S76',
#  'S80',
#  'S60',
#  'S105',
#  'S61',
#  'S84',
#  'S96',
#  'S99',
#  'S87',
#  'S78',
#  'S98',
#  'S79',
#  'S103',
#  'S102',
#  'S85',
#  'S89',
#  'S104',
#  'S95',
#  'S88',
#  'S93',
#  'S111',
#  'S92',
#  'S91',
#  'S108',
#  'S109',
#  'S107',
#  'S106',
#  'S119',
#  'S127',
#  'S126',
#  'S135',
#  'S134',
#  'S113',
#  'S124',
#  'S132',
#  'S110',
#  'S121',
#  'S101',
#  'S100',
#  'S125',
#  'S133',
#  'S122',
#  'S130',
#  'S129',
#  'S131']
# ['A',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'B',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'A',
#  'B',
#  'A',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'B',
#  'A',
#  'B',
#  'B',
#  'A',
#  'A',
#  'A']
# ['2023-10-27',
#  '2023-11-02',
#  '2023-11-07',
#  '2023-10-27',
#  '2023-10-27',
#  '2023-11-03',
#  '2023-11-04',
#  '2023-11-12',
#  '2023-10-30',
#  '2023-10-26',
#  '2023-11-06',
#  '2023-11-04',
#  '2023-11-06',
#  '2023-11-11',
#  '2023-11-15',
#  '2023-11-11',
#  '2023-11-18',
#  '2023-11-24',
#  '2023-11-30',
#  '2023-11-23',
#  '2023-11-18',
#  '2023-11-22',
#  '2023-11-29',
#  '2023-11-21',
#  '2023-11-30',
#  '2023-12-04',
#  '2023-11-20',
#  '2023-12-05',
#  '2023-12-05',
#  '2023-12-10',
#  '2023-12-14',
#  '2023-12-13',
#  '2023-11-16',
#  '2023-11-15',
#  '2023-11-15',
#  '2023-11-15',
#  '2023-11-27',
#  '2023-11-27',
#  '2023-11-23',
#  '2023-12-12',
#  '2023-12-12',
#  '2023-11-29',
#  '2023-12-13',
#  '2023-12-10',
#  '2023-12-16',
#  '2023-12-21',
#  '2023-12-18',
#  '2023-12-23',
#  '2023-12-23',
#  '2023-12-22',
#  '2023-12-23',
#  '2024-01-04',
#  '2024-01-04',
#  '2023-12-31',
#  '2024-01-11',
#  '2024-01-01',
#  '2024-01-04',
#  '2024-01-09',
#  '2024-01-01',
#  '2024-01-02',
#  '2024-01-18',
#  '2024-01-08',
#  '2024-01-19',
#  '2024-01-02',
#  '2024-01-12',
#  '2023-12-20',
#  '2024-01-26',
#  '2023-12-20',
#  '2024-01-11',
#  '2024-01-22',
#  '2024-01-23',
#  '2024-01-16',
#  '2024-01-07',
#  '2024-01-28',
#  '2024-01-13',
#  '2024-01-26',
#  '2024-02-03',
#  '2024-01-19',
#  '2024-01-17',
#  '2024-01-31',
#  '2024-02-04',
#  '2024-01-16',
#  '2024-01-23',
#  '2024-02-09',
#  '2024-01-20',
#  '2024-01-19',
#  '2024-02-09',
#  '2024-02-10',
#  '2024-02-10',
#  '2024-02-09',
#  '2024-02-17',
#  '2024-02-22',
#  '2024-02-22',
#  '2024-02-23',
#  '2024-02-26',
#  '2024-02-15',
#  '2024-02-29',
#  '2024-03-01',
#  '2024-02-11',
#  '2024-02-21',
#  '2024-02-06',
#  '2024-02-06',
#  '2024-03-02',
#  '2024-03-07',
#  '2024-03-04',
#  '2024-03-06',
#  '2024-03-08',
#  '2024-03-10']
# ['정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '정상배치완료',
#  '최선조기착수 후보날짜가 없음',
#  '정상배치완
# Out:
# (123, 14)

# %%
merged_df["상태정보"] = 결론_상태정보
merged_df.shape
# Out:
# (123, 15)

# %%
merged_df.to_csv("merged_df.csv", encoding="utf-8-sig")

# %%
merged_df1 = merged_df[["블록명", "사이즈", "정반명", "표준공기", "납기", "최소착수요구일", "착수일자", "상태정보"]]
merged_df1.to_csv("merged_df.csv", encoding="utf-8-sig")

# %%
@unpack_df_columns
def 종료일구하기(착수일자, 표준공기):
    try:
        original_date = datetime.strptime(착수일자, "%Y-%m-%d")
        종료날짜 = original_date + timedelta(days=int(표준공기)) 
        종료날짜 = 종료날짜.strftime("%Y-%m-%d")
        return 종료날짜
    except:
        pass

# %%
# @unpack_df_columns
# def create_text(블록명, 표준공기, 사이즈):
#     return str(블록명)+"/"+"조립중량:"+str(표준공기)+"ton" + "/" +"사이즈:"+str(사이즈)

# %%
@unpack_df_columns
def create_text(블록명, 납기, 최소착수요구일, 착수일자,  종료일자):
    납기 = 납기.date()
    return str(블록명)+"/"+"납기:"+str(납기)+"/" +"최소착수요구일:"+str(최소착수요구일)+"/"+"착수일자:"+str(착수일자)+"/"+"종료일자:"+str(종료일자)

# %%
merged_df["종료일자"] = merged_df[["착수일자", "표준공기"]].apply(종료일구하기, axis=1)
merged_df["차트텍스트"] = merged_df[["블록명", "납기", "최소착수요구일", "착수일자",  "종료일자"]].apply(create_text, axis=1)
merged_df
# Out:
#       블록명   중량  표준공기         납기       사이즈  최대길이   면적     최소착수요구일   날짜순서  \
# 0     S15  139    10 2023-11-13  (15, 14)    15  210  2023-11-03    4.0
# 1     S24   56    12 2023-11-21  (18, 14)    18  252  2023-11-09    9.5
# 2     S33   33    13 2023-11-27  (19, 15)    19  285  2023-11-14   14.5
# 3     S19   21    12 2023-11-15   (14, 7)    14   98  2023-11-03    4.0
# 4     S16   24    11 2023-11-14   (14, 5)    14   70  2023-11-03    4.0
# 5     S25   98    11 2023-11-21  (19, 13)    19  247  2023-11-10   12.0
# 6     S21   82     8 2023-11-17  (17, 15)    17  255  2023-11-09    9.5
# 7     S17   68     8 2023-11-14  (15, 13)    15  195  2023-11-06    6.5
# 8     S32   84    10 2023-11-27  (17, 15)    17  255  2023-11-17   17.0
# 9     S18   21     9 2023-11-15   (14, 7)    14   98  2023-11-06    6.5
# 10    S14   67     7 2023-11-09  (13, 13)    13  169  2023-11-02    1.5
# 11    S13  131     6 2023-11-08  (15, 14)    15  210  2023-11-02    1.5
# 12    S20   76     8 2023-11-15  (14, 13)    14  182  2023-11-07    8.0
# 13    S22   41    11 2023-11-21   (17, 5)    17   85  2023-11-10   12.0
# 14    S23   20    11 2023-11-21   (17, 5)    17   85  2023-11-10   12.0
# 15    S26   42     9 2023-11-23  (12, 11)    12  132  2023-11-14   14.5
# 16    S36   79     9 2023-12-01  (17, 15)    17  255  2023-11-22   21.5
# 17    S27  106     8 2023-11-23  (19, 13)    19  247  2023-11-15   16.0
# 18    S35   67     7 2023-11-29  (17, 15)    17  255  2023-11-22   21.5
# 111  S118/납기:2024-03-01/최소착수요구일:2024-02-23/착수일자:nan...
# 118  S117/납기:2024-03-01/최소착수요구일:2024-02-26/착수일자:nan...
# 121  S123/납기:2024-03-11/최소착수요구일:2024-03-04/착수일자:nan...

# %%
def draw_gant(df):
    fig = px.timeline(
        df, x_start="착수일자", x_end="종료일자", y="블록명",color="정반명", hover_data = ["표준공기", "중량"],
        text = "차트텍스트", opacity=0.7)
    fig.update_yaxes(autorange="reversed")          #if not specified as 'reversed', the tasks will be listed from bottom up       
    fig.update_layout(
                    hoverlabel_bgcolor='#DAEEED',   #Change the hover tooltip background color to a universal light blue color. If not specified, the background color will vary by team or completion pct, depending on what view the user chooses
                    bargap=0.2,
                    height=900,              
                    xaxis_title="", 
                    yaxis_title="블록명", 
                    font=dict(
                        family="Courier New, monospace",
                        size=12,  # Set the font size here
                        color="RebeccaPurple"),),
    fig.update_traces(marker_line_width=2, opacity = 1)
    fig.show()

# %%
draw_gant(merged_df)

# %% [markdown]
# # 결과정리 - 레이아웃 달력

# %%
def 정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
        
    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    배치레이아웃 = 배치결과[0]
    draw1(배치레이아웃, block_names)

# %%
조회날짜 = "2023-11-03"
정반배치레이아웃("A", 정반데이터, 조회날짜, 블록명달력, 사이즈달력)     
정반배치레이아웃("B", 정반데이터, 조회날짜, 블록명달력, 사이즈달력)

# %%
# 조회날짜리스트 = 면적달력.index[:5]
# 정반리스트 = 면적달력.columns.tolist()
# 조회날짜_iter = iter(조회날짜리스트)
# 정반리스트_iter = iter(정반리스트)

# try:
#     while True:
#         조회날짜 = next(조회날짜_iter)
#         for 정반명 in 면적달력.columns:
#             print(f"*** 정반명: {정반명}, 조회날짜: {조회날짜}")
#             정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)     
# except StopIteration:
#     print("end of iteration")

# %% [markdown]
# # 가중치 변경 시뮬레이션 (GridSearchCV 방식)

# %%
# data_num = "_과다조기착수금지"
# data_num = "_블록50개_정반1개"
# data_num = "_블록50개_정반3개"
# data_num = "_블록100개_정반1개"
# data_num = "_블록100개_정반6개"
data_num = "_블록130개_정반6개"
# data_num = "_블록130개_정반6개_납기5일후퇴"

# %%
블록원데이터 = pd.read_excel(f"./data/data{data_num}.xlsx", sheet_name="블록데이터")
# 블록원데이터 = 블록원데이터.iloc[4:,:]

정반원데이터 = pd.read_excel(f"./data/data{data_num}.xlsx", sheet_name="정반데이터")

블록데이터 = 블록데이터전처리(블록원데이터)
정반데이터 = 정반데이터전처리(정반원데이터)
블록데이터.shape, 정반데이터.shape

## Block Weight 후보들
착수일가중치들 = [1.0, 1.5, 2.0, 2.5, 3.0]
공기가중치들 = [0.9, 0.75, 0.5, 0.25, 0.1]
크기가중치들 = [0.1, 0.5, 0.9]

조기착수금지일수 = 7

배치결과모음 = []
가중치모음 = []

for _ in tqdm(range(3)):  #랜덤 00회 순환 검토
    
    # 블록가중치 랜덤 선택
    공기가중치 = choice(공기가중치들)
    크기가중치 = choice(크기가중치들)
    착수일가중치 = choice(착수일가중치들)
    
    가중치세트 = [착수일가중치, 공기가중치, 크기가중치]
    가중치모음.append(가중치세트)
    
    블록데이터 = 블록데이터전처리(블록원데이터)    

    시작년, 시작월, 시작일, 종료년, 종료월 = 2024, 1, 2, 2024, 4
    면적달력 = create_면적달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
    블록명달력 = create_블록명달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
    사이즈달력 = create_사이즈달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
        
    생산계획결과 = 생산계획수립(블록데이터, 정반데이터, 면적달력, 블록명달력, 사이즈달력, 조기착수금지일수)
    
    결론_블록리스트 = 생산계획결과[0]
    결론_정반리스트 = 생산계획결과[1]
    결론_착수일자 = 생산계획결과[2]
    결론_상태정보 = 생산계획결과[3]
    면적달력 = 생산계획결과[4]
    블록명달력 = 생산계획결과[5]
    사이즈달력 = 생산계획결과[6]

    print(f">>>>>>>> 총 블록 대수: {len(결론_상태정보)}")
    print(f">>>>>>>> 정상배치 블록 대수: {결론_상태정보.count('정상배치완료')}")
    print(f">>>>>>>> 배치못한 블록 대수: {len(결론_상태정보) - 결론_상태정보.count('정상배치완료')}")
    print("-"*70)
    
    fin_df = pd.DataFrame({
    "블록명":결론_블록리스트,
    "정반명":결론_정반리스트,
    "착수일자":결론_착수일자,
    })
    merged_df = pd.merge(블록데이터, fin_df, on="블록명", how="left")
    print(f"결론_상태정보: {결론_상태정보}")
    merged_df["상태정보"] = 결론_상태정보
    
    merged_df["종료일자"] = merged_df[["착수일자", "표준공기"]].apply(종료일구하기, axis=1)
    merged_df["차트텍스트"] = merged_df[["블록명", "납기", "최소착수요구일", "착수일자",  "종료일자"]].apply(create_text, axis=1)
    
    배치결과모음.append(merged_df)

# %%
for i in range(len(배치결과모음)):
    draw_gant(배치결과모음[i])

# %% [markdown]
# # 목적함수 체크

# %%
배치결과모음[0].info()

# %%
df3 = 배치결과모음[0]
df3[df3["상태정보"]!="정상배치완료"]

# %%
for i, 가중치세트 in enumerate(가중치모음):
    print(f">>> {int(i)+1}번째: 블록가중치 세트 --> {가중치세트} (착수일, 공기, 크기 순서)----------------------")
    t_df = 배치결과모음[i]
    t_df = t_df.dropna()
    t_df["종료년"] = t_df["종료일자"].apply(lambda x: x[0:4])
    t_df["종료월"] = t_df["종료일자"].apply(lambda x: x[5:7])
    g_df1 = t_df.groupby(["종료년", "종료월"]).agg({"블록명":'count', "중량":'sum'})
    g_df1.columns = ["블록개수", "총조립중량"]
    g_df1

# %%
# for i in range(len(공기가중치들)):
#     print(f">>> {int(i)+1}번째 에피소드 ----------------------")
#     t_df = 배치결과모음[i]
#     t_df = t_df.dropna()
#     t_df["종료월"] = t_df["종료일자"].apply(lambda x: x[5:7])
#     g_df1 = t_df.groupby(["종료월", "정반명"]).agg({"블록명":'count', "중량":'sum'})
#     g_df1.columns = ["블록개수", "총조립중량"]
#     g_df1
