# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from random import random, randrange, choice, shuffle
from datetime import datetime, timedelta, date
from itertools import combinations
from pprint import pprint
import calendar
import plotly.express as px
import time

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # Cell의 모든 반환값 출력

pd.set_option('display.max_rows', None)

import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# # 함수 정의

# %% [markdown]
# ## 블록데이터 전처리 함수

# %%
import functools
def unpack_df_columns(func):
    @functools.wraps(func)
    def _unpack_df_columns(*args, **kwargs):
        series = args[0]
        return func(*series.values)
    return _unpack_df_columns

@unpack_df_columns
def 최소착수요구일구하기(납기, 공기):
    result = pd.to_datetime(납기) - timedelta(days=int(공기))
    return result.date()

@unpack_df_columns
def 블록우선순위구하기(날짜순서, 공기순서, 크기순서):
    global 착수일가중치, 공기가중치, 크기가중치
    result = np.round((날짜순서*float(착수일가중치) + 공기순서*float(공기가중치) + 크기순서*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 블록사이즈튜플만들기(가로, 세로):
    길이2 = max(가로, 세로)  
    길이1 = min(가로, 세로)
    result = (길이2, 길이1)
    return result

def 블록데이터전처리(블록원데이터):
    df1 = 블록원데이터.copy()
    df1["blk_id"] = df1["블록명"].apply(lambda x: x[1:])
    df1["사이즈"] = df1[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
    df1["최대길이"] = df1["사이즈"].apply(lambda x: max(x))
    df1["납기"] = pd.to_datetime(df1["납기"])
    df1["면적"] = df1.eval("가로*세로")
    df1["최소착수요구일"] = df1[["납기", "표준공기"]].apply(최소착수요구일구하기, axis=1)
    df1["날짜순서"] = df1["최소착수요구일"].rank()
    df1["공기순서"] = df1["표준공기"].rank(ascending=False)
    df1["크기순서"] = df1["면적"].rank(ascending=False)
    df1["우선순위"] = df1[["날짜순서", "공기순서", "크기순서"]].apply(블록우선순위구하기, axis=1)
    
    df1 = df1.drop(['가로', '세로'], axis=1)
    df1 = df1.sort_values(by=["우선순위"])
    return df1

# %% [markdown]
# ## 정반데이터 전처리 함수

# %%
@unpack_df_columns
def 정반우선순위구하기(중순, 크순):
    global 중량가중치, 크기가중치
    result = np.round((중순*float(중량가중치) + 크순*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 정반사이즈튜플만들기(가로, 세로):
    길이1 = max(가로, 세로)  
    길이2 = min(가로, 세로)
    result = (길이1, 길이2)
    return result

def 정반데이터전처리(정반원데이터):
    df = 정반원데이터.copy()
    
    df["사이즈"] = df[["가로", "세로"]].apply(정반사이즈튜플만들기, axis=1)
    df["면적"] = df.eval("가로*세로")
    df["최대길이"] = df["사이즈"].apply(lambda x: max(x))
    df["중량순서"] = df["가능중량"].rank(ascending=False)
    df["크기순서"] = df["면적"].rank(ascending=False)
    df["우선순위"] = df[["중량순서", "크기순서"]].apply(정반우선순위구하기, axis=1)
    
    df = df.drop(['가로', '세로'], axis=1)
    df = df.sort_values(by=["우선순위"])
    return df

# %% [markdown]
# ## 물리조건 체크 함수 (중량, 최장길이)

# %%
def 중량조건체크(target_block):
    가능정반리스트 = []
    블록중량 = 블록데이터[블록데이터["블록명"]==target_block]["중량"].values[0]
    for 정반 in 정반데이터["정반명"]:
        정반가능중량 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반가능중량 > 블록중량:
            가능정반리스트.append(정반)       
    return 가능정반리스트  

def 최장길이체크(target_block:str, 중량가능정반들:list):
    가능정반리스트 = []
    블록최장길이 = 블록데이터[블록데이터["블록명"]==target_block]["최대길이"].values[0]
    for 정반 in 중량가능정반들:
        정반최장길이 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반최장길이 > 블록최장길이:
            가능정반리스트.append(정반)
    return 가능정반리스트

# %% [markdown]
# ## 레이아웃 함수

# %%
def init_jungban(사이즈):  #사이즈 = (10, 10)
    surface_width, surface_height = 사이즈[0], 사이즈[1]  # Adjusted to match the provided image for demonstration
    surface = np.zeros((surface_height, surface_width), dtype=int)
    return surface, surface_width, surface_height

def can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, start_row, start_col, thresh):
    new_width = surface_width - thresh
    new_height = surface_height - thresh
    
    if start_row + block_height > surface_height or start_col + block_width > surface_width:
        return False

    block_area = surface[start_row:start_row+block_height, start_col:start_col+block_width]
    if np.any(block_area != 0):
        return False
    
    if start_row > 0 and np.any(surface[start_row-thresh: start_row, start_col:start_col+block_width] != 0):
        return False
    if start_col > 0 and np.any(surface[start_row: start_row+block_height, start_col-thresh: start_col] != 0):
        return False
    
    return True

# Function to place a block on the surface, if possible
def place_block(surface, block_height, block_width, start_row, start_col, block_id):
    block_height, block_width = block_height, block_width
    surface[start_row:start_row + block_height, start_col:start_col + block_width] = block_id
    return surface


# def 레이아웃배치(surface, surface_width, surface_height, block_width, block_height, block_id, thresh):
def 레이아웃배치(surface, surface_width, surface_height, block_height, block_width, block_id, thresh):

    best_fit_score = float('inf')
    best_position = None
    
    for start_row in range(surface_height - block_height + 1):
        for start_col in range(surface_width - block_width + 1):
            if can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, start_row, start_col, thresh):
                # Calculate a score; here we use the top-left corner (y, x) as the score
                # A lower score means the block is closer to the top-left
                score = start_row + start_col
                if score < best_fit_score:
                    best_fit_score = score
                    best_position = (start_row, start_col)
    
    if best_position:
        surface = place_block(surface, block_height, block_width, *best_position, block_id)
        return True, surface
    else:
        return False, surface

def get_overlapped_surface(*arrays):
    result = arrays[0]
    for arr in arrays[1:]:
        result = np.add(result, arr)
    return result

# 특정 값만 남기고 다 지운후에 그 결과를 다시 각 해당일 surface에 더해준다...천재네..ㅋ
def extract_newblock_layout_only(overlapped_surface, block_id):
    mask = overlapped_surface != block_id
    overlapped_surface[mask] = 0
    newblock_layout = overlapped_surface
    return newblock_layout

# %%
# def draw_layout(레이아웃달력, 정반, idx):
#     target_date = 레이아웃달력.index[idx]
#     target_surface = 레이아웃달력.at[target_date, 정반]
#     fig, ax = plt.subplots(figsize=(8, 6))
#     plt.imshow(target_surface, cmap="Blues", interpolation='nearest')
    
#     for i in range(len(target_surface)):
#         for j in range(len(target_surface[0])):
#             plt.text(j, i, f'{target_surface[i, j]}', ha='center', va='center', color='white', fontsize=7)
#     # plt.colorbar()  # Add a color bar to show the mapping of values to colors
#     plt.show()

# %%
def draw_layout_subplots(레이아웃달력, 정반리스트, idx):
    정반1 = 정반리스트[0]
    정반2 = 정반리스트[1]
    
    target_date = 레이아웃달력.index[idx]
    target_surface1 = 레이아웃달력.at[target_date, 정반1]
    fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(12, 6))  # Create a figure with 2 subplots
    
    # Plot the first subplot
    ax = axs[0]
    ax.imshow(target_surface1, cmap="Blues", interpolation='nearest')
    for i in range(len(target_surface1)):
        for j in range(len(target_surface1[0])):
            ax.text(j, i, f'{target_surface1[i, j]}', ha='center', va='center', color='white', fontsize=6)
    ax.set_title(f'{정반1} - First Subplot')  # Set subplot title
    
    # Plot the second subplot
    target_surface2 = 레이아웃달력.at[target_date, 정반2]
    ax = axs[1]
    ax.imshow(target_surface2, cmap="Blues", interpolation='nearest')
    for i in range(len(target_surface2)):
        for j in range(len(target_surface2[0])):
            ax.text(j, i, f'{target_surface2[i, j]}', ha='center', va='center', color='white', fontsize=6)
    ax.set_title(f'{정반2} - Second Subplot')  # Set subplot title
    
    plt.tight_layout()  # Adjust subplot layout
    plt.show()

# %% [markdown]
# ## 레이아웃 달력

# %%
def get_end_date_of_month(year, month):
    # Get the number of days in the given month
    num_days = calendar.monthrange(year, month)[1]
    # Return the last day of the month as a datetime object
    return date(year, month, num_days)

def create_레이아웃달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터:pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        정반사이즈 = 정반데이터[정반데이터["정반명"]==정반]["사이즈"].values[0]
        # print(f"{정반}정반사이즈: {정반사이즈}")
        surface, surface_width, surface_height = init_jungban(정반사이즈)
        달력[정반] = [surface for _ in range(len(날짜집합))]
        
    return 달력

# %%
def update_레이아웃달력(레이아웃달력, 정반명, 블록명, 정반데이터, 블록데이터):
    # 변수정리
    조기착수금지일 = 7    # 자재준비기간 고려한 최대조기착수 한계일수
    thresh = 1   # 블록사이간격 (작업성고려 최소 1미터)
    최소착수요구일 = 블록데이터[블록데이터["블록명"]==블록명]["최소착수요구일"].values[0]
    표준공기 = int(블록데이터[블록데이터["블록명"]==블록명]["표준공기"].values[0])
    blk_id = 블록데이터[블록데이터["블록명"]==블록명]["blk_id"].values[0]
    블록사이즈 = 블록데이터[블록데이터["블록명"]==블록명]["사이즈"].values[0]
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    surface_width, surface_height = 정반사이즈[0], 정반사이즈[1]
    block_width, block_height = 블록사이즈[0], 블록사이즈[1]
    
    날짜리스트 = [d.strftime("%Y-%m-%d") for d in 레이아웃달력.index]
    start_date = 최소착수요구일 # datetime.strptime(최소착수요구일, "%Y-%m-%d").date()
    min_start_date = start_date - timedelta(days=조기착수금지일)
    
    end_date = min_start_date + timedelta(days=표준공기)
    min_start_date= min_start_date.strftime('%Y-%m-%d')
    end_date = end_date.strftime('%Y-%m-%d')
    min_start_idx = 날짜리스트.index(min_start_date)
    end_idx = 날짜리스트.index(end_date)
    
    # 레이아웃 순환 검토 
    # 후퇴배수 = int(표준공기 * 1)   # 최선조기착수일 인덱스에서 표준공기의 최대 00배수까지 후퇴 검토
    후퇴배수 = 14 # 그냥 숫자로 한정하기
    for k in range(후퇴배수):  
        min_start_idx += 1
        end_idx += 1
        print(f">>>>> 검토차수{k} / {레이아웃달력.index[min_start_idx]}: {min_start_idx} ~ {end_idx}")
    
        target_surfaces = []
        temp_dates = []
        for idx in range(min_start_idx, end_idx+1): # 표준공기에 해당하는 시기인덱스~종기인덱스 순환 검토
            target_date = 레이아웃달력.index[idx]    # 대상인덱스의 날짜 불러오기
            temp_dates.append(target_date)
            target_surface = 레이아웃달력.at[target_date, 정반명]  # 조회날짜의 레이아웃(서페이스) 불러오기
            target_surfaces.append(target_surface)   # 조회날짜의 레이아웃들을 리스트로 담기
                
        overlapped_surface = get_overlapped_surface(*target_surfaces)  # 리스트에 담은 레이아웃을 합하여 오버랩 레이아웃 생성
        
        bool_res, surface = 레이아웃배치(overlapped_surface, surface_width, surface_height, block_width, block_height, blk_id, thresh)  # 오버랩 레이아웃에 신규 블록 레이아웃 배치검토
        
        if bool_res:  # 신규블록이 배치되어 True라면...
            newblock_layout = extract_newblock_layout_only(surface, int(blk_id))  # 신규배치블록의 레이아웃만 추출 (기배치 다른 블록 레이아웃 제거)
            
            for idx in range(min_start_idx, end_idx+1):   # 조회기간 다시 탐색 (레이아웃 업데이트를 위해)
                target_date = 레이아웃달력.index[idx]  
                target_surface = 레이아웃달력.at[target_date, 정반명]    # 조회일의 레이아웃 불러오기
                target_surface = target_surface + newblock_layout        # 조회일의 레이아웃에 새블록 레이아웃 더하여 내용 합치기
                레이아웃달력.at[target_date, 정반명] = target_surface   # 해당일의 레이아웃을 새레이아웃으로 변경하기 (업데이트 완료)
            
            최선배치일 = temp_dates[0].strftime('%Y-%m-%d')
            최선정반 = 정반명
            break

        else:
            # 가로세로 바꿔서
            bool_res, surface = 레이아웃배치(overlapped_surface, surface_width, surface_height, block_height, block_width, blk_id, thresh)  

            if bool_res:
                newblock_layout = extract_newblock_layout_only(surface, int(blk_id))  # 신규배치블록의 레이아웃만 추출 (기배치 다른 블록 레이아웃 제거)
            
                for idx in range(min_start_idx, end_idx+1):   # 조회기간 다시 탐색 (레이아웃 업데이트를 위해)
                    target_date = 레이아웃달력.index[idx]  
                    target_surface = 레이아웃달력.at[target_date, 정반명]    # 조회일의 레이아웃 불러오기
                    target_surface = target_surface + newblock_layout        # 조회일의 레이아웃에 새블록 레이아웃 더하여 내용 합치기
                    레이아웃달력.at[target_date, 정반명] = target_surface   # 해당일의 레이아웃을 새레이아웃으로 변경하기 (업데이트 완료)
            
                최선배치일 = temp_dates[0].strftime('%Y-%m-%d')
                최선정반 = 정반명
                break

            else:  # 신규블록 배치가 False라면.. 계속 순환
                최선배치일 = None
                최선정반 = None
        
        
    return 레이아웃달력, 최선정반, 최선배치일

# %%
# 레이아웃달력 = create_레이아웃달력(2024, 2, 1, 2024, 4, 정반데이터)
# 대상정반 = "A"
# 정반사이즈 = (42, 28)
# 최소착수요구일 = "2024-02-10"
# 조기착수금지일 = 7
# 표준공기 = 3
# 레이아웃달력 = 레이아웃달력
# 블록사이즈 = (20, 20)
# blk_id = 1
# thresh = 1 # 블록최소간격

# surface_width, surface_height = 정반사이즈[0], 정반사이즈[1]
# block_width, block_height = 블록사이즈[0], 블록사이즈[1]

# 날짜리스트 = [d.strftime("%Y-%m-%d") for d in 레이아웃달력.index]
# start_date = datetime.strptime(최소착수요구일, "%Y-%m-%d").date()
# min_start_date = start_date - timedelta(days=조기착수금지일)

# end_date = min_start_date + timedelta(days=표준공기)
# min_start_date= min_start_date.strftime('%Y-%m-%d')
# end_date = end_date.strftime('%Y-%m-%d')
# min_start_idx = 날짜리스트.index(min_start_date)
# end_idx = 날짜리스트.index(end_date)
# min_start_date, min_start_idx, end_idx

# %%
# for k in range(표준공기*3):
#     min_start_idx += k
#     end_idx += k
#     print(f">>> 검토차수{k}: {min_start_idx} ~ {end_idx}")

#     target_surfaces = []
#     temp_dates = []
#     for idx in range(min_start_idx, end_idx+1):
#         target_date = 레이아웃달력.index[idx]
#         temp_dates.append(target_date)
#         target_surface = 레이아웃달력.at[target_date, 대상정반]
#         target_surfaces.append(target_surface)

#     overlapped_surface = get_overlapped_surface(*target_surfaces)
#     bool_res, surface = 레이아웃배치(overlapped_surface, surface_width, surface_height, block_width, block_height, blk_id, thresh)
    
#     if bool_res:
#         print(">>> 조회기간 레이아웃 배치가능")
#         newblock_layout = extract_newblock_layout_only(surface, blk_id)

#         for idx in range(min_start_idx, end_idx+1):
#             target_date = 레이아웃달력.index[idx]
#             target_surface = 레이아웃달력.at[target_date, 대상정반]
#             target_surface = target_surface + newblock_layout
#             레이아웃달력.at[target_date, 대상정반] = target_surface
#             print(idx, len(target_surface))      
#         break
#     else:
#         print(">>> 다음차수검토")
# 레이아웃달력.head(8)

# %% [markdown]
# # 시뮬레이션

# %%
data_num = "_실행계획"
블록원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="블록데이터")
기배치블록 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="기배치블록")
기배치블록.rename(columns={'공기':'표준공기'}, inplace=True)
기배치블록["blk_id"] = 기배치블록["블록명"].apply(lambda x: x[1:])
정반원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="정반데이터")

기배치블록1 =기배치블록[["블록명", "중량", "가로", "세로", "표준공기", "종료일"]]
기배치블록1.rename(columns={'종료일':'납기'}, inplace=True)
블록마스터 = pd.concat([기배치블록1, 블록원데이터])

검토개수 = 115
블록원데이터 = 블록원데이터.iloc[:검토개수,:]
블록원데이터.shape

착수일가중치, 공기가중치, 크기가중치 = 10, 1, 0.1
블록데이터 = 블록데이터전처리(블록원데이터)

중량가중치, 크기가중치 = 0.5, 0.5
정반데이터 = 정반데이터전처리(정반원데이터)
블록마스터.shape, 기배치블록.shape, 블록데이터.shape, 정반데이터.shape
# Out:
# (115, 6)
# ((135, 6), (12, 9), (115, 13), (2, 8))

# %%
시작년, 시작월, 시작일, 종료년, 종료월 = 2023, 10, 1, 2024, 5
레이아웃달력 = create_레이아웃달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)

블록리스트 = 블록데이터["블록명"].tolist()
정반리스트 = 정반데이터["정반명"].tolist()

배치정반모음 = []
배치일모음 = []

# print(블록리스트)
for _ in tqdm(range(len(블록리스트))):
    target_block = 블록리스트[0]
    print()
    print(f"***** 검토대상블록: {target_block} ---------------------------------------------")

    # 물리조건 체크
    가능정반들 = 중량조건체크(target_block)
    가능정반들 = 최장길이체크(target_block, 가능정반들)

    최선정반 = choice(가능정반들)
    print(f">>>>> 물리조건가능정반들: {가능정반들}, 최선정반(현재는 완전 랜덤 선택): {최선정반}")

    레이아웃달력, 최선정반, 최종배치일 = update_레이아웃달력(레이아웃달력, 최선정반, target_block, 정반데이터, 블록데이터)
    배치정반모음.append(최선정반)
    배치일모음.append(최종배치일)
    print(f">>>>> 블록명:{target_block}, 최선정반: {최선정반}, 최종배치일:{최종배치일}")
    블록리스트.remove(target_block)

배치후데이터 = 블록데이터.copy()
배치후데이터["배치정반"] = 배치정반모음
배치후데이터["착수일자"] = 배치일모음
배치후데이터['최소착수요구일'] = pd.to_datetime(배치후데이터['최소착수요구일'])
배치후데이터['착수일자'] = pd.to_datetime(배치후데이터['착수일자'])
배치후데이터["델타"] = 배치후데이터['착수일자'] - 배치후데이터['최소착수요구일']
배치후데이터["델타"] = 배치후데이터["델타"].dt.days
배치후데이터.to_csv("./results/배치결과.csv", encoding='utf-8-sig')
# Out:
#   0%|          | 0/115 [00:00<?, ?it/s]
# ***** 검토대상블록: S19 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-10-28 00:00:00: 27 ~ 39
# >>>>> 블록명:S19, 최선정반: A, 최종배치일:2023-10-28
#
# ***** 검토대상블록: S16 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-10-28 00:00:00: 27 ~ 38
# >>>>> 블록명:S16, 최선정반: A, 최종배치일:2023-10-28
#
# ***** 검토대상블록: S15 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-10-28 00:00:00: 27 ~ 37
# >>>>> 블록명:S15, 최선정반: A, 최종배치일:2023-10-28
#
# ***** 검토대상블록: S14 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-10-27 00:00:00: 26 ~ 33
# >>>>> 블록명:S14, 최선정반: B, 최종배치일:2023-10-27
#
# ***** 검토대상블록: S24 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-03 00:00:00: 33 ~ 45
# >>>>> 검토차수1 / 2023-11-04 00:00:00: 34 ~ 46
# >>>>> 검토차수2 / 2023-11-05 00:00:00: 35 ~ 47
# >>>>> 검토차수3 / 2023-11-06 00:00:00: 36 ~ 48
# >>>>> 검토차수4 / 2023-11-07 00:00:00: 37 ~ 49
# >>>>> 검토차수5 / 2023-11-08 00:00:00: 38 ~ 50
# >>>>> 블록명:S24, 최선정반: A, 최종배치일:2023-11-08
#
# ***** 검토대상블록: S13 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-10-27 00:00:00: 26 ~ 32
# >>>>> 블록명:S13, 최선정반: B, 최종배치일:2023-10-27
#
# ***** 검토대상블록: S18 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-10-31 00:00:00: 30 ~ 39
# >>>>> 블록명:S18, 최선정반: B, 최종배치일:2023-10-31
#
# ***** 검토대상블록: S17 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-10-31 00:00:00: 30 ~ 38
# >>>>> 블록명:S17, 최선정반: A, 최종배치일:2023-10-31
#
# ***** 검토대상블록: S20 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-01 00:00:00: 31 ~ 39
# >>>>> 블록명:S20, 최선정반: A, 최종배치일:2023-11-01
#
# ***** 검토대상블록: S25 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-04 00:00:00: 34 ~ 45
# >>>>> 검토차수1 / 2023-11-05 00:00:00: 35 ~ 46
# >>>>> 검토차수2 / 2023-11-06 00:00:00: 36 ~ 47
# >>>>> 검토차수3 / 2023-11-07 00:00:00: 37 ~ 48
# >>>>> 검토차수4 / 2023-11-08 00:00:00: 38 ~ 49
# >>>>> 검토차수5 / 2023-11-09 00:00:00: 39 ~ 50
# >>>>> 블록명:S25, 최선정반: A, 최종배치일:2023-11-09
#
# ***** 검토대상블록: S33 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-08 00:00:00: 38 ~ 51
# >>>>> 검토차수1 / 2023-11-09 00:00:00: 39 ~ 52
# >>>>> 검토차수2 / 2023-11-10 00:00:00: 40 ~ 53
# >>>>> 검토차수3 / 2023-11-11 00:00:00: 41 ~ 54
# >>>>> 검토차수4 / 2023-11-12 00:00:00: 42 ~ 55
# >>>>> 검토차수5 / 2023-11-13 00:00:00: 43 ~ 56
# >>>>> 검토차수6 / 2023-11-14 00:00:00: 44 ~ 57
# >>>>> 검토차수7 / 2023-11-15 00:00:00: 45 ~ 58
# >>>>> 검토차수8 / 2023-11-16 00:00:00: 46 ~ 59
# >>>>> 검토차수9 / 2023-11-17 00:00:00: 47 ~ 60
# >>>>> 검토차수10 / 2023-11-18 00:00:00: 48 ~ 61
# >>>>> 검토차수11 / 2023-11-19 00:00:00: 49 ~ 62
# >>>>> 검토차수12 / 2023-11-20 00:00:00: 50 ~ 63
# >>>>> 검토차수13 / 2023-11-21 00:00:00: 51 ~ 64
# >>>>> 블록명:S33, 최선정반: A, 최종배치일:2023-11-21
#
# ***** 검토대상블록: S23 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-04 00:00:00: 34 ~ 45
# >>>>> 블록명:S23, 최선정반: B, 최종배치일:2023-11-04
#
# ***** 검토대상블록: S22 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-04 00:00:00: 34 ~ 45
# >>>>> 블록명:S22, 최선정반: A, 최종배치일:2023-11-04
#
# ***** 검토대상블록: S21 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-03 00:00:00: 33 ~ 41
# >>>>> 검토차수1 / 2023-11-04 00:00:00: 34 ~ 42
# >>>>> 검토차수2 / 2023-11-05 00:00:00: 35 ~ 43
# >>>>> 검토차수3 / 2023-11-06 00:00:00: 36 ~ 44
# >>>>> 검토차수4 / 2023-11-07 00:00:00: 37 ~ 45
# >>>>> 검토차수5 / 2023-11-08 00:00:00: 38 ~ 46
# >>>>> 검토차수6 / 2023-11-09 00:00:00: 39 ~ 47
# >>>>> 검토차수7 / 2023-11-10 00:00:00: 40 ~ 48
# >>>>> 검토차수8 / 2023-11-11 00:00:00: 41 ~ 49
# >>>>> 검토차수9 / 2023-11-12 00:00:00: 42 ~ 50
# >>>>> 검토차수10 / 2023-11-13 00:00:00: 43 ~ 51
# >>>>> 검토차수11 / 2023-11-14 00:00:00: 44 ~ 52
# >>>>> 검토차수12 / 2023-11-15 00:00:00: 45 ~ 53
# >>>>> 검토차수13 / 2023-11-16 00:00:00: 46 ~ 54
# >>>>> 블록명:S21, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S26 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-08 00:00:00: 38 ~ 47
# >>>>> 검토차수1 / 2023-11-09 00:00:00: 39 ~ 48
# >>>>> 검토차수2 / 2023-11-10 00:00:00: 40 ~ 49
# >>>>> 블록명:S26, 최선정반: A, 최종배치일:2023-11-10
#
# ***** 검토대상블록: S32 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-11 00:00:00: 41 ~ 51
# >>>>> 검토차수1 / 2023-11-12 00:00:00: 42 ~ 52
# >>>>> 검토차수2 / 2023-11-13 00:00:00: 43 ~ 53
# >>>>> 검토차수3 / 2023-11-14 00:00:00: 44 ~ 54
# >>>>> 검토차수4 / 2023-11-15 00:00:00: 45 ~ 55
# >>>>> 검토차수5 / 2023-11-16 00:00:00: 46 ~ 56
# >>>>> 검토차수6 / 2023-11-17 00:00:00: 47 ~ 57
# >>>>> 검토차수7 / 2023-11-18 00:00:00: 48 ~ 58
# >>>>> 검토차수8 / 2023-11-19 00:00:00: 49 ~ 59
# >>>>> 검토차수9 / 2023-11-20 00:00:00: 50 ~ 60
# >>>>> 검토차수10 / 2023-11-21 00:00:00: 51 ~ 61
# >>>>> 블록명:S32, 최선정반: A, 최종배치일:2023-11-21
#
# ***** 검토대상블록: S27 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-09 00:00:00: 39 ~ 47
# >>>>> 블록명:S27, 최선정반: B, 최종배치일:2023-11-09
#
# ***** 검토대상블록: S36 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 55
# >>>>> 검토차수1 / 2023-11-17 00:00:00: 47 ~ 56
# >>>>> 검토차수2 / 2023-11-18 00:00:00: 48 ~ 57
# >>>>> 블록명:S36, 최선정반: B, 최종배치일:2023-11-18
#
# ***** 검토대상블록: S34 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-14 00:00:00: 44 ~ 51
# >>>>> 블록명:S34, 최선정반: B, 최종배치일:2023-11-14
#
# ***** 검토대상블록: S35 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 53
# >>>>> 검토차수1 / 2023-11-17 00:00:00: 47 ~ 54
# >>>>> 검토차수2 / 2023-11-18 00:00:00: 48 ~ 55
# >>>>> 검토차수3 / 2023-11-19 00:00:00: 49 ~ 56
# >>>>> 검토차수4 / 2023-11-20 00:00:00: 50 ~ 57
# >>>>> 검토차수5 / 2023-11-21 00:00:00: 51 ~ 58
# >>>>> 검토차수6 / 2023-11-22 00:00:00: 52 ~ 59
# >>>>> 검토차수7 / 2023-11-23 00:00:00: 53 ~ 60
# >>>>> 검토차수8 / 2023-11-24 00:00:00: 54 ~ 61
# >>>>> 검토차수9 / 2023-11-25 00:00:00: 55 ~ 62
# >>>>> 검토차수10 / 2023-11-26 00:00:00: 56 ~ 63
# >>>>> 검토차수11 / 2023-11-27 00:00:00: 57 ~ 64
# >>>>> 검토차수12 / 2023-11-28 00:00:00: 58 ~ 65
# >>>>> 검토차수13 / 2023-11-29 00:00:00: 59 ~ 66
# >>>>> 블록명:S35, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S40 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-22 00:00:00: 52 ~ 61
# >>>>> 블록명:S40, 최선정반: B, 최종배치일:2023-11-22
#
# ***** 검토대상블록: S28 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 51
# >>>>> 블록명:S28, 최선정반: B, 최종배치일:2023-11-16
#
# ***** 검토대상블록: S30 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 51
# >>>>> 블록명:S30, 최선정반: B, 최종배치일:2023-11-16
#
# ***** 검토대상블록: S29 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 51
# >>>>> 블록명:S29, 최선정반: A, 최종배치일:2023-11-16
#
# ***** 검토대상블록: S31 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-16 00:00:00: 46 ~ 51
# >>>>> 블록명:S31, 최선정반: B, 최종배치일:2023-11-16
#
# ***** 검토대상블록: S45 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-25 00:00:00: 55 ~ 66
# >>>>> 블록명:S45, 최선정반: B, 최종배치일:2023-11-25
#
# ***** 검토대상블록: S39 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-22 00:00:00: 52 ~ 60
# >>>>> 검토차수1 / 2023-11-23 00:00:00: 53 ~ 61
# >>>>> 검토차수2 / 2023-11-24 00:00:00: 54 ~ 62
# >>>>> 검토차수3 / 2023-11-25 00:00:00: 55 ~ 63
# >>>>> 검토차수4 / 2023-11-26 00:00:00: 56 ~ 64
# >>>>> 검토차수5 / 2023-11-27 00:00:00: 57 ~ 65
# >>>>> 검토차수6 / 2023-11-28 00:00:00: 58 ~ 66
# >>>>> 블록명:S39, 최선정반: B, 최종배치일:2023-11-28
#
# ***** 검토대상블록: S41 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-23 00:00:00: 53 ~ 62
# >>>>> 검토차수1 / 2023-11-24 00:00:00: 54 ~ 63
# >>>>> 검토차수2 / 2023-11-25 00:00:00: 55 ~ 64
# >>>>> 검토차수3 / 2023-11-26 00:00:00: 56 ~ 65
# >>>>> 검토차수4 / 2023-11-27 00:00:00: 57 ~ 66
# >>>>> 검토차수5 / 2023-11-28 00:00:00: 58 ~ 67
# >>>>> 블록명:S41, 최선정반: B, 최종배치일:2023-11-28
#
# ***** 검토대상블록: S38 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-21 00:00:00: 51 ~ 58
# >>>>> 블록명:S38, 최선정반: A, 최종배치일:2023-11-21
#
# ***** 검토대상블록: S46 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-30 00:00:00: 60 ~ 72
# >>>>> 블록명:S46, 최선정반: A, 최종배치일:2023-11-30
#
# ***** 검토대상블록: S49 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-01 00:00:00: 61 ~ 73
# >>>>> 검토차수1 / 2023-12-02 00:00:00: 62 ~ 74
# >>>>> 검토차수2 / 2023-12-03 00:00:00: 63 ~ 75
# >>>>> 검토차수3 / 2023-12-04 00:00:00: 64 ~ 76
# >>>>> 검토차수4 / 2023-12-05 00:00:00: 65 ~ 77
# >>>>> 검토차수5 / 2023-12-06 00:00:00: 66 ~ 78
# >>>>> 검토차수6 / 2023-12-07 00:00:00: 67 ~ 79
# >>>>> 블록명:S49, 최선정반: B, 최종배치일:2023-12-07
#
# ***** 검토대상블록: S37 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-22 00:00:00: 52 ~ 58
# >>>>> 블록명:S37, 최선정반: B, 최종배치일:2023-11-22
#
# ***** 검토대상블록: S47 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-01 00:00:00: 61 ~ 72
# >>>>> 블록명:S47, 최선정반: B, 최종배치일:2023-12-01
#
# ***** 검토대상블록: S43 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-28 00:00:00: 58 ~ 66
# >>>>> 블록명:S43, 최선정반: A, 최종배치일:2023-11-28
#
# ***** 검토대상블록: S44 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-11-28 00:00:00: 58 ~ 66
# >>>>> 블록명:S44, 최선정반: A, 최종배치일:2023-11-28
#
# ***** 검토대상블록: S52 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-05 00:00:00: 65 ~ 74
# >>>>> 블록명:S52, 최선정반: A, 최종배치일:2023-12-05
#
# ***** 검토대상블록: S42 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-11-28 00:00:00: 58 ~ 62
# >>>>> 검토차수1 / 2023-11-29 00:00:00: 59 ~ 63
# >>>>> 검토차수2 / 2023-11-30 00:00:00: 60 ~ 64
# >>>>> 검토차수3 / 2023-12-01 00:00:00: 61 ~ 65
# >>>>> 검토차수4 / 2023-12-02 00:00:00: 62 ~ 66
# >>>>> 검토차수5 / 2023-12-03 00:00:00: 63 ~ 67
# >>>>> 검토차수6 / 2023-12-04 00:00:00: 64 ~ 68
# >>>>> 검토차수7 / 2023-12-05 00:00:00: 65 ~ 69
# >>>>> 검토차수8 / 2023-12-06 00:00:00: 66 ~ 70
# >>>>> 검토차수9 / 2023-12-07 00:00:00: 67 ~ 71
# >>>>> 블록명:S42, 최선정반: B, 최종배치일:2023-12-07
#
# ***** 검토대상블록: S50 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-05 00:00:00: 65 ~ 73
# >>>>> 검토차수1 / 2023-12-06 00:00:00: 66 ~ 74
# >>>>> 검토차수2 / 2023-12-07 00:00:00: 67 ~ 75
# >>>>> 검토차수3 / 2023-12-08 00:00:00: 68 ~ 76
# >>>>> 검토차수4 / 2023-12-09 00:00:00: 69 ~ 77
# >>>>> 검토차수5 / 2023-12-10 00:00:00: 70 ~ 78
# >>>>> 검토차수6 / 2023-12-11 00:00:00: 71 ~ 79
# >>>>> 검토차수7 / 2023-12-12 00:00:00: 72 ~ 80
# >>>>> 블록명:S50, 최선정반: B, 최종배치일:2023-12-12
#
# ***** 검토대상블록: S51 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-05 00:00:00: 65 ~ 73
# >>>>> 블록명:S51, 최선정반: A, 최종배치일:2023-12-05
#
# ***** 검토대상블록: S57 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-07 00:00:00: 67 ~ 79
# >>>>> 검토차수1 / 2023-12-08 00:00:00: 68 ~ 80
# >>>>> 검토차수2 / 2023-12-09 00:00:00: 69 ~ 81
# >>>>> 검토차수3 / 2023-12-10 00:00:00: 70 ~ 82
# >>>>> 검토차수4 / 2023-12-11 00:00:00: 71 ~ 83
# >>>>> 검토차수5 / 2023-12-12 00:00:00: 72 ~ 84
# >>>>> 검토차수6 / 2023-12-13 00:00:00: 73 ~ 85
# >>>>> 검토차수7 / 2023-12-14 00:00:00: 74 ~ 86
# >>>>> 블록명:S57, 최선정반: A, 최종배치일:2023-12-14
#
# ***** 검토대상블록: S48 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-05 00:00:00: 65 ~ 72
# >>>>> 검토차수1 / 2023-12-06 00:00:00: 66 ~ 73
# >>>>> 검토차수2 / 2023-12-07 00:00:00: 67 ~ 74
# >>>>> 블록명:S48, 최선정반: B, 최종배치일:2023-12-07
#
# ***** 검토대상블록: S63 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-13 00:00:00: 73 ~ 88
# >>>>> 블록명:S63, 최선정반: B, 최종배치일:2023-12-13
#
# ***** 검토대상블록: S64 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-13 00:00:00: 73 ~ 88
# >>>>> 블록명:S64, 최선정반: A, 최종배치일:2023-12-13
#
# ***** 검토대상블록: S55 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-07 00:00:00: 67 ~ 75
# >>>>> 검토차수1 / 2023-12-08 00:00:00: 68 ~ 76
# >>>>> 검토차수2 / 2023-12-09 00:00:00: 69 ~ 77
# >>>>> 검토차수3 / 2023-12-10 00:00:00: 70 ~ 78
# >>>>> 검토차수4 / 2023-12-11 00:00:00: 71 ~ 79
# >>>>> 검토차수5 / 2023-12-12 00:00:00: 72 ~ 80
# >>>>> 검토차수6 / 2023-12-13 00:00:00: 73 ~ 81
# >>>>> 검토차수7 / 2023-12-14 00:00:00: 74 ~ 82
# >>>>> 검토차수8 / 2023-12-15 00:00:00: 75 ~ 83
# >>>>> 검토차수9 / 2023-12-16 00:00:00: 76 ~ 84
# >>>>> 검토차수10 / 2023-12-17 00:00:00: 77 ~ 85
# >>>>> 검토차수11 / 2023-12-18 00:00:00: 78 ~ 86
# >>>>> 검토차수12 / 2023-12-19 00:00:00: 79 ~ 87
# >>>>> 검토차수13 / 2023-12-20 00:00:00: 80 ~ 88
# >>>>> 블록명:S55, 최선정반: B, 최종배치일:2023-12-20
#
# ***** 검토대상블록: S59 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-12 00:00:00: 72 ~ 82
# >>>>> 검토차수1 / 2023-12-13 00:00:00: 73 ~ 83
# >>>>> 블록명:S59, 최선정반: B, 최종배치일:2023-12-13
#
# ***** 검토대상블록: S62 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-14 00:00:00: 74 ~ 87
# >>>>> 검토차수1 / 2023-12-15 00:00:00: 75 ~ 88
# >>>>> 블록명:S62, 최선정반: A, 최종배치일:2023-12-15
#
# ***** 검토대상블록: S67 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-15 00:00:00: 75 ~ 90
# >>>>> 검토차수1 / 2023-12-16 00:00:00: 76 ~ 91
# >>>>> 검토차수2 / 2023-12-17 00:00:00: 77 ~ 92
# >>>>> 검토차수3 / 2023-12-18 00:00:00: 78 ~ 93
# >>>>> 검토차수4 / 2023-12-19 00:00:00: 79 ~ 94
# >>>>> 검토차수5 / 2023-12-20 00:00:00: 80 ~ 95
# >>>>> 검토차수6 / 2023-12-21 00:00:00: 81 ~ 96
# >>>>> 검토차수7 / 2023-12-22 00:00:00: 82 ~ 97
# >>>>> 검토차수8 / 2023-12-23 00:00:00: 83 ~ 98
# >>>>> 검토차수9 / 2023-12-24 00:00:00: 84 ~ 99
# >>>>> 검토차수10 / 2023-12-25 00:00:00: 85 ~ 100
# >>>>> 검토차수11 / 2023-12-26 00:00:00: 86 ~ 101
# >>>>> 검토차수12 / 2023-12-27 00:00:00: 87 ~ 102
# >>>>> 블록명:S67, 최선정반: A, 최종배치일:2023-12-27
#
# ***** 검토대상블록: S53 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-07 00:00:00: 67 ~ 74
# >>>>> 블록명:S53, 최선정반: A, 최종배치일:2023-12-07
#
# ***** 검토대상블록: S54 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-07 00:00:00: 67 ~ 74
# >>>>> 블록명:S54, 최선정반: A, 최종배치일:2023-12-07
#
# ***** 검토대상블록: S56 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-12 00:00:00: 72 ~ 79
# >>>>> 검토차수1 / 2023-12-13 00:00:00: 73 ~ 80
# >>>>> 검토차수2 / 2023-12-14 00:00:00: 74 ~ 81
# >>>>> 검토차수3 / 2023-12-15 00:00:00: 75 ~ 82
# >>>>> 검토차수4 / 2023-12-16 00:00:00: 76 ~ 83
# >>>>> 검토차수5 / 2023-12-17 00:00:00: 77 ~ 84
# >>>>> 검토차수6 / 2023-12-18 00:00:00: 78 ~ 85
# >>>>> 검토차수7 / 2023-12-19 00:00:00: 79 ~ 86
# >>>>> 검토차수8 / 2023-12-20 00:00:00: 80 ~ 87
# >>>>> 검토차수9 / 2023-12-21 00:00:00: 81 ~ 88
# >>>>> 블록명:S56, 최선정반: B, 최종배치일:2023-12-21
#
# ***** 검토대상블록: S58 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-13 00:00:00: 73 ~ 81
# >>>>> 검토차수1 / 2023-12-14 00:00:00: 74 ~ 82
# >>>>> 검토차수2 / 2023-12-15 00:00:00: 75 ~ 83
# >>>>> 검토차수3 / 2023-12-16 00:00:00: 76 ~ 84
# >>>>> 검토차수4 / 2023-12-17 00:00:00: 77 ~ 85
# >>>>> 검토차수5 / 2023-12-18 00:00:00: 78 ~ 86
# >>>>> 검토차수6 / 2023-12-19 00:00:00: 79 ~ 87
# >>>>> 검토차수7 / 2023-12-20 00:00:00: 80 ~ 88
# >>>>> 검토차수8 / 2023-12-21 00:00:00: 81 ~ 89
# >>>>> 검토차수9 / 2023-12-22 00:00:00: 82 ~ 90
# >>>>> 검토차수10 / 2023-12-23 00:00:00: 83 ~ 91
# >>>>> 검토차수11 / 2023-12-24 00:00:00: 84 ~ 92
# >>>>> 블록명:S58, 최선정반: B, 최종배치일:2023-12-24
#
# ***** 검토대상블록: S66 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-19 00:00:00: 79 ~ 90
# >>>>> 블록명:S66, 최선정반: A, 최종배치일:2023-12-19
#
# ***** 검토대상블록: S65 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-19 00:00:00: 79 ~ 90
# >>>>> 블록명:S65, 최선정반: A, 최종배치일:2023-12-19
#
# ***** 검토대상블록: S70 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-21 00:00:00: 81 ~ 94
# >>>>> 검토차수1 / 2023-12-22 00:00:00: 82 ~ 95
# >>>>> 검토차수2 / 2023-12-23 00:00:00: 83 ~ 96
# >>>>> 검토차수3 / 2023-12-24 00:00:00: 84 ~ 97
# >>>>> 검토차수4 / 2023-12-25 00:00:00: 85 ~ 98
# >>>>> 검토차수5 / 2023-12-26 00:00:00: 86 ~ 99
# >>>>> 검토차수6 / 2023-12-27 00:00:00: 87 ~ 100
# >>>>> 검토차수7 / 2023-12-28 00:00:00: 88 ~ 101
# >>>>> 검토차수8 / 2023-12-29 00:00:00: 89 ~ 102
# >>>>> 블록명:S70, 최선정반: B, 최종배치일:2023-12-29
#
# ***** 검토대상블록: S68 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-20 00:00:00: 80 ~ 90
# >>>>> 검토차수1 / 2023-12-21 00:00:00: 81 ~ 91
# >>>>> 검토차수2 / 2023-12-22 00:00:00: 82 ~ 92
# >>>>> 검토차수3 / 2023-12-23 00:00:00: 83 ~ 93
# >>>>> 검토차수4 / 2023-12-24 00:00:00: 84 ~ 94
# >>>>> 검토차수5 / 2023-12-25 00:00:00: 85 ~ 95
# >>>>> 검토차수6 / 2023-12-26 00:00:00: 86 ~ 96
# >>>>> 검토차수7 / 2023-12-27 00:00:00: 87 ~ 97
# >>>>> 검토차수8 / 2023-12-28 00:00:00: 88 ~ 98
# >>>>> 검토차수9 / 2023-12-29 00:00:00: 89 ~ 99
# >>>>> 블록명:S68, 최선정반: B, 최종배치일:2023-12-29
#
# ***** 검토대상블록: S69 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-20 00:00:00: 80 ~ 90
# >>>>> 블록명:S69, 최선정반: B, 최종배치일:2023-12-20
#
# ***** 검토대상블록: S71 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-30 00:00:00: 90 ~ 97
# >>>>> 검토차수1 / 2023-12-31 00:00:00: 91 ~ 98
# >>>>> 검토차수2 / 2024-01-01 00:00:00: 92 ~ 99
# >>>>> 검토차수3 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 검토차수4 / 2024-01-03 00:00:00: 94 ~ 101
# >>>>> 검토차수5 / 2024-01-04 00:00:00: 95 ~ 102
# >>>>> 검토차수6 / 2024-01-05 00:00:00: 96 ~ 103
# >>>>> 검토차수7 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 검토차수8 / 2024-01-07 00:00:00: 98 ~ 105
# >>>>> 검토차수9 / 2024-01-08 00:00:00: 99 ~ 106
# >>>>> 검토차수10 / 2024-01-09 00:00:00: 100 ~ 107
# >>>>> 블록명:S71, 최선정반: B, 최종배치일:2024-01-09
#
# ***** 검토대상블록: S82 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-05 00:00:00: 96 ~ 108
# >>>>> 블록명:S82, 최선정반: A, 최종배치일:2024-01-05
#
# ***** 검토대상블록: S81 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-05 00:00:00: 96 ~ 108
# >>>>> 블록명:S81, 최선정반: A, 최종배치일:2024-01-05
#
# ***** 검토대상블록: S72 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-30 00:00:00: 90 ~ 97
# >>>>> 검토차수1 / 2023-12-31 00:00:00: 91 ~ 98
# >>>>> 검토차수2 / 2024-01-01 00:00:00: 92 ~ 99
# >>>>> 검토차수3 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 검토차수4 / 2024-01-03 00:00:00: 94 ~ 101
# >>>>> 검토차수5 / 2024-01-04 00:00:00: 95 ~ 102
# >>>>> 검토차수6 / 2024-01-05 00:00:00: 96 ~ 103
# >>>>> 검토차수7 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 검토차수8 / 2024-01-07 00:00:00: 98 ~ 105
# >>>>> 검토차수9 / 2024-01-08 00:00:00: 99 ~ 106
# >>>>> 검토차수10 / 2024-01-09 00:00:00: 100 ~ 107
# >>>>> 검토차수11 / 2024-01-10 00:00:00: 101 ~ 108
# >>>>> 검토차수12 / 2024-01-11 00:00:00: 102 ~ 109
# >>>>> 검토차수13 / 2024-01-12 00:00:00: 103 ~ 110
# >>>>> 블록명:S72, 최선정반: A, 최종배치일:2024-01-12
#
# ***** 검토대상블록: S73 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2023-12-30 00:00:00: 90 ~ 97
# >>>>> 검토차수1 / 2023-12-31 00:00:00: 91 ~ 98
# >>>>> 검토차수2 / 2024-01-01 00:00:00: 92 ~ 99
# >>>>> 검토차수3 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 검토차수4 / 2024-01-03 00:00:00: 94 ~ 101
# >>>>> 검토차수5 / 2024-01-04 00:00:00: 95 ~ 102
# >>>>> 검토차수6 / 2024-01-05 00:00:00: 96 ~ 103
# >>>>> 검토차수7 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 검토차수8 / 2024-01-07 00:00:00: 98 ~ 105
# >>>>> 검토차수9 / 2024-01-08 00:00:00: 99 ~ 106
# >>>>> 검토차수10 / 2024-01-09 00:00:00: 100 ~ 107
# >>>>> 검토차수11 / 2024-01-10 00:00:00: 101 ~ 108
# >>>>> 검토차수12 / 2024-01-11 00:00:00: 102 ~ 109
# >>>>> 검토차수13 / 2024-01-12 00:00:00: 103 ~ 110
# >>>>> 블록명:S73, 최선정반: A, 최종배치일:2024-01-12
#
# ***** 검토대상블록: S60 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-21 00:00:00: 81 ~ 83
# >>>>> 블록명:S60, 최선정반: B, 최종배치일:2023-12-21
#
# ***** 검토대상블록: S61 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2023-12-21 00:00:00: 81 ~ 83
# >>>>> 블록명:S61, 최선정반: B, 최종배치일:2023-12-21
#
# ***** 검토대상블록: S74 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 검토차수1 / 2024-01-03 00:00:00: 94 ~ 101
# >>>>> 검토차수2 / 2024-01-04 00:00:00: 95 ~ 102
# >>>>> 검토차수3 / 2024-01-05 00:00:00: 96 ~ 103
# >>>>> 검토차수4 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 검토차수5 / 2024-01-07 00:00:00: 98 ~ 105
# >>>>> 검토차수6 / 2024-01-08 00:00:00: 99 ~ 106
# >>>>> 검토차수7 / 2024-01-09 00:00:00: 100 ~ 107
# >>>>> 검토차수8 / 2024-01-10 00:00:00: 101 ~ 108
# >>>>> 검토차수9 / 2024-01-11 00:00:00: 102 ~ 109
# >>>>> 검토차수10 / 2024-01-12 00:00:00: 103 ~ 110
# >>>>> 블록명:S74, 최선정반: B, 최종배치일:2024-01-12
#
# ***** 검토대상블록: S75 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 검토차수1 / 2024-01-03 00:00:00: 94 ~ 101
# >>>>> 검토차수2 / 2024-01-04 00:00:00: 95 ~ 102
# >>>>> 검토차수3 / 2024-01-05 00:00:00: 96 ~ 103
# >>>>> 검토차수4 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 검토차수5 / 2024-01-07 00:00:00: 98 ~ 105
# >>>>> 검토차수6 / 2024-01-08 00:00:00: 99 ~ 106
# >>>>> 검토차수7 / 2024-01-09 00:00:00: 100 ~ 107
# >>>>> 검토차수8 / 2024-01-10 00:00:00: 101 ~ 108
# >>>>> 검토차수9 / 2024-01-11 00:00:00: 102 ~ 109
# >>>>> 검토차수10 / 2024-01-12 00:00:00: 103 ~ 110
# >>>>> 검토차수11 / 2024-01-13 00:00:00: 104 ~ 111
# >>>>> 검토차수12 / 2024-01-14 00:00:00: 105 ~ 112
# >>>>> 검토차수13 / 2024-01-15 00:00:00: 106 ~ 113
# >>>>> 블록명:S75, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S76 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-02 00:00:00: 93 ~ 100
# >>>>> 블록명:S76, 최선정반: B, 최종배치일:2024-01-02
#
# ***** 검토대상블록: S83 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-09 00:00:00: 100 ~ 109
# >>>>> 검토차수1 / 2024-01-10 00:00:00: 101 ~ 110
# >>>>> 검토차수2 / 2024-01-11 00:00:00: 102 ~ 111
# >>>>> 검토차수3 / 2024-01-12 00:00:00: 103 ~ 112
# >>>>> 검토차수4 / 2024-01-13 00:00:00: 104 ~ 113
# >>>>> 검토차수5 / 2024-01-14 00:00:00: 105 ~ 114
# >>>>> 검토차수6 / 2024-01-15 00:00:00: 106 ~ 115
# >>>>> 검토차수7 / 2024-01-16 00:00:00: 107 ~ 116
# >>>>> 검토차수8 / 2024-01-17 00:00:00: 108 ~ 117
# >>>>> 블록명:S83, 최선정반: B, 최종배치일:2024-01-17
#
# ***** 검토대상블록: S77 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-04 00:00:00: 95 ~ 101
# >>>>> 검토차수1 / 2024-01-05 00:00:00: 96 ~ 102
# >>>>> 검토차수2 / 2024-01-06 00:00:00: 97 ~ 103
# >>>>> 검토차수3 / 2024-01-07 00:00:00: 98 ~ 104
# >>>>> 검토차수4 / 2024-01-08 00:00:00: 99 ~ 105
# >>>>> 검토차수5 / 2024-01-09 00:00:00: 100 ~ 106
# >>>>> 검토차수6 / 2024-01-10 00:00:00: 101 ~ 107
# >>>>> 검토차수7 / 2024-01-11 00:00:00: 102 ~ 108
# >>>>> 검토차수8 / 2024-01-12 00:00:00: 103 ~ 109
# >>>>> 검토차수9 / 2024-01-13 00:00:00: 104 ~ 110
# >>>>> 검토차수10 / 2024-01-14 00:00:00: 105 ~ 111
# >>>>> 검토차수11 / 2024-01-15 00:00:00: 106 ~ 112
# >>>>> 검토차수12 / 2024-01-16 00:00:00: 107 ~ 113
# >>>>> 검토차수13 / 2024-01-17 00:00:00: 108 ~ 114
# >>>>> 블록명:S77, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S86 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-12 00:00:00: 103 ~ 114
# >>>>> 검토차수1 / 2024-01-13 00:00:00: 104 ~ 115
# >>>>> 검토차수2 / 2024-01-14 00:00:00: 105 ~ 116
# >>>>> 검토차수3 / 2024-01-15 00:00:00: 106 ~ 117
# >>>>> 검토차수4 / 2024-01-16 00:00:00: 107 ~ 118
# >>>>> 검토차수5 / 2024-01-17 00:00:00: 108 ~ 119
# >>>>> 검토차수6 / 2024-01-18 00:00:00: 109 ~ 120
# >>>>> 검토차수7 / 2024-01-19 00:00:00: 110 ~ 121
# >>>>> 검토차수8 / 2024-01-20 00:00:00: 111 ~ 122
# >>>>> 블록명:S86, 최선정반: B, 최종배치일:2024-01-20
#
# ***** 검토대상블록: S78 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-06 00:00:00: 97 ~ 104
# >>>>> 블록명:S78, 최선정반: B, 최종배치일:2024-01-06
#
# ***** 검토대상블록: S84 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-11 00:00:00: 102 ~ 110
# >>>>> 검토차수1 / 2024-01-12 00:00:00: 103 ~ 111
# >>>>> 블록명:S84, 최선정반: A, 최종배치일:2024-01-12
#
# ***** 검토대상블록: S80 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-10 00:00:00: 101 ~ 108
# >>>>> 검토차수1 / 2024-01-11 00:00:00: 102 ~ 109
# >>>>> 검토차수2 / 2024-01-12 00:00:00: 103 ~ 110
# >>>>> 검토차수3 / 2024-01-13 00:00:00: 104 ~ 111
# >>>>> 검토차수4 / 2024-01-14 00:00:00: 105 ~ 112
# >>>>> 검토차수5 / 2024-01-15 00:00:00: 106 ~ 113
# >>>>> 검토차수6 / 2024-01-16 00:00:00: 107 ~ 114
# >>>>> 검토차수7 / 2024-01-17 00:00:00: 108 ~ 115
# >>>>> 검토차수8 / 2024-01-18 00:00:00: 109 ~ 116
# >>>>> 검토차수9 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수10 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 검토차수11 / 2024-01-21 00:00:00: 112 ~ 119
# >>>>> 검토차수12 / 2024-01-22 00:00:00: 113 ~ 120
# >>>>> 검토차수13 / 2024-01-23 00:00:00: 114 ~ 121
# >>>>> 블록명:S80, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S94 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-19 00:00:00: 110 ~ 129
# >>>>> 블록명:S94, 최선정반: A, 최종배치일:2024-01-19
#
# ***** 검토대상블록: S90 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-16 00:00:00: 107 ~ 116
# >>>>> 검토차수1 / 2024-01-17 00:00:00: 108 ~ 117
# >>>>> 검토차수2 / 2024-01-18 00:00:00: 109 ~ 118
# >>>>> 검토차수3 / 2024-01-19 00:00:00: 110 ~ 119
# >>>>> 검토차수4 / 2024-01-20 00:00:00: 111 ~ 120
# >>>>> 검토차수5 / 2024-01-21 00:00:00: 112 ~ 121
# >>>>> 블록명:S90, 최선정반: A, 최종배치일:2024-01-21
#
# ***** 검토대상블록: S79 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-10 00:00:00: 101 ~ 105
# >>>>> 검토차수1 / 2024-01-11 00:00:00: 102 ~ 106
# >>>>> 검토차수2 / 2024-01-12 00:00:00: 103 ~ 107
# >>>>> 검토차수3 / 2024-01-13 00:00:00: 104 ~ 108
# >>>>> 검토차수4 / 2024-01-14 00:00:00: 105 ~ 109
# >>>>> 검토차수5 / 2024-01-15 00:00:00: 106 ~ 110
# >>>>> 검토차수6 / 2024-01-16 00:00:00: 107 ~ 111
# >>>>> 검토차수7 / 2024-01-17 00:00:00: 108 ~ 112
# >>>>> 검토차수8 / 2024-01-18 00:00:00: 109 ~ 113
# >>>>> 검토차수9 / 2024-01-19 00:00:00: 110 ~ 114
# >>>>> 검토차수10 / 2024-01-20 00:00:00: 111 ~ 115
# >>>>> 검토차수11 / 2024-01-21 00:00:00: 112 ~ 116
# >>>>> 검토차수12 / 2024-01-22 00:00:00: 113 ~ 117
# >>>>> 검토차수13 / 2024-01-23 00:00:00: 114 ~ 118
# >>>>> 블록명:S79, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S97 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-20 00:00:00: 111 ~ 130
# >>>>> 블록명:S97, 최선정반: B, 최종배치일:2024-01-20
#
# ***** 검토대상블록: S85 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-13 00:00:00: 104 ~ 111
# >>>>> 검토차수1 / 2024-01-14 00:00:00: 105 ~ 112
# >>>>> 검토차수2 / 2024-01-15 00:00:00: 106 ~ 113
# >>>>> 검토차수3 / 2024-01-16 00:00:00: 107 ~ 114
# >>>>> 검토차수4 / 2024-01-17 00:00:00: 108 ~ 115
# >>>>> 검토차수5 / 2024-01-18 00:00:00: 109 ~ 116
# >>>>> 검토차수6 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수7 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 블록명:S85, 최선정반: A, 최종배치일:2024-01-20
#
# ***** 검토대상블록: S87 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-16 00:00:00: 107 ~ 114
# >>>>> 검토차수1 / 2024-01-17 00:00:00: 108 ~ 115
# >>>>> 검토차수2 / 2024-01-18 00:00:00: 109 ~ 116
# >>>>> 검토차수3 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수4 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 검토차수5 / 2024-01-21 00:00:00: 112 ~ 119
# >>>>> 검토차수6 / 2024-01-22 00:00:00: 113 ~ 120
# >>>>> 검토차수7 / 2024-01-23 00:00:00: 114 ~ 121
# >>>>> 검토차수8 / 2024-01-24 00:00:00: 115 ~ 122
# >>>>> 검토차수9 / 2024-01-25 00:00:00: 116 ~ 123
# >>>>> 검토차수10 / 2024-01-26 00:00:00: 117 ~ 124
# >>>>> 검토차수11 / 2024-01-27 00:00:00: 118 ~ 125
# >>>>> 블록명:S87, 최선정반: B, 최종배치일:2024-01-27
#
# ***** 검토대상블록: S96 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-23 00:00:00: 114 ~ 129
# >>>>> 블록명:S96, 최선정반: B, 최종배치일:2024-01-23
#
# ***** 검토대상블록: S89 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-16 00:00:00: 107 ~ 114
# >>>>> 검토차수1 / 2024-01-17 00:00:00: 108 ~ 115
# >>>>> 검토차수2 / 2024-01-18 00:00:00: 109 ~ 116
# >>>>> 검토차수3 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수4 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 검토차수5 / 2024-01-21 00:00:00: 112 ~ 119
# >>>>> 검토차수6 / 2024-01-22 00:00:00: 113 ~ 120
# >>>>> 검토차수7 / 2024-01-23 00:00:00: 114 ~ 121
# >>>>> 검토차수8 / 2024-01-24 00:00:00: 115 ~ 122
# >>>>> 검토차수9 / 2024-01-25 00:00:00: 116 ~ 123
# >>>>> 검토차수10 / 2024-01-26 00:00:00: 117 ~ 124
# >>>>> 검토차수11 / 2024-01-27 00:00:00: 118 ~ 125
# >>>>> 검토차수12 / 2024-01-28 00:00:00: 119 ~ 126
# >>>>> 검토차수13 / 2024-01-29 00:00:00: 120 ~ 127
# >>>>> 블록명:S89, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S99 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-24 00:00:00: 115 ~ 130
# >>>>> 블록명:S99, 최선정반: B, 최종배치일:2024-01-24
#
# ***** 검토대상블록: S105 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-27 00:00:00: 118 ~ 136
# >>>>> 검토차수1 / 2024-01-28 00:00:00: 119 ~ 137
# >>>>> 검토차수2 / 2024-01-29 00:00:00: 120 ~ 138
# >>>>> 검토차수3 / 2024-01-30 00:00:00: 121 ~ 139
# >>>>> 검토차수4 / 2024-01-31 00:00:00: 122 ~ 140
# >>>>> 검토차수5 / 2024-02-01 00:00:00: 123 ~ 141
# >>>>> 블록명:S105, 최선정반: B, 최종배치일:2024-02-01
#
# ***** 검토대상블록: S88 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-17 00:00:00: 108 ~ 114
# >>>>> 검토차수1 / 2024-01-18 00:00:00: 109 ~ 115
# >>>>> 검토차수2 / 2024-01-19 00:00:00: 110 ~ 116
# >>>>> 검토차수3 / 2024-01-20 00:00:00: 111 ~ 117
# >>>>> 검토차수4 / 2024-01-21 00:00:00: 112 ~ 118
# >>>>> 검토차수5 / 2024-01-22 00:00:00: 113 ~ 119
# >>>>> 검토차수6 / 2024-01-23 00:00:00: 114 ~ 120
# >>>>> 검토차수7 / 2024-01-24 00:00:00: 115 ~ 121
# >>>>> 검토차수8 / 2024-01-25 00:00:00: 116 ~ 122
# >>>>> 검토차수9 / 2024-01-26 00:00:00: 117 ~ 123
# >>>>> 검토차수10 / 2024-01-27 00:00:00: 118 ~ 124
# >>>>> 검토차수11 / 2024-01-28 00:00:00: 119 ~ 125
# >>>>> 블록명:S88, 최선정반: A, 최종배치일:2024-01-28
#
# ***** 검토대상블록: S103 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-27 00:00:00: 118 ~ 131
# >>>>> 블록명:S103, 최선정반: B, 최종배치일:2024-01-27
#
# ***** 검토대상블록: S98 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-27 00:00:00: 118 ~ 130
# >>>>> 검토차수1 / 2024-01-28 00:00:00: 119 ~ 131
# >>>>> 검토차수2 / 2024-01-29 00:00:00: 120 ~ 132
# >>>>> 검토차수3 / 2024-01-30 00:00:00: 121 ~ 133
# >>>>> 검토차수4 / 2024-01-31 00:00:00: 122 ~ 134
# >>>>> 블록명:S98, 최선정반: A, 최종배치일:2024-01-31
#
# ***** 검토대상블록: S91 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수1 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 검토차수2 / 2024-01-21 00:00:00: 112 ~ 119
# >>>>> 블록명:S91, 최선정반: A, 최종배치일:2024-01-21
#
# ***** 검토대상블록: S92 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-19 00:00:00: 110 ~ 117
# >>>>> 검토차수1 / 2024-01-20 00:00:00: 111 ~ 118
# >>>>> 검토차수2 / 2024-01-21 00:00:00: 112 ~ 119
# >>>>> 검토차수3 / 2024-01-22 00:00:00: 113 ~ 120
# >>>>> 검토차수4 / 2024-01-23 00:00:00: 114 ~ 121
# >>>>> 검토차수5 / 2024-01-24 00:00:00: 115 ~ 122
# >>>>> 검토차수6 / 2024-01-25 00:00:00: 116 ~ 123
# >>>>> 검토차수7 / 2024-01-26 00:00:00: 117 ~ 124
# >>>>> 검토차수8 / 2024-01-27 00:00:00: 118 ~ 125
# >>>>> 검토차수9 / 2024-01-28 00:00:00: 119 ~ 126
# >>>>> 검토차수10 / 2024-01-29 00:00:00: 120 ~ 127
# >>>>> 블록명:S92, 최선정반: A, 최종배치일:2024-01-29
#
# ***** 검토대상블록: S102 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-30 00:00:00: 121 ~ 131
# >>>>> 검토차수1 / 2024-01-31 00:00:00: 122 ~ 132
# >>>>> 검토차수2 / 2024-02-01 00:00:00: 123 ~ 133
# >>>>> 검토차수3 / 2024-02-02 00:00:00: 124 ~ 134
# >>>>> 검토차수4 / 2024-02-03 00:00:00: 125 ~ 135
# >>>>> 검토차수5 / 2024-02-04 00:00:00: 126 ~ 136
# >>>>> 블록명:S102, 최선정반: B, 최종배치일:2024-02-04
#
# ***** 검토대상블록: S104 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-01 00:00:00: 123 ~ 135
# >>>>> 검토차수1 / 2024-02-02 00:00:00: 124 ~ 136
# >>>>> 검토차수2 / 2024-02-03 00:00:00: 125 ~ 137
# >>>>> 검토차수3 / 2024-02-04 00:00:00: 126 ~ 138
# >>>>> 검토차수4 / 2024-02-05 00:00:00: 127 ~ 139
# >>>>> 검토차수5 / 2024-02-06 00:00:00: 128 ~ 140
# >>>>> 검토차수6 / 2024-02-07 00:00:00: 129 ~ 141
# >>>>> 검토차수7 / 2024-02-08 00:00:00: 130 ~ 142
# >>>>> 블록명:S104, 최선정반: B, 최종배치일:2024-02-08
#
# ***** 검토대상블록: S93 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-01-23 00:00:00: 114 ~ 118
# >>>>> 검토차수1 / 2024-01-24 00:00:00: 115 ~ 119
# >>>>> 검토차수2 / 2024-01-25 00:00:00: 116 ~ 120
# >>>>> 검토차수3 / 2024-01-26 00:00:00: 117 ~ 121
# >>>>> 검토차수4 / 2024-01-27 00:00:00: 118 ~ 122
# >>>>> 검토차수5 / 2024-01-28 00:00:00: 119 ~ 123
# >>>>> 검토차수6 / 2024-01-29 00:00:00: 120 ~ 124
# >>>>> 검토차수7 / 2024-01-30 00:00:00: 121 ~ 125
# >>>>> 검토차수8 / 2024-01-31 00:00:00: 122 ~ 126
# >>>>> 검토차수9 / 2024-02-01 00:00:00: 123 ~ 127
# >>>>> 검토차수10 / 2024-02-02 00:00:00: 124 ~ 128
# >>>>> 검토차수11 / 2024-02-03 00:00:00: 125 ~ 129
# >>>>> 검토차수12 / 2024-02-04 00:00:00: 126 ~ 130
# >>>>> 검토차수13 / 2024-02-05 00:00:00: 127 ~ 131
# >>>>> 블록명:S93, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S95 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-01-30 00:00:00: 121 ~ 129
# >>>>> 검토차수1 / 2024-01-31 00:00:00: 122 ~ 130
# >>>>> 검토차수2 / 2024-02-01 00:00:00: 123 ~ 131
# >>>>> 검토차수3 / 2024-02-02 00:00:00: 124 ~ 132
# >>>>> 검토차수4 / 2024-02-03 00:00:00: 125 ~ 133
# >>>>> 검토차수5 / 2024-02-04 00:00:00: 126 ~ 134
# >>>>> 검토차수6 / 2024-02-05 00:00:00: 127 ~ 135
# >>>>> 검토차수7 / 2024-02-06 00:00:00: 128 ~ 136
# >>>>> 검토차수8 / 2024-02-07 00:00:00: 129 ~ 137
# >>>>> 검토차수9 / 2024-02-08 00:00:00: 130 ~ 138
# >>>>> 블록명:S95, 최선정반: A, 최종배치일:2024-02-08
#
# ***** 검토대상블록: S108 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-08 00:00:00: 130 ~ 139
# >>>>> 검토차수1 / 2024-02-09 00:00:00: 131 ~ 140
# >>>>> 검토차수2 / 2024-02-10 00:00:00: 132 ~ 141
# >>>>> 블록명:S108, 최선정반: B, 최종배치일:2024-02-10
#
# ***** 검토대상블록: S112 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-09 00:00:00: 131 ~ 142
# >>>>> 검토차수1 / 2024-02-10 00:00:00: 132 ~ 143
# >>>>> 검토차수2 / 2024-02-11 00:00:00: 133 ~ 144
# >>>>> 검토차수3 / 2024-02-12 00:00:00: 134 ~ 145
# >>>>> 검토차수4 / 2024-02-13 00:00:00: 135 ~ 146
# >>>>> 검토차수5 / 2024-02-14 00:00:00: 136 ~ 147
# >>>>> 검토차수6 / 2024-02-15 00:00:00: 137 ~ 148
# >>>>> 검토차수7 / 2024-02-16 00:00:00: 138 ~ 149
# >>>>> 검토차수8 / 2024-02-17 00:00:00: 139 ~ 150
# >>>>> 블록명:S112, 최선정반: A, 최종배치일:2024-02-17
#
# ***** 검토대상블록: S109 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-08 00:00:00: 130 ~ 139
# >>>>> 블록명:S109, 최선정반: A, 최종배치일:2024-02-08
#
# ***** 검토대상블록: S107 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-08 00:00:00: 130 ~ 139
# >>>>> 검토차수1 / 2024-02-09 00:00:00: 131 ~ 140
# >>>>> 블록명:S107, 최선정반: B, 최종배치일:2024-02-09
#
# ***** 검토대상블록: S111 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-09 00:00:00: 131 ~ 142
# >>>>> 검토차수1 / 2024-02-10 00:00:00: 132 ~ 143
# >>>>> 검토차수2 / 2024-02-11 00:00:00: 133 ~ 144
# >>>>> 검토차수3 / 2024-02-12 00:00:00: 134 ~ 145
# >>>>> 검토차수4 / 2024-02-13 00:00:00: 135 ~ 146
# >>>>> 블록명:S111, 최선정반: A, 최종배치일:2024-02-13
#
# ***** 검토대상블록: S106 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-07 00:00:00: 129 ~ 136
# >>>>> 검토차수1 / 2024-02-08 00:00:00: 130 ~ 137
# >>>>> 검토차수2 / 2024-02-09 00:00:00: 131 ~ 138
# >>>>> 검토차수3 / 2024-02-10 00:00:00: 132 ~ 139
# >>>>> 검토차수4 / 2024-02-11 00:00:00: 133 ~ 140
# >>>>> 검토차수5 / 2024-02-12 00:00:00: 134 ~ 141
# >>>>> 검토차수6 / 2024-02-13 00:00:00: 135 ~ 142
# >>>>> 검토차수7 / 2024-02-14 00:00:00: 136 ~ 143
# >>>>> 검토차수8 / 2024-02-15 00:00:00: 137 ~ 144
# >>>>> 블록명:S106, 최선정반: B, 최종배치일:2024-02-15
#
# ***** 검토대상블록: S100 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-07 00:00:00: 129 ~ 131
# >>>>> 블록명:S100, 최선정반: A, 최종배치일:2024-02-07
#
# ***** 검토대상블록: S101 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-07 00:00:00: 129 ~ 131
# >>>>> 블록명:S101, 최선정반: A, 최종배치일:2024-02-07
#
# ***** 검토대상블록: S113 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-13 00:00:00: 135 ~ 143
# >>>>> 검토차수1 / 2024-02-14 00:00:00: 136 ~ 144
# >>>>> 검토차수2 / 2024-02-15 00:00:00: 137 ~ 145
# >>>>> 검토차수3 / 2024-02-16 00:00:00: 138 ~ 146
# >>>>> 검토차수4 / 2024-02-17 00:00:00: 139 ~ 147
# >>>>> 검토차수5 / 2024-02-18 00:00:00: 140 ~ 148
# >>>>> 검토차수6 / 2024-02-19 00:00:00: 141 ~ 149
# >>>>> 블록명:S113, 최선정반: B, 최종배치일:2024-02-19
#
# ***** 검토대상블록: S110 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-10 00:00:00: 132 ~ 139
# >>>>> 블록명:S110, 최선정반: A, 최종배치일:2024-02-10
#
# ***** 검토대상블록: S116 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-15 00:00:00: 137 ~ 145
# >>>>> 검토차수1 / 2024-02-16 00:00:00: 138 ~ 146
# >>>>> 검토차수2 / 2024-02-17 00:00:00: 139 ~ 147
# >>>>> 검토차수3 / 2024-02-18 00:00:00: 140 ~ 148
# >>>>> 검토차수4 / 2024-02-19 00:00:00: 141 ~ 149
# >>>>> 검토차수5 / 2024-02-20 00:00:00: 142 ~ 150
# >>>>> 블록명:S116, 최선정반: B, 최종배치일:2024-02-20
#
# ***** 검토대상블록: S115 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-15 00:00:00: 137 ~ 145
# >>>>> 검토차수1 / 2024-02-16 00:00:00: 138 ~ 146
# >>>>> 검토차수2 / 2024-02-17 00:00:00: 139 ~ 147
# >>>>> 검토차수3 / 2024-02-18 00:00:00: 140 ~ 148
# >>>>> 검토차수4 / 2024-02-19 00:00:00: 141 ~ 149
# >>>>> 검토차수5 / 2024-02-20 00:00:00: 142 ~ 150
# >>>>> 검토차수6 / 2024-02-21 00:00:00: 143 ~ 151
# >>>>> 블록명:S115, 최선정반: B, 최종배치일:2024-02-21
#
# ***** 검토대상블록: S119 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-17 00:00:00: 139 ~ 149
# >>>>> 검토차수1 / 2024-02-18 00:00:00: 140 ~ 150
# >>>>> 검토차수2 / 2024-02-19 00:00:00: 141 ~ 151
# >>>>> 검토차수3 / 2024-02-20 00:00:00: 142 ~ 152
# >>>>> 검토차수4 / 2024-02-21 00:00:00: 143 ~ 153
# >>>>> 검토차수5 / 2024-02-22 00:00:00: 144 ~ 154
# >>>>> 검토차수6 / 2024-02-23 00:00:00: 145 ~ 155
# >>>>> 검토차수7 / 2024-02-24 00:00:00: 146 ~ 156
# >>>>> 검토차수8 / 2024-02-25 00:00:00: 147 ~ 157
# >>>>> 검토차수9 / 2024-02-26 00:00:00: 148 ~ 158
# >>>>> 검토차수10 / 2024-02-27 00:00:00: 149 ~ 159
# >>>>> 검토차수11 / 2024-02-28 00:00:00: 150 ~ 160
# >>>>> 블록명:S119, 최선정반: B, 최종배치일:2024-02-28
#
# ***** 검토대상블록: S114 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-15 00:00:00: 137 ~ 145
# >>>>> 검토차수1 / 2024-02-16 00:00:00: 138 ~ 146
# >>>>> 검토차수2 / 2024-02-17 00:00:00: 139 ~ 147
# >>>>> 검토차수3 / 2024-02-18 00:00:00: 140 ~ 148
# >>>>> 블록명:S114, 최선정반: A, 최종배치일:2024-02-18
#
# ***** 검토대상블록: S126 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-23 00:00:00: 145 ~ 158
# >>>>> 검토차수1 / 2024-02-24 00:00:00: 146 ~ 159
# >>>>> 검토차수2 / 2024-02-25 00:00:00: 147 ~ 160
# >>>>> 검토차수3 / 2024-02-26 00:00:00: 148 ~ 161
# >>>>> 검토차수4 / 2024-02-27 00:00:00: 149 ~ 162
# >>>>> 검토차수5 / 2024-02-28 00:00:00: 150 ~ 163
# >>>>> 검토차수6 / 2024-02-29 00:00:00: 151 ~ 164
# >>>>> 블록명:S126, 최선정반: B, 최종배치일:2024-02-29
#
# ***** 검토대상블록: S127 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-23 00:00:00: 145 ~ 158
# >>>>> 검토차수1 / 2024-02-24 00:00:00: 146 ~ 159
# >>>>> 검토차수2 / 2024-02-25 00:00:00: 147 ~ 160
# >>>>> 검토차수3 / 2024-02-26 00:00:00: 148 ~ 161
# >>>>> 검토차수4 / 2024-02-27 00:00:00: 149 ~ 162
# >>>>> 블록명:S127, 최선정반: A, 최종배치일:2024-02-27
#
# ***** 검토대상블록: S120 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-20 00:00:00: 142 ~ 151
# >>>>> 검토차수1 / 2024-02-21 00:00:00: 143 ~ 152
# >>>>> 검토차수2 / 2024-02-22 00:00:00: 144 ~ 153
# >>>>> 검토차수3 / 2024-02-23 00:00:00: 145 ~ 154
# >>>>> 검토차수4 / 2024-02-24 00:00:00: 146 ~ 155
# >>>>> 검토차수5 / 2024-02-25 00:00:00: 147 ~ 156
# >>>>> 검토차수6 / 2024-02-26 00:00:00: 148 ~ 157
# >>>>> 검토차수7 / 2024-02-27 00:00:00: 149 ~ 158
# >>>>> 블록명:S120, 최선정반: A, 최종배치일:2024-02-27
#
# ***** 검토대상블록: S124 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-23 00:00:00: 145 ~ 157
# >>>>> 검토차수1 / 2024-02-24 00:00:00: 146 ~ 158
# >>>>> 검토차수2 / 2024-02-25 00:00:00: 147 ~ 159
# >>>>> 검토차수3 / 2024-02-26 00:00:00: 148 ~ 160
# >>>>> 검토차수4 / 2024-02-27 00:00:00: 149 ~ 161
# >>>>> 검토차수5 / 2024-02-28 00:00:00: 150 ~ 162
# >>>>> 검토차수6 / 2024-02-29 00:00:00: 151 ~ 163
# >>>>> 검토차수7 / 2024-03-01 00:00:00: 152 ~ 164
# >>>>> 블록명:S124, 최선정반: B, 최종배치일:2024-03-01
#
# ***** 검토대상블록: S118 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-17 00:00:00: 139 ~ 146
# >>>>> 검토차수1 / 2024-02-18 00:00:00: 140 ~ 147
# >>>>> 검토차수2 / 2024-02-19 00:00:00: 141 ~ 148
# >>>>> 검토차수3 / 2024-02-20 00:00:00: 142 ~ 149
# >>>>> 검토차수4 / 2024-02-21 00:00:00: 143 ~ 150
# >>>>> 검토차수5 / 2024-02-22 00:00:00: 144 ~ 151
# >>>>> 검토차수6 / 2024-02-23 00:00:00: 145 ~ 152
# >>>>> 검토차수7 / 2024-02-24 00:00:00: 146 ~ 153
# >>>>> 검토차수8 / 2024-02-25 00:00:00: 147 ~ 154
# >>>>> 검토차수9 / 2024-02-26 00:00:00: 148 ~ 155
# >>>>> 검토차수10 / 2024-02-27 00:00:00: 149 ~ 156
# >>>>> 검토차수11 / 2024-02-28 00:00:00: 150 ~ 157
# >>>>> 검토차수12 / 2024-02-29 00:00:00: 151 ~ 158
# >>>>> 검토차수13 / 2024-03-01 00:00:00: 152 ~ 159
# >>>>> 블록명:S118, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S121 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): A
# >>>>> 검토차수0 / 2024-02-22 00:00:00: 144 ~ 152
# >>>>> 검토차수1 / 2024-02-23 00:00:00: 145 ~ 153
# >>>>> 검토차수2 / 2024-02-24 00:00:00: 146 ~ 154
# >>>>> 검토차수3 / 2024-02-25 00:00:00: 147 ~ 155
# >>>>> 검토차수4 / 2024-02-26 00:00:00: 148 ~ 156
# >>>>> 검토차수5 / 2024-02-27 00:00:00: 149 ~ 157
# >>>>> 검토차수6 / 2024-02-28 00:00:00: 150 ~ 158
# >>>>> 검토차수7 / 2024-02-29 00:00:00: 151 ~ 159
# >>>>> 블록명:S121, 최선정반: A, 최종배치일:2024-02-29
#
# ***** 검토대상블록: S117 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-20 00:00:00: 142 ~ 146
# >>>>> 검토차수1 / 2024-02-21 00:00:00: 143 ~ 147
# >>>>> 검토차수2 / 2024-02-22 00:00:00: 144 ~ 148
# >>>>> 검토차수3 / 2024-02-23 00:00:00: 145 ~ 149
# >>>>> 검토차수4 / 2024-02-24 00:00:00: 146 ~ 150
# >>>>> 검토차수5 / 2024-02-25 00:00:00: 147 ~ 151
# >>>>> 검토차수6 / 2024-02-26 00:00:00: 148 ~ 152
# >>>>> 검토차수7 / 2024-02-27 00:00:00: 149 ~ 153
# >>>>> 검토차수8 / 2024-02-28 00:00:00: 150 ~ 154
# >>>>> 검토차수9 / 2024-02-29 00:00:00: 151 ~ 155
# >>>>> 검토차수10 / 2024-03-01 00:00:00: 152 ~ 156
# >>>>> 검토차수11 / 2024-03-02 00:00:00: 153 ~ 157
# >>>>> 검토차수12 / 2024-03-03 00:00:00: 154 ~ 158
# >>>>> 검토차수13 / 2024-03-04 00:00:00: 155 ~ 159
# >>>>> 블록명:S117, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S125 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-27 00:00:00: 149 ~ 157
# >>>>> 검토차수1 / 2024-02-28 00:00:00: 150 ~ 158
# >>>>> 검토차수2 / 2024-02-29 00:00:00: 151 ~ 159
# >>>>> 검토차수3 / 2024-03-01 00:00:00: 152 ~ 160
# >>>>> 검토차수4 / 2024-03-02 00:00:00: 153 ~ 161
# >>>>> 검토차수5 / 2024-03-03 00:00:00: 154 ~ 162
# >>>>> 검토차수6 / 2024-03-04 00:00:00: 155 ~ 163
# >>>>> 검토차수7 / 2024-03-05 00:00:00: 156 ~ 164
# >>>>> 검토차수8 / 2024-03-06 00:00:00: 157 ~ 165
# >>>>> 검토차수9 / 2024-03-07 00:00:00: 158 ~ 166
# >>>>> 검토차수10 / 2024-03-08 00:00:00: 159 ~ 167
# >>>>> 검토차수11 / 2024-03-09 00:00:00: 160 ~ 168
# >>>>> 검토차수12 / 2024-03-10 00:00:00: 161 ~ 169
# >>>>> 검토차수13 / 2024-03-11 00:00:00: 162 ~ 170
# >>>>> 블록명:S125, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S122 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-27 00:00:00: 149 ~ 156
# >>>>> 검토차수1 / 2024-02-28 00:00:00: 150 ~ 157
# >>>>> 검토차수2 / 2024-02-29 00:00:00: 151 ~ 158
# >>>>> 검토차수3 / 2024-03-01 00:00:00: 152 ~ 159
# >>>>> 검토차수4 / 2024-03-02 00:00:00: 153 ~ 160
# >>>>> 검토차수5 / 2024-03-03 00:00:00: 154 ~ 161
# >>>>> 검토차수6 / 2024-03-04 00:00:00: 155 ~ 162
# >>>>> 검토차수7 / 2024-03-05 00:00:00: 156 ~ 163
# >>>>> 검토차수8 / 2024-03-06 00:00:00: 157 ~ 164
# >>>>> 검토차수9 / 2024-03-07 00:00:00: 158 ~ 165
# >>>>> 검토차수10 / 2024-03-08 00:00:00: 159 ~ 166
# >>>>> 검토차수11 / 2024-03-09 00:00:00: 160 ~ 167
# >>>>> 검토차수12 / 2024-03-10 00:00:00: 161 ~ 168
# >>>>> 검토차수13 / 2024-03-11 00:00:00: 162 ~ 169
# >>>>> 블록명:S122, 최선정반: None, 최종배치일:None
#
# ***** 검토대상블록: S123 ---------------------------------------------
# >>>>> 물리조건가능정반들: ['B', 'A'], 최선정반(현재는 완전 랜덤 선택): B
# >>>>> 검토차수0 / 2024-02-27 00:00:00: 149 ~ 156
# >>>>> 검토차수1 / 2024-02-28 00:00:00: 150 ~ 157
# >>>>> 검토차수2 / 2024-02-29 00:00:00: 151 ~ 158
# >>>>> 검토차수3 / 2024-03-01 00:00:00: 152 ~ 159
# >>>>> 검토차수4 / 2024-03-02 00:00:00: 153 ~ 160
# >>>>> 검토차수5 / 2024-03-03 00:00:00: 154 ~ 161
# >>>>> 검토차수6 / 2024-03-04 00:00:00: 155 ~ 162
# >>>>> 검토차수7 / 2024-03-05 00:00:00: 156 ~ 163
# >>>>> 검토차수8 / 2024-03-06 00:00:00: 157 ~ 164
# >>>>> 검토차수9 / 2024-03-07 00:00:00: 158 ~ 165
# >>>>> 검토차수10 / 2024-03-08 00:00:00: 159 ~ 166
# >>>>> 검토차수11 / 2024-03-09 00:00:00: 160 ~ 167
# >>>>> 검토차수12 / 2024-03-10 00:00:00: 161 ~ 168
# >>>>> 블록명:S123, 최선정반: B, 최종배치일:2024-03-10

# %%
print(f"*** 미배치개수: {배치후데이터['착수일자'].isnull().sum()}")
# 배치후데이터
배치후데이터["델타"].value_counts().sort_index()
# Out:
# *** 미배치개수: 12
# 델타
# -6.0    48
# -5.0     4
# -4.0     5
# -3.0     1
# -2.0     3
# -1.0     7
#  0.0     5
#  1.0     7
#  2.0     5
#  3.0     4
#  4.0     4
#  5.0     4
#  6.0     2
#  7.0     4
# Name: count, dtype: int64

# %% [markdown]
# # 시각화

# %%
정반리스트 = ["A", "B"]
for i in range(26, 40):
    target_date = 레이아웃달력.index[i]
    print(target_date)
    
    draw_layout_subplots(레이아웃달력, 정반리스트, i)
print(">>>> 시각화 완료 =============================================================================================================")
# Out:
# 2023-10-27 00:00:00
# 2023-10-28 00:00:00
# 2023-10-29 00:00:00
# 2023-10-30 00:00:00
# 2023-10-31 00:00:00
# 2023-11-01 00:00:00
# 2023-11-02 00:00:00
# 2023-11-03 00:00:00
# 2023-11-04 00:00:00
# 2023-11-05 00:00:00
# 2023-11-06 00:00:00
# 2023-11-07 00:00:00
# 2023-11-08 00:00:00
# 2023-11-09 00:00:00
# 시각화 완료
