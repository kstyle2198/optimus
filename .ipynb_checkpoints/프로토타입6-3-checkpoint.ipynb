# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from random import random, randrange, choice, shuffle
from datetime import datetime, timedelta, date
from itertools import combinations
from pprint import pprint
import calendar
import plotly.express as px

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # Cell의 모든 반환값 출력

pd.set_option('display.max_rows', None)

# %% [markdown]
# # 블록데이터 전처리 함수

# %%
import functools
def unpack_df_columns(func):
    @functools.wraps(func)
    def _unpack_df_columns(*args, **kwargs):
        series = args[0]
        return func(*series.values)
    return _unpack_df_columns

# %%
@unpack_df_columns
def 최소착수요구일구하기(납기, 공기):
    result = pd.to_datetime(납기) - timedelta(days=int(공기))
    return result.date()

# %%
@unpack_df_columns
def 블록우선순위구하기(날짜순서, 공기순서, 크기순서):
    global 착수일가중치, 공기가중치, 크기가중치
    result = np.round((날짜순서*float(착수일가중치) + 공기순서*float(공기가중치) + 크기순서*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 블록사이즈튜플만들기(가로, 세로):
    길이2 = max(가로, 세로)  
    길이1 = min(가로, 세로)
    result = (길이2, 길이1)
    return result

# %%
def 블록데이터전처리(블록원데이터):
    df1 = 블록원데이터.copy()
    df1["사이즈"] = df1[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
    df1["최대길이"] = df1["사이즈"].apply(lambda x: max(x))
    df1["납기"] = pd.to_datetime(df1["납기"])
    df1["면적"] = df1.eval("가로*세로")
    df1["최소착수요구일"] = df1[["납기", "표준공기"]].apply(최소착수요구일구하기, axis=1)
    df1["날짜순서"] = df1["최소착수요구일"].rank()
    df1["공기순서"] = df1["표준공기"].rank(ascending=False)
    df1["크기순서"] = df1["면적"].rank(ascending=False)
    df1["우선순위"] = df1[["날짜순서", "공기순서", "크기순서"]].apply(블록우선순위구하기, axis=1)
    
    df1 = df1.drop(['가로', '세로'], axis=1)
    df1 = df1.sort_values(by=["우선순위"])
    return df1

# %% [markdown]
# # 정반데이터 전처리 함수

# %%
@unpack_df_columns
def 정반우선순위구하기(중순, 크순):
    global 중량가중치, 크기가중치
    result = np.round((중순*float(중량가중치) + 크순*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 정반사이즈튜플만들기(가로, 세로):
    길이1 = max(가로, 세로)  
    길이2 = min(가로, 세로)
    result = (길이1, 길이2)
    return result

# %%
def 정반데이터전처리(정반원데이터):
    df = 정반원데이터.copy()
    
    df["사이즈"] = df[["가로", "세로"]].apply(정반사이즈튜플만들기, axis=1)
    df["면적"] = df.eval("가로*세로")
    df["최대길이"] = df["사이즈"].apply(lambda x: max(x))
    df["중량순서"] = df["가능중량"].rank(ascending=False)
    df["크기순서"] = df["면적"].rank(ascending=False)
    df["우선순위"] = df[["중량순서", "크기순서"]].apply(정반우선순위구하기, axis=1)
    
    df = df.drop(['가로', '세로'], axis=1)
    df = df.sort_values(by=["우선순위"])
    return df

# %% [markdown]
# # 면적달력 함수

# %%
def get_end_date_of_month(year, month):
    # Get the number of days in the given month
    num_days = calendar.monthrange(year, month)[1]
    # Return the last day of the month as a datetime object
    return date(year, month, num_days)

# %%
def create_면적달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터: pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    면적달력 = pd.DataFrame()
    면적달력.index = 날짜집합
   
    for 정반 in 정반집합:
        면적달력[f"{정반}"] = 정반데이터[정반데이터["정반명"]==정반]["면적"].values[0]

    return 면적달력

# %%
def update_init_면적달력(면적달력:pd.DataFrame, 블록착수일:str, 정반:str, 블록면적:int, 표준공기:int) -> pd.DataFrame:
    
    정반리스트 = 면적달력.columns.tolist()
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)   
    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values

    for idx, 대상일면적 in enumerate(조회기간면적리스트):
        수정면적 = 대상일면적 - 블록면적
        대상일인덱스 = 시점인덱스 + idx
        면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
        
    return 면적달력

# %%
def update_면적달력(면적달력, 정반, 블록착수일, 배치블록명, 블록데이터):
    
    정반리스트 = 면적달력.columns.tolist()
    블록면적 = 블록데이터[블록데이터["블록명"]==배치블록명]["면적"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==배치블록명]["표준공기"].values[0]
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)        

    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values
    
    print(f"조회기간 최소면적: {min(조회기간면적리스트)}, 블록면적: {블록면적}")
    if min(조회기간면적리스트) >= 블록면적:
        for idx, 대상일면적 in enumerate(조회기간면적리스트):
            수정면적 = 대상일면적 - 블록면적
            대상일인덱스 = 시점인덱스 + idx
            면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
            
        return True, 면적달력
    else:
        print("면적부족으로 배치불가능")
        return False, 면적달력

# %%
def update_면적달력1(면적달력, 최선정반, 최선착수일, 배치블록명, 블록데이터):

    정반리스트 = 면적달력.columns.tolist()
    블록면적 = 블록데이터[블록데이터["블록명"]==배치블록명]["면적"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==배치블록명]["표준공기"].values[0]
    블록착수일 = 최선착수일
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)
    정반 = 최선정반

    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values
    
    print(f"조회기간 최소면적: {min(조회기간면적리스트)}, 블록면적: {블록면적}")
    if min(조회기간면적리스트) >= 블록면적:
        for idx, 대상일면적 in enumerate(조회기간면적리스트):
            수정면적 = 대상일면적 - 블록면적
            대상일인덱스 = 시점인덱스 + idx
            면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
            
        return True, 면적달력
    else:
        print("면적부족으로 배치불가능")
        return False, 면적달력

# %% [markdown]
# # 블록명달력 함수

# %%
def create_블록명달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터:pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
def update_블록명달력(블록명달력:pd.DataFrame, 최선정반:str, 블록데이터:pd.DataFrame, block_names: list, best_st_date: list) -> pd.DataFrame:
    
    달력 = 블록명달력
    날짜집합 = 블록명달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]

    for block_name, 블록착수일 in zip(block_names, best_st_date):

        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        표준공기 = 블록데이터[블록데이터["블록명"]==block_name]["표준공기"].values[0]

        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(block_name)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %% [markdown]
# # 사이즈 달력 함수

# %%
def create_사이즈달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터:pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
def update_사이즈달력(사이즈달력: pd.DataFrame, 최선정반:str, 블록데이터:pd.DataFrame, block_names:list, block_sizes:tuple, best_st_date:list) -> pd.DataFrame:
    
    달력 = 사이즈달력
    날짜집합 = 달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]
        
    for i in range(len(block_names)):
        블록명 = block_names[i]
        블록사이즈 = block_sizes[i]
        블록착수일 = best_st_date[i]
        
        표준공기 = 블록데이터[블록데이터["블록명"]==블록명]["표준공기"].values[0]
        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        
        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(블록사이즈)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %% [markdown]
# # 레이아웃 적합도 함수

# %%
def 정반세팅(사이즈):  #사이즈 = (10, 10)
    surface_width, surface_height = 사이즈[0], 사이즈[1]  # Adjusted to match the provided image for demonstration
    surface = np.zeros((surface_height, surface_width), dtype=int)
    return surface, surface_width, surface_height

# %%
def can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, start_row, start_col, thresh):
    new_width = surface_width - thresh
    new_height = surface_height - thresh
    
#     block_height, block_width = block_height, block_width
    if start_row + block_height > surface_height or start_col + block_width > surface_width:
        return False

    block_area = surface[start_row:start_row+block_height, start_col:start_col+block_width]
    if np.any(block_area != 0):
        return False
    
    if start_row > 0 and np.any(surface[start_row-thresh: start_row, start_col:start_col+block_width] != 0):
        return False
    if start_col > 0 and np.any(surface[start_row: start_row+block_height, start_col-thresh: start_col] != 0):
        return False
    
    return True

# Function to place a block on the surface, if possible
def place_block(surface, block_height, block_width, start_row, start_col, block_id):
    block_height, block_width = block_height, block_width
    surface[start_row:start_row + block_height, start_col:start_col + block_width] = block_id

# Function to find the best fit for a block on the surface
def find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh):
    best_fit_score = float('inf')
    best_position = None
    block_height, block_width = block_height, block_width

    # Iterate over all possible positions on the surface
    for y in range(surface_height - block_height + 1):
        for x in range(surface_width - block_width + 1):
            if can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, y, x, thresh):
                # Calculate a score; here we use the top-left corner (y, x) as the score
                # A lower score means the block is closer to the top-left
                score = y + x
                if score < best_fit_score:
                    best_fit_score = score
                    best_position = (y, x)

    # If a best position was found, place the block there
    if best_position:
        place_block(surface, block_height, block_width, *best_position, block_id)
        return True

    return False  # No fit found

# Function to fit blocks on the surface in order
def fit_blocks_with_thresh(surface, surface_width, surface_height, blocks, names, thresh):
    result = "적합"
    block_id = max(map(max, surface))+1  # Start numbering blocks from 1
    for name, block in zip(names, blocks):
        
        block_height, block_width = block
        if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
            print(f"-----1차검토 부적합 - Block {name} of height {block_height} width {block_width} could not be placed.")
            # result = "부적합"
            
            if block_height != block_width:  # 가로 세로 길이가 같지 않다면...
                ## 가로 세로 길이 바꿔서 검토 -------------------------------------
                block_height, block_width = block_width, block_height
                
                if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
                    print(f"-----2차검토 부적합 - Block {name} of height {block_height} width {block_width} could not be placed.")
                    result = "부적합"
                else:
                    # print(f"2차검토 적합 - Block {name} of height {block_height} width {block_width} could be placed.")
                    result = "적합"
            else:
                pass
        else:
            # print(f"1차검토 적합 - Block {name} of height {block_height} width {block_width} could be placed.")
            result = "적합"
            
        block_id += 1  # Increment block_id for the next block
    return surface, result

# %%
def 정반배치레이아웃적합도(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    # print(f"{block_names}: {block_sizes}")

    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    적합도 = 배치결과[1]
    
    return 적합도

# %% [markdown]
# # 시각화 함수

# %%
def draw1(surface, block_names):
    fig, ax = plt.subplots(figsize=(8, 8))

    cmap = mcolors.ListedColormap(['white'] + ['C{}'.format(i) for i in range(len(block_names))])
    norm = mcolors.BoundaryNorm(np.arange(0.5, len(block_names) + 2), cmap.N)

    ax.imshow(surface, cmap=cmap, norm=norm)

    for y in range(surface.shape[0]):
        for x in range(surface.shape[1]):
            if surface[y, x] != 0:
                ax.text(x, y, str(block_names[surface[y, x]-1]), ha='center', va='center', color='black', fontsize=6)
                
    ax.set_xticks(np.arange(-.5, surface.shape[1], 1), minor=True)
    ax.set_yticks(np.arange(-.5, surface.shape[0], 1), minor=True)
    ax.grid(which="minor", color="black", linestyle='-', linewidth=1)
    ax.tick_params(which="minor", size=0)

    ax.set_xticks([])
    ax.set_yticks([])

    plt.show()

# %%
def 정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
        
    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    배치레이아웃 = 배치결과[0]
    draw1(배치레이아웃, block_names)

# %% [markdown]
# # 생산계획 서브 함수

# %%
def 중량조건체크(target_block):
    가능정반리스트 = []
    블록중량 = 블록데이터[블록데이터["블록명"]==target_block]["중량"].values[0]
    for 정반 in 정반데이터["정반명"]:
        정반가능중량 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반가능중량 > 블록중량:
            가능정반리스트.append(정반)       
    return 가능정반리스트

# %%
def 최장길이체크(target_block:str, 중량가능정반들:list):
    가능정반리스트 = []
    블록최장길이 = 블록데이터[블록데이터["블록명"]==target_block]["최대길이"].values[0]
    for 정반 in 중량가능정반들:
        정반최장길이 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반최장길이 > 블록최장길이:
            가능정반리스트.append(정반)
    return 가능정반리스트

# %%
def 최선착수일후보체크(target_block:str, 길이가능정반들:list, 조기착수금지일수:int):
    result_dict = dict()
    # 블록납기 및 표준공기, 블록면적 확인
    블록데이터["납기"] = 블록데이터["납기"].astype('str')
    블록납기 = 블록데이터[블록데이터["블록명"]==target_block]["납기"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==target_block]["표준공기"].values[0]
    블록면적 = 블록데이터[블록데이터["블록명"]==target_block]["면적"].values[0]
    # 블록 최소착수요구일 확인
    최소착수요구일 = 블록데이터[블록데이터["블록명"]==target_block]["최소착수요구일"].values[0]
    최소착수요구일 = 최소착수요구일.strftime("%Y-%m-%d")
    # 면적달력날짜리스트 확인
    면적달력날짜리스트_datetime = list(면적달력.index)
    면적달력날짜리스트 = [date_obj.strftime("%Y-%m-%d") for date_obj in 면적달력날짜리스트_datetime]
    # 최소착수요구일인덱스 및 한계시점인덱스 확인
    블록납기일인덱스 = 면적달력날짜리스트.index(블록납기)
    최소착수요구일인덱스 = 면적달력날짜리스트.index(최소착수요구일)
    한계시점인덱스 = max(0, 최소착수요구일인덱스 - 조기착수금지일수)
    # print(f"최소착수요구일:{최소착수요구일}, 최소착수요구일인덱스:{최소착수요구일인덱스}, 한계시점인덱스:{한계시점인덱스}")
    
    for 대상정반 in 길이가능정반들:
        정반면적리스트 = 면적달력[f"{대상정반}"].iloc[한계시점인덱스:블록납기일인덱스].values
        # print(f"대상정반:{대상정반}- \n{정반면적리스트}")

        for idx in range(len(정반면적리스트)):
            조회구간면적리스트 = 정반면적리스트[idx:idx+표준공기]
            조회구간최소면적 = min(조회구간면적리스트)
            # print(f"{대상정반} - 조회구간면적리스트: {조회구간면적리스트}, 조회구간최소면적: {조회구간최소면적}, 블록면적: {블록면적}")

            if 조회구간최소면적 >= 블록면적:
                조회시점인덱스 = 한계시점인덱스 + idx
                최선조기착수일 = 면적달력.index[조회시점인덱스]
                result_dict[대상정반] = 최선조기착수일
                break
            else:
                pass
    return result_dict

# %%
 def 최선조기착수대상선택(최선착수일후보):
    values = 최선착수일후보.values()
    unique_values = set(values)

    if len(unique_values) > 1:
        # 최선 날짜가 복수개 있으면 조기 착수일 선택
        최선조기착수정반 = min(최선착수일후보, key=lambda k: 최선착수일후보[k])
        최선조기착수날짜 = 최선착수일후보[최선조기착수정반]
        return (최선조기착수정반, 최선조기착수날짜)
    else:
        # 최선 날짜가 한개면, 랜덤 선택
        random_key = choice(list(최선착수일후보.keys()))
        return (random_key, 최선착수일후보[random_key])

# %% [markdown]
# # 시뮬레이션 실시

# %%
# data_num = "_실행계획_small"
data_num = "_실행계획"

시작년, 시작월, 시작일, 종료년, 종료월 = 2023, 10, 1, 2024, 3

thresh = 1  # 블록 간격(m)
조기착수금지일수 = 7

블록원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="블록데이터")
기배치블록 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="기배치블록")
정반원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="정반데이터")
블록원데이터.shape

착수일가중치, 공기가중치, 크기가중치 = 1, 0.2, 0.1
블록데이터 = 블록데이터전처리(블록원데이터)

중량가중치, 크기가중치 = 0.5, 0.5
정반데이터 = 정반데이터전처리(정반원데이터)
블록데이터.shape, 정반데이터.shape

면적달력 = create_면적달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
블록명달력 = create_블록명달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
사이즈달력 = create_사이즈달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)

기배치블록["블록면적"] = 기배치블록.eval("가로*세로")
기배치블록["사이즈"] = 기배치블록[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
기배치블록["착수일"] = 기배치블록["착수일"].dt.strftime('%Y-%m-%d')
기배치블록["종료일"] = 기배치블록["종료일"].dt.strftime('%Y-%m-%d')
for 블록착수일, 배치블록명, 블록면적, 표준공기, 배치정반 in zip(기배치블록["착수일"], 기배치블록["블록명"], 기배치블록["블록면적"], 기배치블록["공기"], 기배치블록["배치정반"],):
    면적달력 = update_init_면적달력(면적달력, 블록착수일, 배치정반, 블록면적, 표준공기)

# 블록데이터 및 정반데이터 정리
# 달력초기화 및 기진행블록 달력에 반영
block_list = 블록데이터["블록명"].tolist()
정반리스트 = 정반데이터["정반명"].tolist()
print(block_list)

블록명_dict = {key: [] for key in 정반리스트}
착수일자_dict = {key: [] for key in 정반리스트}
사이즈_dict = {key: [] for key in 정반리스트}
배치상태 = []

for _ in tqdm(range(len(block_list))):
    
    target_block = block_list[0]
    print()
    print(f"***** 검토대상블록: {target_block} ---------------------------------------------")

    # 중량조건체크함수  --> 적합 정반리스트
    중량가능정반들 = 중량조건체크(target_block)
    # print(f"중량가능정반들: {중량가능정반들}")

    # 최장길이체크함수  --> 적합 정반리스트
    길이가능정반들 = 최장길이체크(target_block, 중량가능정반들)
    # print(f"길이가능정반들: {길이가능정반들}")

    # 날짜 및 면적 체크후 정반별 최선조기착수일 후보 검토
    최선착수일후보 = 최선착수일후보체크(target_block, 길이가능정반들, 7)      
    print(f"최선착수일후보: {최선착수일후보}")
    
    # 최선 조기착수대상 선택 (착수일자가 빠른 것 우선)
    최선조기착수대상 = 최선조기착수대상선택(최선착수일후보)
    print(f"최선조기착수대상: {최선조기착수대상}")
    최소착수요구일 = 블록데이터[블록데이터["블록명"]==target_block]["최소착수요구일"].values[0]
    최선정반, 최선착수일 = 최선조기착수대상[0], 최선조기착수대상[1]

    # 최선착수일과 최소착수요구일 간격 구하기
    최선착수일 = 최선착수일.date()
    gap = 최소착수요구일 - 최선착수일
    gap = int(gap.days + 1)

    # origin 변수 저장
    origin_블록명 = 블록명_dict[최선정반].copy()
    origin_착수일자 = 착수일자_dict[최선정반].copy()
    origin_사이즈 = 사이즈_dict[최선정반].copy()

    origin_면적달력 = 면적달력.copy()
    origin_블록명달력 = 블록명달력.copy()
    origin_사이즈달력 = 사이즈달력.copy()

    # 달력업데이트 변수 정의
    블록명_dict[최선정반].append(target_block)

    최선착수일 = 최선착수일.strftime("%Y-%m-%d")
    착수일자_dict[최선정반].append(최선착수일)
    
    사이즈 = 블록데이터[블록데이터["블록명"]==target_block]["사이즈"].values[0]
    사이즈_dict[최선정반].append(사이즈)

    # 기타 참고변수
    납기 = 블록데이터[블록데이터["블록명"]==target_block]["납기"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==target_block]["표준공기"].values[0]
    print(f"*** 최선정반: {최선정반}, 납기: {납기}, , 표준공기: {표준공기}, 최소요구착수일: {최소착수요구일}, 최선착수일: {최선착수일}, gap: {gap}, 사이즈: {사이즈}")

    # 레이아웃 체크 함수 ------------------------------------------------------------------------------------------------------------------------------------------------   
    status = "정상배치"
    for g in range(gap):
        print(f">>>> 레이아웃검토: {g}")
    
        레이아웃적합도모음= []
        
        # 최선착수일 순환 계산 가산 계수
        g = 0 if g == 0 else 1
        
        최선착수일 = datetime.strptime(최선착수일, "%Y-%m-%d").date() + timedelta(days= g)
        최선착수일 = 최선착수일.strftime("%Y-%m-%d")
        착수일자_dict[최선정반][-1] = 최선착수일#.strftime("%Y-%m-%d")
        
        print(f"{g}: {블록명_dict[최선정반]}")
        print(f"{g}: {착수일자_dict[최선정반]}")

        블록명달력 = origin_블록명달력
        사이즈달력 = origin_사이즈달력
        
        # 레이아웃 적합도 판단을 위해 임시 배치한 달력을 생성
        임시_블록명달력 = update_블록명달력(블록명달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 착수일자_dict[최선정반])
        임시_사이즈달력 = update_사이즈달력(사이즈달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 사이즈_dict[최선정반], 착수일자_dict[최선정반])

        for k in range(표준공기):
            레이아웃배치검토시작일 = datetime.strptime(최선착수일, "%Y-%m-%d")  # + timedelta(days=g)
            new_date = 레이아웃배치검토시작일 + timedelta(days=k)
            레이아웃검토날짜 = new_date.strftime("%Y-%m-%d") 
            print(f"--- g: {g}, k: {k}, 레이아웃배치검토시작일: {레이아웃배치검토시작일.strftime('%Y-%m-%d')}, 레이아웃검토날짜: {레이아웃검토날짜}")

            적합도 = 정반배치레이아웃적합도(최선정반, 정반데이터, 레이아웃검토날짜, 임시_블록명달력, 임시_사이즈달력)

            레이아웃적합도모음.append(적합도)

        print(f"레이아웃적합도모음: {레이아웃적합도모음}")
        
        if "부적합" not in  레이아웃적합도모음:

            레이아웃검토후최선착수일 = 레이아웃배치검토시작일.strftime("%Y-%m-%d")
            print(f"레이아웃검토후최선착수일:  {레이아웃검토후최선착수일}")

            착수일자_dict[최선정반] = 착수일자_dict[최선정반][:-1]
            착수일자_dict[최선정반].append(레이아웃검토후최선착수일)
            
            # 달력 업데이트
            면적달력결과 = update_면적달력1(면적달력, 최선정반, 레이아웃검토후최선착수일, target_block, 블록데이터)
            print(f"면적달력 업데이트 결과: {면적달력결과[0]}")

            if 면적달력결과[0] == True:
                면적달력 = 면적달력결과[1]
                블록명달력 = update_블록명달력(블록명달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 착수일자_dict[최선정반])
                사이즈달력 = update_사이즈달력(사이즈달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 사이즈_dict[최선정반], 착수일자_dict[최선정반])
                status = "정상배치"
                break
                
            else:
                
                면적달력 = origin_면적달력            
                블록명달력 = origin_블록명달력
                사이즈달력 = origin_사이즈달력
           
        else:
            status = "배치불가"
            print("부적합")
            print()
            
            면적달력 = origin_면적달력            
            블록명달력 = origin_블록명달력
            사이즈달력 = origin_사이즈달력
    
    
    면적달력 = origin_면적달력            
    블록명달력 = origin_블록명달력
    사이즈달력 = origin_사이즈달력
     
    배치상태.append(status)
    block_list.remove(target_block)
    print("="*80)
# Out:
# (123, 6)
# ((123, 12), (2, 8))
# ['S15', 'S24', 'S33', 'S19', 'S16', 'S25', 'S21', 'S17', 'S32', 'S18', 'S14', 'S13', 'S20', 'S22', 'S23', 'S26', 'S36', 'S27', 'S35', 'S45', 'S49', 'S41', 'S34', 'S39', 'S46', 'S40', 'S47', 'S52', 'S38', 'S51', 'S50', 'S57', 'S67', 'S62', 'S30', 'S28', 'S29', 'S31', 'S43', 'S44', 'S37', 'S64', 'S63', 'S42', 'S58', 'S55', 'S59', 'S70', 'S56', 'S48', 'S68', 'S65', 'S66', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S75', 'S74', 'S83', 'S73', 'S72', 'S90', 'S94', 'S77', 'S97', 'S76', 'S80', 'S60', 'S105', 'S61', 'S84', 'S96', 'S99', 'S87', 'S78', 'S98', 'S79', 'S103', 'S102', 'S85', 'S89', 'S104', 'S95', 'S112', 'S88', 'S93', 'S111', 'S92', 'S91', 'S108', 'S109', 'S107', 'S106', 'S119', 'S127', 'S126', 'S135', 'S134', 'S113', 'S116', 'S115', 'S124', 'S114', 'S120', 'S132', 'S128', 'S110', 'S118', 'S121', 'S101', 'S100', 'S125', 'S133', 'S122', 'S117', 'S130', 'S129', 'S123', 'S131']
#   0%|          | 0/123 [00:00<?, ?it/s]
# ***** 검토대상블록: S15 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-13, , 표준공기: 10, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (15, 14)
# >>>> 레이아웃검토: 0
# 0: ['S15']
# 0: ['2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 241, 블록면적: 210
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S24 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-02 00:00:00'), 'A': Timestamp('2023-11-02 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-02 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-21, , 표준공기: 12, 최소요구착수일: 2023-11-09, 최선착수일: 2023-11-02, gap: 8, 사이즈: (18, 14)
# >>>> 레이아웃검토: 0
# 0: ['S24']
# 0: ['2023-11-02']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-02
# 조회기간 최소면적: 547, 블록면적: 252
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S33 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-07 00:00:00'), 'A': Timestamp('2023-11-07 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-07 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-27, , 표준공기: 13, 최소요구착수일: 2023-11-14, 최선착수일: 2023-11-07, gap: 8, 사이즈: (19, 15)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S33']
# 0: ['2023-10-27', '2023-11-07']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-13
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-14
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-15
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-16
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-17
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-18
# --- g: 0, k: 12, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-19
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-07
# 조회기간 최소면적: 1007, 블록면적: 285
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S19 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-15, , 표준공기: 12, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (14, 7)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19']
# 0: ['2023-11-02', '2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-07
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 467, 블록면적: 98
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S16 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-14, , 표준공기: 11, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (14, 5)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-06
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 467, 블록면적: 70
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S25 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-03 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-21, , 표준공기: 11, 최소요구착수일: 2023-11-10, 최선착수일: 2023-11-03, gap: 8, 사이즈: (19, 13)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-03
# 조회기간 최소면적: 659, 블록면적: 247
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S21 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-02 00:00:00'), 'A': Timestamp('2023-11-02 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-02 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-17, , 표준공기: 8, 최소요구착수일: 2023-11-09, 최선착수일: 2023-11-02, gap: 8, 사이즈: (17, 15)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25', 'S21']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-02']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-02
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 1
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-03']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 2
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-04']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-05']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-06']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 5
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-07']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-14
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 6
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-08']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-15
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 7
# 1: ['S24', 'S19', 'S16', 'S25', 'S21']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-16
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합']
# 부적합
#
# ================================================================================
#
# ***** 검토대상블록: S17 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-30 00:00:00'), 'A': Timestamp('2023-10-30 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-30 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-14, , 표준공기: 8, 최소요구착수일: 2023-11-06, 최선착수일: 2023-10-30, gap: 8, 사이즈: (15, 13)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-10-30']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 1
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-10-31']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-10-31
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-01
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-02
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 2
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-01']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-01
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-02
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-01, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-02']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-02
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-03']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 5
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-04']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 6
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-05']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 7
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S21 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S21 of height 15 width 17 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# ================================================================================
#
# ***** 검토대상블록: S32 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-10 00:00:00'), 'A': Timestamp('2023-11-10 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-10 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-27, , 표준공기: 10, 최소요구착수일: 2023-11-17, 최선착수일: 2023-11-10, gap: 8, 사이즈: (17, 15)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S33', 'S32']
# 0: ['2023-10-27', '2023-11-07', '2023-11-10']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-13
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-14
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-15
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-16
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-17
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-18
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-19
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-10
# 조회기간 최소면적: 1176, 블록면적: 255
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S18 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-30 00:00:00'), 'A': Timestamp('2023-10-30 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-30 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-15, , 표준공기: 9, 최소요구착수일: 2023-11-06, 최선착수일: 2023-10-30, gap: 8, 사이즈: (14, 7)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-30, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-30
# 조회기간 최소면적: 467, 블록면적: 98
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S14 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-26 00:00:00'), 'A': Timestamp('2023-10-26 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-26 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-09, , 표준공기: 7, 최소요구착수일: 2023-11-02, 최선착수일: 2023-10-26, gap: 8, 사이즈: (13, 13)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-26
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-11-01
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-26
# 조회기간 최소면적: 467, 블록면적: 169
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S13 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-26 00:00:00'), 'A': Timestamp('2023-10-26 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-26 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-08, , 표준공기: 6, 최소요구착수일: 2023-11-02, 최선착수일: 2023-10-26, gap: 8, 사이즈: (15, 14)
# >>>> 레이아웃검토: 0
# 0: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13']
# 0: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-26
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-31
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-26
# 조회기간 최소면적: 467, 블록면적: 210
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S20 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-31 00:00:00'), 'A': Timestamp('2023-10-31 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-10-31 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-15, , 표준공기: 8, 최소요구착수일: 2023-11-07, 최선착수일: 2023-10-31, gap: 8, 사이즈: (14, 13)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S33', 'S32', 'S20']
# 0: ['2023-10-27', '2023-11-07', '2023-11-10', '2023-10-31']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-31, 레이아웃검토날짜: 2023-11-07
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-31
# 조회기간 최소면적: 241, 블록면적: 182
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S22 ---------------------------------------------
# ...
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-06']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-06
# -----1차검토 부적합 - Block S125 of height 19 width 15 could not be placed.
# -----2차검토 부적합 - Block S125 of height 15 width 19 could not be placed.
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-07
# -----1차검토 부적합 - Block S125 of height 19 width 15 could not be placed.
# -----2차검토 부적합 - Block S125 of height 15 width 19 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-08
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-09
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-06, 레이아웃검토날짜: 2024-03-12
# 레이아웃적합도모음: ['적합', '적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13', 'S26', 'S45', 'S49', 'S34', 'S39', 'S46', 'S47', 'S52', 'S38', 'S62', 'S31', 'S43', 'S37', 'S64', 'S42', 'S59', 'S56', 'S48', 'S68', 'S65', 'S69', 'S81', 'S82', 'S71', 'S74', 'S72', 'S77', 'S80', 'S60', 'S96', 'S99', 'S87', 'S78', 'S98', 'S103', 'S102', 'S104', 'S95', 'S88', 'S93', 'S91', 'S108', 'S119', 'S135', 'S124', 'S114', 'S120', 'S128', 'S121', 'S125', 'S133', 'S117', 'S123', 'S131']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-07']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-07
# -----1차검토 부적합 - Block S125 of height 19 width 15 could not be placed.
# -----2차검토 부적합 - Block S125 of height 15 width 19 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-08
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-09
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-12
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-07, 레이아웃검토날짜: 2024-03-13
# 레이아웃적합도모음: ['적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13', 'S26', 'S45', 'S49', 'S34', 'S39', 'S46', 'S47', 'S52', 'S38', 'S62', 'S31', 'S43', 'S37', 'S64', 'S42', 'S59', 'S56', 'S48', 'S68', 'S65', 'S69', 'S81', 'S82', 'S71', 'S74', 'S72', 'S77', 'S80', 'S60', 'S96', 'S99', 'S87', 'S78', 'S98', 'S103', 'S102', 'S104', 'S95', 'S88', 'S93', 'S91', 'S108', 'S119', 'S135', 'S124', 'S114', 'S120', 'S128', 'S121', 'S125', 'S133', 'S117', 'S123', 'S131']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-08']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-08
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-09
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-12
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-13
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-08, 레이아웃검토날짜: 2024-03-14
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 5
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13', 'S26', 'S45', 'S49', 'S34', 'S39', 'S46', 'S47', 'S52', 'S38', 'S62', 'S31', 'S43', 'S37', 'S64', 'S42', 'S59', 'S56', 'S48', 'S68', 'S65', 'S69', 'S81', 'S82', 'S71', 'S74', 'S72', 'S77', 'S80', 'S60', 'S96', 'S99', 'S87', 'S78', 'S98', 'S103', 'S102', 'S104', 'S95', 'S88', 'S93', 'S91', 'S108', 'S119', 'S135', 'S124', 'S114', 'S120', 'S128', 'S121', 'S125', 'S133', 'S117', 'S123', 'S131']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-09']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-09
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-12
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-13
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-14
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-09, 레이아웃검토날짜: 2024-03-15
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 6
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13', 'S26', 'S45', 'S49', 'S34', 'S39', 'S46', 'S47', 'S52', 'S38', 'S62', 'S31', 'S43', 'S37', 'S64', 'S42', 'S59', 'S56', 'S48', 'S68', 'S65', 'S69', 'S81', 'S82', 'S71', 'S74', 'S72', 'S77', 'S80', 'S60', 'S96', 'S99', 'S87', 'S78', 'S98', 'S103', 'S102', 'S104', 'S95', 'S88', 'S93', 'S91', 'S108', 'S119', 'S135', 'S124', 'S114', 'S120', 'S128', 'S121', 'S125', 'S133', 'S117', 'S123', 'S131']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-10']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S123 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S123 of height 12 width 16 could not be placed.
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-12
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-13
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-14
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-15
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-10, 레이아웃검토날짜: 2024-03-16
# 레이아웃적합도모음: ['부적합', '부적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 7
# 1: ['S24', 'S19', 'S16', 'S25', 'S21', 'S17', 'S18', 'S14', 'S13', 'S26', 'S45', 'S49', 'S34', 'S39', 'S46', 'S47', 'S52', 'S38', 'S62', 'S31', 'S43', 'S37', 'S64', 'S42', 'S59', 'S56', 'S48', 'S68', 'S65', 'S69', 'S81', 'S82', 'S71', 'S74', 'S72', 'S77', 'S80', 'S60', 'S96', 'S99', 'S87', 'S78', 'S98', 'S103', 'S102', 'S104', 'S95', 'S88', 'S93', 'S91', 'S108', 'S119', 'S135', 'S124', 'S114', 'S120', 'S128', 'S121', 'S125', 'S133', 'S117', 'S123', 'S131']
# 1: ['2023-11-02', '2023-10-27', '2023-10-27', '2023-11-03', '2023-11-09', '2023-11-06', '2023-10-30', '2023-10-26', '2023-10-26', '2023-11-08', '2023-11-24', '2023-11-30', '2023-11-13', '2023-11-21', '2023-11-29', '2023-11-30', '2023-12-11', '2023-11-20', '2023-12-13', '2023-11-15', '2023-11-27', '2023-11-21', '2023-12-12', '2023-12-04', '2023-12-11', '2023-12-18', '2023-12-05', '2023-12-21', '2023-12-18', '2023-12-20', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-05', '2023-12-29', '2024-01-10', '2024-01-16', '2023-12-20', '2024-01-22', '2024-01-23', '2024-01-16', '2024-01-05', '2024-01-26', '2024-01-26', '2024-02-05', '2024-01-31', '2024-02-05', '2024-01-16', '2024-01-29', '2024-01-18', '2024-02-07', '2024-02-16', '2024-02-22', '2024-02-26', '2024-02-14', '2024-02-26', '2024-02-28', '2024-02-28', '2024-03-04', '2024-03-09', '2024-02-26', '2024-03-04', '2024-03-11']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-11
# -----1차검토 부적합 - Block S131 of height 16 width 12 could not be placed.
# -----2차검토 부적합 - Block S131 of height 12 width 16 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-12
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-13
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-14
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-15
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-16
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-11, 레이아웃검토날짜: 2024-03-17
# 레이아웃적합도모음: ['부적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# ================================================================================

# %%
len(배치상태), 배치상태.count("정상배치"), 배치상태.count("배치불가")
# 배치상태
# Out:
# (123, 97, 26)

# %%
블록명달력
# Out:
#                                                      B  \
# 2023-10-01                                          []
# 2023-10-02                                          []
# 2023-10-03                                          []
# 2023-10-04                                          []
# 2023-10-05                                          []
# 2023-10-06                                          []
# 2023-10-07                                          []
# 2023-10-08                                          []
# 2023-10-09                                          []
# 2023-10-10                                          []
# 2023-10-11                                          []
# 2023-10-12                                          []
# 2023-10-13                                          []
# 2023-10-14                                          []
# 2023-10-15                                          []
# 2023-10-16                                          []
# 2023-10-17                                          []
# 2023-10-18                                          []
# 2023-10-19                                          []
# 2023-10-20                                          []
# 2023-10-21                                          []
# 2023-10-22                                          []
# 2023-10-23                                          []
# 2023-10-24                                          []
# 2023-10-25                                          []
# 2023-10-26                                       [S13]
# 2023-10-27                                  [S19, S13]
# 2023-10-28                                  [S19, S13]
# 2023-10-29                                  [S19, S13]
# 2023-10-30                             [S19, S17, S13]
# 2023-10-31                             [S19, S17, S13]
# 2023-11-01                                  [S19, S17]
# 2023-11-02                             [S24, S19, S17]
# 2023-11-03                        [S24, S19, S17, S23]
# 2023-11-04                        [S24, S19, S17, S23]
# 2023-11-05                        [S24, S19, S17, S23]
# 2023-11-06                        [S24, S19, S17, S23]
# 2023-11-07                   [S24, S33, S19, S20, S23]
# 2023-11-08                        [S24, S33, S20, S23]
# 2023-11-09                        [S24, S33, S20, S23]
# 2023-11-10                        [S24, S33, S20, S23]
# 2023-11-11                        [S24, S33, S20, S23]
# 2023-11-12                        [S24, S33, S20, S23]
# 2023-11-13                        [S24, S33, S20, S23]
# 2023-11-14                        [S33, S32, S20, S26]
# 2023-11-15              [S33, S32, S26, S27, S30, S28]
# 2023-11-16              [S33, S32, S26, S27, S30, S28]
# 2023-11-17              [S33, S32, S26, S27, S30, S28]
# 2023-11-18              [S33, S32, S26, S27, S30, S28]
# 2023-11-19              [S33, S32, S26, S27, S30, S28]
# 2023-11-20                   [S32, S26, S36, S27, S38]
# 2023-11-21              [S32, S26, S36, S27, S40, S38]
# 2023-11-22         [S32, S26, S36, S27, S35, S40, S38]
# 2023-11-23                   [S32, S36, S35, S40, S38]
# 2023-11-24                        [S36, S35, S40, S38]
# 2023-11-25                        [S36, S35, S40, S38]
# 2023-11-26                        [S36, S35, S40, S38]
# 2023-11-27                        [S36, S35, S40, S43]
# 2023-11-28                        [S36, S35, S40, S43]
# 2023-11-29                             [S40, S43, S42]
# 2023-11-30                             [S49, S43, S42]
# 2023-12-01                             [S49, S43, S42]
# 2023-12-02                             [S49, S43, S42]
# 2023-12-03                                  [S49, S43]
# 2023-12-04                             [S49, S52, S43]
# 2023-12-05                                  [S49, S52]
# 2023-12-06                        [S49, S52, S54, S53]
# 2023-12-07                        [S49, S52, S54, S53]
# 2023-12-08                        [S49, S52, S54, S53]
# 2023-12-09                        [S49, S52, S54, S53]
# 2023-12-10                        [S49, S52, S54, S53]
# 2023-12-11              [S49, S52, S51, S50, S54, S53]
# 2023-12-12              [S52, S51, S50, S63, S54, S53]
# 2023-12-13                        [S51, S50, S57, S63]
# 2023-12-14                        [S51, S50, S57, S63]
# 2023-12-15                        [S51, S50, S57, S63]
# 2023-12-16                        [S51, S50, S57, S63]
# 2023-12-17                        [S51, S50, S57, S63]
# 2023-12-18                   [S51, S50, S57, S63, S56]
# 2023-12-19              [S57, S67, S63, S58, S56, S69]
# 2023-12-20         [S57, S67, S63, S58, S56, S69, S61]
# 2023-12-21         [S57, S67, S63, S58, S56, S69, S61]
# 2023-12-22              [S57, S67, S63, S58, S56, S69]
# 2023-12-23              [S57, S67, S63, S58, S56, S69]
# 2023-12-24              [S57, S67, S63, S58, S56, S69]
# 2023-12-25              [S67, S63, S58, S70, S68, S69]
# 2023-12-26              [S67, S63, S58, S70, S68, S69]
# 2023-12-27                        [S67, S70, S68, S69]
# 2023-12-28                        [S67, S70, S68, S69]
# 2023-12-29                        [S67, S70, S68, S72]
# 2023-12-30                        [S67, S70, S68, S72]
# 2023-12-31                        [S67, S70, S68, S72]
# 2024-01-01                        [S67, S70, S68, S72]
# 2024-01-02                        [S67, S70, S68, S72]
# 2024-01-03                             [S70, S68, S72]
# 2024-01-04                        [S70, S82, S75, S72]
# 2024-01-05                             [S70, S82, S75]
# 2024-01-06                             [S70, S82, S75]
# 2024-01-07                                  [S82, S75]
# 2024-01-08                             [S82, S75, S83]
# 2024-01-09                             [S82, S75, S83]
# 2024-01-10                             [S82, S75, S83]
# 2024-01-11                             [S82, S83, S80]
# 2024-01-12                        [S82, S83, S80, S85]
# 2024-01-13                        [S82, S83, S80, S85]
# 2024-01-14                        [S82, S83, S80, S85]
# 2024-01-15                   [S82, S83, S80, S85, S89]
# 2024-01-16                        [S83, S80, S85, S89]
# 2024-01-17                        [S80, S87, S85, S89]
# 2024-01-18                        [S87, S85, S89, S92]
# 2024-01-19                        [S97, S87, S89, S92]
# 2024-01-20                        [S97, S87, S89, S92]
# 2024-01-21                        [S97, S87, S89, S92]
# 2024-01-22                        [S97, S96, S87, S92]
# 2024-01-23                        [S97, S96, S87, S92]
# 2024-01-24                             [S97, S96, S92]
# 2024-01-25                                  [S97, S96]
# 2024-01-26                            [S97, S105, S96]
# 2024-01-27                            [S97, S105, S96]
# 2024-01-28                            [S97, S105, S96]
# 2024-01-29                      [S97, S105, S96, S102]
# 2024-01-30                      [S97, S105, S96, S102]
# 2024-01-31                      [S97, S105, S96, S102]
# 2024-02-01                      [S97, S105, S96, S102]
# 2024-02-02                      [S97, S105, S96, S102]
# 2024-02-03                      [S97, S105, S96, S102]
# 2024-02-04                      [S97, S105, S96, S102]
# 2024-02-05                 [S97, S105, S96, S102, S95]
# 2024-02-06                [S97, S105, S102, S95, S106]
# 2024-02-07                     [S105, S102, S95, S106]
# 2024-02-08                           [S105, S95, S106]
# 2024-02-09                           [S105, S95, S106]
# 2024-02-10                           [S105, S95, S106]
# 2024-02-11                           [S105, S95, S106]
# 2024-02-12                           [S105, S95, S106]
# 2024-02-13                                          []
# 2024-02-14                                      [S116]
# 2024-02-15                                      [S116]
# 2024-02-16                                [S119, S116]
# 2024-02-17                                [S119, S116]
# 2024-02-18                                [S119, S116]
# 2024-02-19                                [S119, S116]
# 2024-02-20                                [S119, S116]
# 2024-02-21                    [S119, S116, S115, S114]
# 2024-02-22                    [S119, S127, S115, S114]
# 2024-02-23              [S119, S127, S115, S114, S118]
# 2024-02-24              [S119, S127, S115, S114, S118]
# 2024-02-25              [S119, S127, S115, S114, S118]
# 2024-02-26        [S127, S115, S114, S128, S118, S117]
# 2024-02-27        [S127, S115, S114, S128, S118, S117]
# 2024-02-28  [S127, S115, S114, S128, S118, S121, S117]
# 2024-02-29        [S127, S132, S128, S118, S121, S117]
# 2024-03-01                    [S127, S132, S128, S121]
# 2024-03-02                    [S127, S132, S128, S121]
# 2024-03-03                    [S127, S132, S128, S121]
# 2024-03-04        [S127, S132, S128, S121, S122, S123]
# 2024-03-05        [S127, S132, S128, S121, S122, S123]
# 2024-03-06                    [S132, S121, S122, S123]
# 2024-03-07                    [S132, S133, S122, S123]
# 2024-03-08              [S132, S133, S122, S130, S123]
# 2024-03-09              [S132, S133, S122, S130, S123]
# 2024-03-10              [S132, S133, S122, S130, S123]
# 2024-03-11                    [S132, S133, S130, S129]
# 2024-03-12                          [S133, S130, S129]
# 2024-03-13                          [S133, S130, S129]
# 2024-03-14                          [S133, S130, S129]
# 2024-03-15                                      [S129]
# 2024-03-16                                      [S129]
# 2024-03-17                                      [S129]
# 2024-03-18                                      [S129]
# 2024-03-19                                          []
# 2024-03-20                                          []
# 2024-03-21                                          []
# 2024-03-22                                          []
# 2024-03-23                                          []
# 2024-03-24                                          []
# 2024-03-25                                          []
# 2024-03-26                                          []
# 2024-03-27                                          []
# 2024-03-28                                          []
# 2024-03-29                                          []
# 2024-03-30                                          []
# 2024-03-31                                          []
#
#                                                      A
# 2023-10-01                                          []
# 2023-10-02                                          []
# 2023-10-03                                          []
# 2023-10-04                                          []
# 2023-10-05                                          []
# 2023-10-06                                          []
# 2023-10-07                                          []
# 2023-10-08                                          []
# 2023-10-09                                          []
# 2023-10-10                                          []
# 2023-10-11                                          []
# 2023-10-12                                          []
# 2023-10-13                                          []
# 2023-10-14                                          []
# 2023-10-15                                          []
# 2023-10-16                                          []
# 2023-10-17                                          []
# 2023-10-18                                          []
# 2023-10-19                                          []
# 2023-10-20                                          []
# 2023-10-21                                          []
# 2023-10-22                                          []
# 2023-10-23                                          []
# 2023-10-24                                          []
# 2023-10-25                                          []
# 2023-10-26                                       [S14]
# 2023-10-27                             [S15, S16, S14]
# 2023-10-28                             [S15, S16, S14]
# 2023-10-29                             [S15, S16, S14]
# 2023-10-30                        [S15, S16, S18, S14]
# 2023-10-31                        [S15, S16, S18, S14]
# 2023-11-01                        [S15, S16, S18, S14]
# 2023-11-02                             [S15, S16, S18]
# 2023-11-03                   [S15, S16, S25, S18, S22]
# 2023-11-04                   [S15, S16, S25, S18, S22]
# 2023-11-05                   [S15, S16, S25, S18, S22]
# 2023-11-06                   [S16, S25, S21, S18, S22]
# 2023-11-07                        [S25, S21, S18, S22]
# 2023-11-08                             [S25, S21, S22]
# 2023-11-09                             [S25, S21, S22]
# 2023-11-10                             [S25, S21, S22]
# 2023-11-11                             [S25, S21, S22]
# 2023-11-12                             [S25, S21, S22]
# 2023-11-13                             [S25, S21, S22]
# 2023-11-14                                       [S34]
# 2023-11-15                             [S34, S29, S31]
# 2023-11-16                             [S34, S29, S31]
# 2023-11-17                             [S34, S29, S31]
# 2023-11-18                             [S34, S29, S31]
# 2023-11-19                             [S34, S29, S31]
# 2023-11-20                                       [S34]
# 2023-11-21                                  [S39, S37]
# 2023-11-22                             [S41, S39, S37]
# 2023-11-23                             [S41, S39, S37]
# 2023-11-24                        [S45, S41, S39, S37]
# 2023-11-25                        [S45, S41, S39, S37]
# 2023-11-26                        [S45, S41, S39, S37]
# 2023-11-27                        [S45, S41, S39, S44]
# 2023-11-28                        [S45, S41, S39, S44]
# 2023-11-29                        [S45, S41, S46, S44]
# 2023-11-30                   [S45, S41, S46, S47, S44]
# 2023-12-01                        [S45, S46, S47, S44]
# 2023-12-02                        [S45, S46, S47, S44]
# 2023-12-03                        [S45, S46, S47, S44]
# 2023-12-04                   [S45, S46, S47, S44, S48]
# 2023-12-05                             [S46, S47, S48]
# 2023-12-06                        [S46, S47, S55, S48]
# 2023-12-07                        [S46, S47, S55, S48]
# 2023-12-08                        [S46, S47, S55, S48]
# 2023-12-09                        [S46, S47, S55, S48]
# 2023-12-10                        [S46, S47, S55, S48]
# 2023-12-11                                  [S55, S59]
# 2023-12-12                             [S64, S55, S59]
# 2023-12-13                        [S62, S64, S55, S59]
# 2023-12-14                             [S62, S64, S59]
# 2023-12-15                             [S62, S64, S59]
# 2023-12-16                             [S62, S64, S59]
# 2023-12-17                             [S62, S64, S59]
# 2023-12-18                   [S62, S64, S59, S65, S66]
# 2023-12-19                   [S62, S64, S59, S65, S66]
# 2023-12-20              [S62, S64, S59, S65, S66, S60]
# 2023-12-21                   [S62, S64, S65, S66, S60]
# 2023-12-22                        [S62, S64, S65, S66]
# 2023-12-23                        [S62, S64, S65, S66]
# 2023-12-24                        [S62, S64, S65, S66]
# 2023-12-25                        [S62, S64, S65, S66]
# 2023-12-26                             [S64, S65, S66]
# 2023-12-27                                  [S65, S66]
# 2023-12-28                                  [S65, S66]
# 2023-12-29                                  [S71, S73]
# 2023-12-30                                  [S71, S73]
# 2023-12-31                                  [S71, S73]
# 2024-01-01                        [S71, S74, S73, S76]
# 2024-01-02                        [S71, S74, S73, S76]
# 2024-01-03                        [S71, S74, S73, S76]
# 2024-01-04                   [S81, S71, S74, S73, S76]
# 2024-01-05                   [S81, S74, S77, S76, S78]
# 2024-01-06                   [S81, S74, S77, S76, S78]
# 2024-01-07                   [S81, S74, S77, S76, S78]
# 2024-01-08                             [S81, S77, S78]
# 2024-01-09                             [S81, S77, S78]
# 2024-01-10                        [S81, S77, S84, S78]
# 2024-01-11                        [S81, S86, S84, S78]
# 2024-01-12                             [S81, S86, S84]
# 2024-01-13                             [S81, S86, S84]
# 2024-01-14                             [S81, S86, S84]
# 2024-01-15                             [S81, S86, S84]
# 2024-01-16                        [S86, S84, S79, S88]
# 2024-01-17                        [S86, S84, S79, S88]
# 2024-01-18                        [S86, S94, S79, S88]
# 2024-01-19                        [S86, S94, S79, S88]
# 2024-01-20                             [S86, S94, S88]
# 2024-01-21                             [S86, S94, S88]
# 2024-01-22                             [S90, S94, S93]
# 2024-01-23                        [S90, S94, S99, S93]
# 2024-01-24                        [S90, S94, S99, S93]
# 2024-01-25                   [S90, S94, S99, S93, S91]
# 2024-01-26             [S90, S94, S99, S98, S103, S91]
# 2024-01-27             [S90, S94, S99, S98, S103, S91]
# 2024-01-28             [S90, S94, S99, S98, S103, S91]
# 2024-01-29             [S90, S94, S99, S98, S103, S91]
# 2024-01-30             [S90, S94, S99, S98, S103, S91]
# 2024-01-31            [S94, S99, S98, S103, S104, S91]
# 2024-02-01                 [S94, S99, S98, S103, S104]
# 2024-02-02                 [S94, S99, S98, S103, S104]
# 2024-02-03                 [S94, S99, S98, S103, S104]
# 2024-02-04                 [S94, S99, S98, S103, S104]
# 2024-02-05                 [S94, S99, S98, S103, S104]
# 2024-02-06          [S99, S98, S103, S104, S101, S100]
# 2024-02-07        [S103, S104, S108, S107, S101, S100]
# 2024-02-08              [S104, S112, S111, S108, S107]
# 2024-02-09              [S104, S112, S111, S108, S107]
# 2024-02-10              [S104, S112, S111, S108, S107]
# 2024-02-11              [S104, S112, S111, S108, S107]
# 2024-02-12              [S112, S111, S108, S107, S113]
# 2024-02-13              [S112, S111, S108, S107, S113]
# 2024-02-14        [S112, S111, S108, S109, S107, S113]
# 2024-02-15        [S112, S111, S108, S109, S107, S113]
# 2024-02-16              [S112, S111, S109, S113, S110]
# 2024-02-17              [S112, S111, S109, S113, S110]
# 2024-02-18              [S112, S111, S109, S113, S110]
# 2024-02-19                          [S109, S113, S110]
# 2024-02-20                                [S109, S110]
# 2024-02-21                                [S109, S110]
# 2024-02-22                    [S109, S126, S135, S110]
# 2024-02-23                                [S126, S135]
# 2024-02-24                                [S126, S135]
# 2024-02-25                                [S126, S135]
# 2024-02-26                          [S126, S135, S120]
# 2024-02-27                          [S126, S135, S120]
# 2024-02-28                          [S126, S135, S120]
# 2024-02-29              [S126, S135, S134, S124, S120]
# 2024-03-01              [S126, S135, S134, S124, S120]
# 2024-03-02              [S126, S135, S134, S124, S120]
# 2024-03-03              [S126, S135, S134, S124, S120]
# 2024-03-04  [S126, S135, S134, S124, S120, S125, S131]
# 2024-03-05  [S126, S135, S134, S124, S120, S125, S131]
# 2024-03-06                    [S134, S124, S125, S131]
# 2024-03-07                    [S134, S124, S125, S131]
# 2024-03-08                    [S134, S124, S125, S131]
# 2024-03-09                    [S134, S124, S125, S131]
# 2024-03-10                    [S134, S124, S125, S131]
# 2024-03-11                          [S134, S124, S125]
# 2024-03-12                                      [S134]
# 2024-03-13                                          []
# 2024-03-14                                          []
# 2024-03-15                                          []
# 2024-03-16                                          []
# 2024-03-17                                          []
# 2024-03-18                                          []
# 2024-03-19                                          []
# 2024-03-20                                          []
# 2024-03-21                                          []
# 2024-03-22                                          []
# 2024-03-23                                          []
# 2024-03-24                                          []
# 2024-03-25                                          []
# 2024-03-26                                          []
# 2024-03-27                                          []
# 2024-03-28                                          []
# 2024-03-29                                          []
# 2024-03-30                                          []
# 2024-03-31                                          []

# %% [markdown]
# # 레이아웃 조회

# %%
# 연속조회
idx, 조회일수 = 34, 50
정반 = "A"
for 조회날짜 in 면적달력.index.strftime('%Y-%m-%d')[idx:idx+조회일수]:
    print(조회날짜)
    정반배치레이아웃(정반, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)
# Out:
# 2023-11-04
# 1차검토 부적합 - Block S22 of height 17 width 5 could not be placed.
# 2023-11-05
# 1차검토 부적합 - Block S22 of height 17 width 5 could not be placed.
# 2023-11-06
# 1차검토 부적합 - Block S18 of height 14 width 7 could not be placed.
# 2023-11-07
# 1차검토 부적합 - Block S22 of height 17 width 5 could not be placed.
# 2023-11-08
# 2023-11-09
# 2023-11-10
# 2023-11-11
# 2023-11-12
# 2023-11-13
# 2023-11-14
# 2023-11-15
# 2023-11-16
# 2023-11-17
# 2023-11-18
# 2023-11-19
# 2023-11-20
# 2023-11-21
# 2023-11-22
# 2023-11-23
# 2023-11-24
# 2023-11-25
# 2023-11-26
# 2023-11-27
# 1차검토 부적합 - Block S44 of height 17 width 5 could not be placed.
# 2023-11-28
# 1차검토 부적합 - Block S44 of height 17 width 5 could not be placed.
# 2023-11-29
# 1차검토 부적합 - Block S44 of height 17 width 5 could not be placed.
# 2023-11-30
# 1차검토 부적합 - Block S47 of height 15 width 8 could not be placed.
# 1차검토 부적합 - Block S44 of height 17 width 5 could not be placed.
# 2023-12-01
# 2023-12-02
# 2023-12-03
# 2023-12-04
# 1차검토 부적합 - Block S48 of height 14 width 8 could not be placed.
# 2023-12-05
# 2023-12-06
# 2023-12-07
# 2023-12-08
# 2023-12-09
# 2023-12-10
# 2023-12-11
# 2023-12-12
# 2023-12-13
# 1차검토 부적합 - Block S59 of height 15 width 7 could not be placed.
# 2023-12-14
# 2023-12-15
# 2023-12-16
# 2023-12-17
# 2023-12-18
# 1차검토 부적합 - Block S66 of height 17 width 5 could not be placed.
# 2023-12-19
# 1차검토 부적합 - Block S66 of height 17 width 5 could not be placed.
# 2023-12-20
# 1차검토 부적합 - Block S66 of height 17 width 5 could not be placed.
# 2023-12-21
# 2023-12-22
# 2023-12-23

# %%
# 개별조회
정반명 = "A"
조회날짜 =  "2023-11-14"
정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)

# %%
# 개별조회
정반명 = "B"
조회날짜 =  조회날짜
정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)
# Out:
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
