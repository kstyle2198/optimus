# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from random import random, randrange, choice, shuffle
from datetime import datetime, timedelta, date
from itertools import combinations
from pprint import pprint
import calendar
import plotly.express as px
import time

import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

import warnings
warnings.filterwarnings('ignore')

from IPython.core.interactiveshell import InteractiveShell 
InteractiveShell.ast_node_interactivity = "all" # Cell의 모든 반환값 출력

pd.set_option('display.max_rows', None)

# %% [markdown]
# # 블록데이터 전처리 함수

# %%
import functools
def unpack_df_columns(func):
    @functools.wraps(func)
    def _unpack_df_columns(*args, **kwargs):
        series = args[0]
        return func(*series.values)
    return _unpack_df_columns

# %%
@unpack_df_columns
def 최소착수요구일구하기(납기, 공기):
    result = pd.to_datetime(납기) - timedelta(days=int(공기))
    return result.date()

# %%
@unpack_df_columns
def 블록우선순위구하기(날짜순서, 공기순서, 크기순서):
    global 착수일가중치, 공기가중치, 크기가중치
    result = np.round((날짜순서*float(착수일가중치) + 공기순서*float(공기가중치) + 크기순서*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 블록사이즈튜플만들기(가로, 세로):
    길이2 = max(가로, 세로)  
    길이1 = min(가로, 세로)
    result = (길이2, 길이1)
    return result

# %%
def 블록데이터전처리(블록원데이터):
    df1 = 블록원데이터.copy()
    df1["사이즈"] = df1[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
    df1["최대길이"] = df1["사이즈"].apply(lambda x: max(x))
    df1["납기"] = pd.to_datetime(df1["납기"])
    df1["면적"] = df1.eval("가로*세로")
    df1["최소착수요구일"] = df1[["납기", "표준공기"]].apply(최소착수요구일구하기, axis=1)
    df1["날짜순서"] = df1["최소착수요구일"].rank()
    df1["공기순서"] = df1["표준공기"].rank(ascending=False)
    df1["크기순서"] = df1["면적"].rank(ascending=False)
    df1["우선순위"] = df1[["날짜순서", "공기순서", "크기순서"]].apply(블록우선순위구하기, axis=1)
    
    df1 = df1.drop(['가로', '세로'], axis=1)
    df1 = df1.sort_values(by=["우선순위"])
    return df1

# %% [markdown]
# # 정반데이터 전처리 함수

# %%
@unpack_df_columns
def 정반우선순위구하기(중순, 크순):
    global 중량가중치, 크기가중치
    result = np.round((중순*float(중량가중치) + 크순*float(크기가중치))/3,1)
    return result

@unpack_df_columns
def 정반사이즈튜플만들기(가로, 세로):
    길이1 = max(가로, 세로)  
    길이2 = min(가로, 세로)
    result = (길이1, 길이2)
    return result

# %%
def 정반데이터전처리(정반원데이터):
    df = 정반원데이터.copy()
    
    df["사이즈"] = df[["가로", "세로"]].apply(정반사이즈튜플만들기, axis=1)
    df["면적"] = df.eval("가로*세로")
    df["최대길이"] = df["사이즈"].apply(lambda x: max(x))
    df["중량순서"] = df["가능중량"].rank(ascending=False)
    df["크기순서"] = df["면적"].rank(ascending=False)
    df["우선순위"] = df[["중량순서", "크기순서"]].apply(정반우선순위구하기, axis=1)
    
    df = df.drop(['가로', '세로'], axis=1)
    df = df.sort_values(by=["우선순위"])
    return df

# %% [markdown]
# # 면적달력 함수

# %%
def get_end_date_of_month(year, month):
    # Get the number of days in the given month
    num_days = calendar.monthrange(year, month)[1]
    # Return the last day of the month as a datetime object
    return date(year, month, num_days)

# %%
def create_면적달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터: pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    면적달력 = pd.DataFrame()
    면적달력.index = 날짜집합
   
    for 정반 in 정반집합:
        면적달력[f"{정반}"] = 정반데이터[정반데이터["정반명"]==정반]["면적"].values[0]

    return 면적달력

# %%
def update_init_면적달력(면적달력:pd.DataFrame, 블록착수일:str, 정반:str, 블록면적:int, 표준공기:int) -> pd.DataFrame:
    
    정반리스트 = 면적달력.columns.tolist()
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)   
    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values

    for idx, 대상일면적 in enumerate(조회기간면적리스트):
        수정면적 = 대상일면적 - 블록면적
        대상일인덱스 = 시점인덱스 + idx
        면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
        
    return 면적달력

# %%
# def update_면적달력(면적달력, 정반, 블록착수일, 배치블록명, 블록데이터):
#     정반리스트 = 면적달력.columns.tolist()
#     블록면적 = 블록데이터[블록데이터["블록명"]==배치블록명]["면적"].values[0]
#     표준공기 = 블록데이터[블록데이터["블록명"]==배치블록명]["표준공기"].values[0]
#     시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)        

#     조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values
    
#     print(f"조회기간 최소면적: {min(조회기간면적리스트)}, 블록면적: {블록면적}")
#     if min(조회기간면적리스트) >= 블록면적:
#         for idx, 대상일면적 in enumerate(조회기간면적리스트):
#             수정면적 = 대상일면적 - 블록면적
#             대상일인덱스 = 시점인덱스 + idx
#             면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
#         return True, 면적달력
#     else:
#         print("면적부족으로 배치불가능")
#         return False, 면적달력

# %%
def update_면적달력1(면적달력, 정반, 블록착수일, 배치블록명, 블록데이터):
    정반리스트 = 면적달력.columns.tolist()
    블록면적 = 블록데이터[블록데이터["블록명"]==배치블록명]["면적"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==배치블록명]["표준공기"].values[0]
    시점인덱스 = list(면적달력.index.strftime('%Y-%m-%d')).index(블록착수일)

    조회기간면적리스트 = 면적달력[f"{정반}"].iloc[시점인덱스:시점인덱스+표준공기].values
    
    print(f"조회기간 최소면적: {min(조회기간면적리스트)}, 블록면적: {블록면적}")
    if min(조회기간면적리스트) >= 블록면적:
        for idx, 대상일면적 in enumerate(조회기간면적리스트):
            수정면적 = 대상일면적 - 블록면적
            대상일인덱스 = 시점인덱스 + idx
            면적달력[f"{정반}"].iloc[대상일인덱스:대상일인덱스+1] = 수정면적
        return True, 면적달력
    else:
        print("면적부족으로 배치불가능")
        return False, 면적달력

# %% [markdown]
# # 블록명달력 함수

# %%
def create_블록명달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터:pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
def update_블록명달력(블록명달력:pd.DataFrame, 최선정반:str, 블록데이터:pd.DataFrame, block_names: list, best_st_date: list) -> pd.DataFrame:
    
    달력 = 블록명달력
    날짜집합 = 블록명달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]

    for block_name, 블록착수일 in zip(block_names, best_st_date):

        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        표준공기 = 블록데이터[블록데이터["블록명"]==block_name]["표준공기"].values[0]

        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(block_name)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %% [markdown]
# # 사이즈 달력 함수

# %%
def create_사이즈달력(시작년:int, 시작월:int, 시작일: int, 종료년:int, 종료월:int, 정반데이터:pd.DataFrame) -> pd.DataFrame:
    start_date = datetime(시작년, 시작월, 시작일)
    end_date = get_end_date_of_month(종료년, 종료월)
    정반집합 = 정반데이터["정반명"].tolist()
    날짜집합  = pd.date_range(start=start_date, end=end_date, freq='D')
    
    달력 = pd.DataFrame()
    달력.index = 날짜집합
    
    for 정반 in 정반집합:
        달력[정반] = [[] for _ in range(len(날짜집합))]
        
    return 달력

# %%
def update_사이즈달력(사이즈달력: pd.DataFrame, 최선정반:str, 블록데이터:pd.DataFrame, block_names:list, block_sizes:tuple, best_st_date:list) -> pd.DataFrame:
    
    달력 = 사이즈달력
    날짜집합 = 달력.index.tolist()
    결과모음 = [[] for _ in range(len(날짜집합))]
        
    for i in range(len(block_names)):
        블록명 = block_names[i]
        블록사이즈 = block_sizes[i]
        블록착수일 = best_st_date[i]
        
        표준공기 = 블록데이터[블록데이터["블록명"]==블록명]["표준공기"].values[0]
        시점인덱스 = list(달력.index.strftime('%Y-%m-%d')).index(블록착수일)
        
        for i in 결과모음[시점인덱스:시점인덱스+표준공기]:
            i.append(블록사이즈)
            
    달력[f"{최선정반}"] = 결과모음

    return 달력

# %% [markdown]
# # 레이아웃 적합도 함수

# %%
def 정반세팅(사이즈):  #사이즈 = (10, 10)
    surface_width, surface_height = 사이즈[0], 사이즈[1]  # Adjusted to match the provided image for demonstration
    surface = np.zeros((surface_height, surface_width), dtype=int)
    return surface, surface_width, surface_height

# %%
def can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, start_row, start_col, thresh):
    new_width = surface_width - thresh
    new_height = surface_height - thresh
    
    if start_row + block_height > surface_height or start_col + block_width > surface_width:
        return False

    block_area = surface[start_row:start_row+block_height, start_col:start_col+block_width]
    if np.any(block_area != 0):
        return False
    
    if start_row > 0 and np.any(surface[start_row-thresh: start_row, start_col:start_col+block_width] != 0):
        return False
    if start_col > 0 and np.any(surface[start_row: start_row+block_height, start_col-thresh: start_col] != 0):
        return False
    
    return True

# Function to place a block on the surface, if possible
def place_block(surface, block_height, block_width, start_row, start_col, block_id):
    block_height, block_width = block_height, block_width
    surface[start_row:start_row + block_height, start_col:start_col + block_width] = block_id

# Function to find the best fit for a block on the surface
def find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh):
    best_fit_score = float('inf')
    best_position = None
    block_height, block_width = block_height, block_width

    # Iterate over all possible positions on the surface
    for y in range(surface_height - block_height + 1):
        for x in range(surface_width - block_width + 1):
            if can_place_with_thresh(surface, surface_width, surface_height, block_height, block_width, y, x, thresh):
                # Calculate a score; here we use the top-left corner (y, x) as the score
                # A lower score means the block is closer to the top-left
                score = y + x
                if score < best_fit_score:
                    best_fit_score = score
                    best_position = (y, x)

    # If a best position was found, place the block there
    if best_position:
        place_block(surface, block_height, block_width, *best_position, block_id)
        return True

    return False  # No fit found

# Function to fit blocks on the surface in order
def fit_blocks_with_thresh(surface, surface_width, surface_height, blocks, names, thresh):
    result = "적합"
    block_id = max(map(max, surface))+1  # Start numbering blocks from 1
    for name, block in zip(names, blocks):
        
        block_height, block_width = block
        if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
            print(f"-----1차검토 부적합 - Block {name} of height {block_height} width {block_width} could not be placed.")
            # result = "부적합"
            
            if block_height != block_width:  # 가로 세로 길이가 같지 않다면...
                ## 가로 세로 길이 바꿔서 검토 -------------------------------------
                block_height, block_width = block_width, block_height
                
                if find_best_fit_with_thresh(surface, surface_width, surface_height, block_height, block_width, block_id, thresh) == False:
                    print(f"-----2차검토 부적합 - Block {name} of height {block_height} width {block_width} could not be placed.")
                    result = "부적합"
                else:
                    # print(f"2차검토 적합 - Block {name} of height {block_height} width {block_width} could be placed.")
                    result = "적합"
            else:
                pass
        else:
            # print(f"1차검토 적합 - Block {name} of height {block_height} width {block_width} could be placed.")
            result = "적합"
            
        block_id += 1  # Increment block_id for the next block
    return surface, result

# %%
def 정반배치레이아웃적합도(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]

    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    적합도 = 배치결과[1]
    
    return 적합도

# %% [markdown]
# # 시각화 함수

# %%
def draw1(surface, block_names):
    fig, ax = plt.subplots(figsize=(8, 8))

    cmap = mcolors.ListedColormap(['white'] + ['C{}'.format(i) for i in range(len(block_names))])
    norm = mcolors.BoundaryNorm(np.arange(0.5, len(block_names) + 2), cmap.N)

    ax.imshow(surface, cmap=cmap, norm=norm)

    for y in range(surface.shape[0]):
        for x in range(surface.shape[1]):
            if surface[y, x] != 0:
                ax.text(x, y, str(block_names[surface[y, x]-1]), ha='center', va='center', color='black', fontsize=6)
                
    ax.set_xticks(np.arange(-.5, surface.shape[1], 1), minor=True)
    ax.set_yticks(np.arange(-.5, surface.shape[0], 1), minor=True)
    ax.grid(which="minor", color="black", linestyle='-', linewidth=1)
    ax.tick_params(which="minor", size=0)

    ax.set_xticks([])
    ax.set_yticks([])

    plt.show()

# %%
def 정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 블록사이즈달력):
    
    정반사이즈 = 정반데이터[정반데이터["정반명"]==정반명]["사이즈"].values[0]
    block_names = 블록명달력.at[조회날짜, 정반명]
    block_sizes = 블록사이즈달력.at[조회날짜, 정반명]
        
    surface, surface_width, surface_height = 정반세팅(정반사이즈)
    배치결과 = fit_blocks_with_thresh(surface, surface_width, surface_height, block_sizes, block_names, thresh)
    배치레이아웃 = 배치결과[0]
    draw1(배치레이아웃, block_names)

# %% [markdown]
# # 생산계획 서브 함수

# %%
def 중량조건체크(target_block):
    가능정반리스트 = []
    블록중량 = 블록데이터[블록데이터["블록명"]==target_block]["중량"].values[0]
    for 정반 in 정반데이터["정반명"]:
        정반가능중량 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반가능중량 > 블록중량:
            가능정반리스트.append(정반)       
    return 가능정반리스트

# %%
def 최장길이체크(target_block:str, 중량가능정반들:list):
    가능정반리스트 = []
    블록최장길이 = 블록데이터[블록데이터["블록명"]==target_block]["최대길이"].values[0]
    for 정반 in 중량가능정반들:
        정반최장길이 = 정반데이터[정반데이터["정반명"]==정반]["가능중량"].values[0]
        if 정반최장길이 > 블록최장길이:
            가능정반리스트.append(정반)
    return 가능정반리스트

# %%
def 최선착수일후보체크(target_block:str, 길이가능정반들:list, 조기착수금지일수:int):
    result_dict = dict()
    # 블록납기 및 표준공기, 블록면적 확인
    블록데이터["납기"] = 블록데이터["납기"].astype('str')
    블록납기 = 블록데이터[블록데이터["블록명"]==target_block]["납기"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==target_block]["표준공기"].values[0]
    블록면적 = 블록데이터[블록데이터["블록명"]==target_block]["면적"].values[0]
    # 블록 최소착수요구일 확인
    최소착수요구일 = 블록데이터[블록데이터["블록명"]==target_block]["최소착수요구일"].values[0]
    최소착수요구일 = 최소착수요구일.strftime("%Y-%m-%d")
    # 면적달력날짜리스트 확인
    면적달력날짜리스트_datetime = list(면적달력.index)
    면적달력날짜리스트 = [date_obj.strftime("%Y-%m-%d") for date_obj in 면적달력날짜리스트_datetime]
    # 최소착수요구일인덱스 및 한계시점인덱스 확인
    블록납기일인덱스 = 면적달력날짜리스트.index(블록납기)
    최소착수요구일인덱스 = 면적달력날짜리스트.index(최소착수요구일)
    한계시점인덱스 = max(0, 최소착수요구일인덱스 - 조기착수금지일수)
    # print(f"최소착수요구일:{최소착수요구일}, 최소착수요구일인덱스:{최소착수요구일인덱스}, 한계시점인덱스:{한계시점인덱스}")
    
    for 대상정반 in 길이가능정반들:
        정반면적리스트 = 면적달력[f"{대상정반}"].iloc[한계시점인덱스:블록납기일인덱스].values
        # print(f"대상정반:{대상정반}- \n{정반면적리스트}")

        for idx in range(len(정반면적리스트)):
            조회구간면적리스트 = 정반면적리스트[idx:idx+표준공기]
            조회구간최소면적 = min(조회구간면적리스트)
            # print(f"{대상정반} - 조회구간면적리스트: {조회구간면적리스트}, 조회구간최소면적: {조회구간최소면적}, 블록면적: {블록면적}")

            if 조회구간최소면적 >= 블록면적:
                조회시점인덱스 = 한계시점인덱스 + idx
                최선조기착수일 = 면적달력.index[조회시점인덱스]
                result_dict[대상정반] = 최선조기착수일
                break
            else:
                pass
    return result_dict

# %%
 def 최선조기착수대상선택(최선착수일후보):
    values = 최선착수일후보.values()
    unique_values = set(values)

    if len(unique_values) > 1:
        # 최선 날짜가 복수개 있으면 조기 착수일 선택
        최선조기착수정반 = min(최선착수일후보, key=lambda k: 최선착수일후보[k])
        최선조기착수날짜 = 최선착수일후보[최선조기착수정반]
        return (최선조기착수정반, 최선조기착수날짜)
    else:
        # 최선 날짜가 한개면, 랜덤 선택
        random_key = choice(list(최선착수일후보.keys()))
        return (random_key, 최선착수일후보[random_key])

# %% [markdown]
# # 시뮬레이션 실시

# %%
# Out:
# (123, 6)
# (25, 6)

# %%
# 블록원데이터["납기"] = 블록원데이터["납기"] + timedelta(days=3)
# 블록원데이터["표준공기"] = 블록원데이터["표준공기"] + 3
# 블록원데이터.head(2)

# %%
# Out:
# ((25, 12), (2, 8))

# %%
data_num = "_실행계획"

시작년, 시작월, 시작일, 종료년, 종료월 = 2023, 10, 1, 2024, 3

thresh = 1  # 블록 간격(m)
조기착수금지일수 = 7

블록원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="블록데이터")
기배치블록 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="기배치블록")
정반원데이터 = pd.read_excel(f"D:/공정최적화/data/data1{data_num}.xlsx", sheet_name="정반데이터")
블록원데이터.shape

검토개수 = 123
블록원데이터 = 블록원데이터.iloc[:검토개수,:]
블록원데이터.shape

착수일가중치, 공기가중치, 크기가중치 = 1, 0.2, 0.1
블록데이터 = 블록데이터전처리(블록원데이터)

중량가중치, 크기가중치 = 0.5, 0.5
정반데이터 = 정반데이터전처리(정반원데이터)
블록데이터.shape, 정반데이터.shape

면적달력 = create_면적달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
블록명달력 = create_블록명달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)
사이즈달력 = create_사이즈달력(시작년, 시작월, 시작일, 종료년, 종료월, 정반데이터)

기배치블록["블록면적"] = 기배치블록.eval("가로*세로")
기배치블록["사이즈"] = 기배치블록[["가로", "세로"]].apply(블록사이즈튜플만들기, axis=1)
기배치블록["착수일"] = 기배치블록["착수일"].dt.strftime('%Y-%m-%d')
기배치블록["종료일"] = 기배치블록["종료일"].dt.strftime('%Y-%m-%d')
for 블록착수일, 배치블록명, 블록면적, 표준공기, 배치정반 in zip(기배치블록["착수일"], 기배치블록["블록명"], 기배치블록["블록면적"], 기배치블록["공기"], 기배치블록["배치정반"],):
    면적달력 = update_init_면적달력(면적달력, 블록착수일, 배치정반, 블록면적, 표준공기)

# 블록데이터 및 정반데이터 정리
# 달력초기화 및 기진행블록 달력에 반영
block_list = 블록데이터["블록명"].tolist()
정반리스트 = 정반데이터["정반명"].tolist()
print(block_list)

블록명_dict = {key: [] for key in 정반리스트}
착수일자_dict = {key: [] for key in 정반리스트}
사이즈_dict = {key: [] for key in 정반리스트}
배치상태 = []
착수일자 = []

for _ in tqdm(range(len(block_list))):
    
    target_block = block_list[0]
    print()
    print(f"***** 검토대상블록: {target_block} ---------------------------------------------")

    # 중량조건체크함수  --> 적합 정반리스트
    중량가능정반들 = 중량조건체크(target_block)
    # print(f"중량가능정반들: {중량가능정반들}")

    # 최장길이체크함수  --> 적합 정반리스트
    길이가능정반들 = 최장길이체크(target_block, 중량가능정반들)
    # print(f"길이가능정반들: {길이가능정반들}")

    # 날짜 및 면적 체크후 정반별 최선조기착수일 후보 검토
    최선착수일후보 = 최선착수일후보체크(target_block, 길이가능정반들, 7)      
    print(f"최선착수일후보: {최선착수일후보}")
    
    # 최선 조기착수대상 선택 (착수일자가 빠른 것 우선)
    최선조기착수대상 = 최선조기착수대상선택(최선착수일후보)
    print(f"최선조기착수대상: {최선조기착수대상}")
    최소착수요구일 = 블록데이터[블록데이터["블록명"]==target_block]["최소착수요구일"].values[0]
    최선정반, 최선착수일 = 최선조기착수대상[0], 최선조기착수대상[1]

    # 최선착수일과 최소착수요구일 간격 구하기
    최선착수일 = 최선착수일.date()
    gap = 최소착수요구일 - 최선착수일
    gap = int(gap.days + 1)

    # origin 변수 저장
    origin_블록명 = 블록명_dict[최선정반].copy()
    origin_착수일자 = 착수일자_dict[최선정반].copy()
    origin_사이즈 = 사이즈_dict[최선정반].copy()

    origin_면적달력 = 면적달력.copy()
    origin_블록명달력 = 블록명달력.copy()
    origin_사이즈달력 = 사이즈달력.copy()

    # 달력업데이트 변수 정의
    블록명_dict[최선정반].append(target_block)

    최선착수일 = 최선착수일.strftime("%Y-%m-%d")
    착수일자_dict[최선정반].append(최선착수일)
    
    사이즈 = 블록데이터[블록데이터["블록명"]==target_block]["사이즈"].values[0]
    사이즈_dict[최선정반].append(사이즈)

    # 기타 참고변수
    납기 = 블록데이터[블록데이터["블록명"]==target_block]["납기"].values[0]
    표준공기 = 블록데이터[블록데이터["블록명"]==target_block]["표준공기"].values[0]
    print(f"*** 최선정반: {최선정반}, 납기: {납기}, , 표준공기: {표준공기}, 최소요구착수일: {최소착수요구일}, 최선착수일: {최선착수일}, gap: {gap}, 사이즈: {사이즈}")


    
    # 레이아웃 체크 함수 ------------------------------------------------------------------------------------------------------------------------------------------------   
    status = "정상배치"

    # Gap의 00배수만큼 후퇴하면서 검토 (최소착수요구일 초과하더라도..)
    for g in range(gap*3):
        print(f">>>> 레이아웃검토: {g}")
    
        레이아웃적합도모음= []
        
        # 최선착수일 순환 계산 가산 계수
        g = 0 if g == 0 else 1
        
        최선착수일 = datetime.strptime(최선착수일, "%Y-%m-%d").date() + timedelta(days= g)
        최선착수일 = 최선착수일.strftime("%Y-%m-%d")
        착수일자_dict[최선정반][-1] = 최선착수일#.strftime("%Y-%m-%d")
        
        print(f"{g}: {블록명_dict[최선정반]}")
        print(f"{g}: {착수일자_dict[최선정반]}")

        블록명달력 = origin_블록명달력
        사이즈달력 = origin_사이즈달력
        
        # 레이아웃 적합도 판단을 위해 임시 배치한 달력을 생성
        임시_블록명달력 = update_블록명달력(블록명달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 착수일자_dict[최선정반])
        임시_사이즈달력 = update_사이즈달력(사이즈달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 사이즈_dict[최선정반], 착수일자_dict[최선정반])

        for k in range(표준공기):
            레이아웃배치검토시작일 = datetime.strptime(최선착수일, "%Y-%m-%d")  # + timedelta(days=g)
            new_date = 레이아웃배치검토시작일 + timedelta(days=k)
            레이아웃검토날짜 = new_date.strftime("%Y-%m-%d") 
            print(f"--- g: {g}, k: {k}, 레이아웃배치검토시작일: {레이아웃배치검토시작일.strftime('%Y-%m-%d')}, 레이아웃검토날짜: {레이아웃검토날짜}")

            적합도 = 정반배치레이아웃적합도(최선정반, 정반데이터, 레이아웃검토날짜, 임시_블록명달력, 임시_사이즈달력)

            레이아웃적합도모음.append(적합도)

        print(f"레이아웃적합도모음: {레이아웃적합도모음}")
        
        if "부적합" not in  레이아웃적합도모음:

            레이아웃검토후최선착수일 = 레이아웃배치검토시작일.strftime("%Y-%m-%d")
            print(f"레이아웃검토후최선착수일:  {레이아웃검토후최선착수일}")

            착수일자_dict[최선정반] = 착수일자_dict[최선정반][:-1]
            착수일자_dict[최선정반].append(레이아웃검토후최선착수일)
            
            # 달력 업데이트
            면적달력결과 = update_면적달력1(면적달력, 최선정반, 레이아웃검토후최선착수일, target_block, 블록데이터)
            print(f"면적달력 업데이트 결과: {면적달력결과[0]}")

            if 면적달력결과[0] == True:
                면적달력 = 면적달력결과[1]
                블록명달력 = update_블록명달력(블록명달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 착수일자_dict[최선정반])
                사이즈달력 = update_사이즈달력(사이즈달력, 최선정반, 블록데이터, 블록명_dict[최선정반], 사이즈_dict[최선정반], 착수일자_dict[최선정반])
                status = "정상배치"
                착수일 = 레이아웃검토후최선착수일
                break
                
            else:
                
                면적달력 = origin_면적달력            
                블록명달력 = origin_블록명달력
                사이즈달력 = origin_사이즈달력
           
        else:
            status = "배치불가"
            착수일 = None
            print("부적합")
            print()
            
            면적달력 = origin_면적달력            
            블록명달력 = origin_블록명달력
            사이즈달력 = origin_사이즈달력
    
     
    배치상태.append(status)
    착수일자.append(착수일)
    block_list.remove(target_block)
    print("="*80)
    time.sleep(0.1)
# Out:
# (123, 6)
# (123, 6)
# ((123, 12), (2, 8))
# ['S15', 'S24', 'S33', 'S19', 'S16', 'S25', 'S21', 'S17', 'S32', 'S18', 'S14', 'S13', 'S20', 'S22', 'S23', 'S26', 'S36', 'S27', 'S35', 'S45', 'S49', 'S41', 'S34', 'S39', 'S46', 'S40', 'S47', 'S52', 'S38', 'S51', 'S50', 'S57', 'S67', 'S62', 'S30', 'S28', 'S29', 'S31', 'S43', 'S44', 'S37', 'S64', 'S63', 'S42', 'S58', 'S55', 'S59', 'S70', 'S56', 'S48', 'S68', 'S65', 'S66', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S75', 'S74', 'S83', 'S73', 'S72', 'S90', 'S94', 'S77', 'S97', 'S76', 'S80', 'S60', 'S105', 'S61', 'S84', 'S96', 'S99', 'S87', 'S78', 'S98', 'S79', 'S103', 'S102', 'S85', 'S89', 'S104', 'S95', 'S112', 'S88', 'S93', 'S111', 'S92', 'S91', 'S108', 'S109', 'S107', 'S106', 'S119', 'S127', 'S126', 'S135', 'S134', 'S113', 'S116', 'S115', 'S124', 'S114', 'S120', 'S132', 'S128', 'S110', 'S118', 'S121', 'S101', 'S100', 'S125', 'S133', 'S122', 'S117', 'S130', 'S129', 'S123', 'S131']
#   0%|          | 0/123 [00:00<?, ?it/s]
# ***** 검토대상블록: S15 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-13, , 표준공기: 10, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (15, 14)
# >>>> 레이아웃검토: 0
# 0: ['S15']
# 0: ['2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 467, 블록면적: 210
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S24 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-02 00:00:00'), 'A': Timestamp('2023-11-02 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-02 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-21, , 표준공기: 12, 최소요구착수일: 2023-11-09, 최선착수일: 2023-11-02, gap: 8, 사이즈: (18, 14)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24']
# 0: ['2023-10-27', '2023-11-02']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-02
# 조회기간 최소면적: 337, 블록면적: 252
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S33 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-07 00:00:00'), 'A': Timestamp('2023-11-07 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-07 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-27, , 표준공기: 13, 최소요구착수일: 2023-11-14, 최선착수일: 2023-11-07, gap: 8, 사이즈: (19, 15)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24', 'S33']
# 0: ['2023-10-27', '2023-11-02', '2023-11-07']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-13
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-14
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-15
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-16
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-17
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-18
# --- g: 0, k: 12, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-19
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-07
# 조회기간 최소면적: 615, 블록면적: 285
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S19 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-15, , 표준공기: 12, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (14, 7)
# >>>> 레이아웃검토: 0
# 0: ['S19']
# 0: ['2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 11, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-07
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 241, 블록면적: 98
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S16 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-27 00:00:00'), 'A': Timestamp('2023-10-27 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-27 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-14, , 표준공기: 11, 최소요구착수일: 2023-11-03, 최선착수일: 2023-10-27, gap: 8, 사이즈: (14, 5)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24', 'S33', 'S16']
# 0: ['2023-10-27', '2023-11-02', '2023-11-07', '2023-10-27']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-01
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-10-27, 레이아웃검토날짜: 2023-11-06
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-27
# 조회기간 최소면적: 85, 블록면적: 70
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S25 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-03 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-21, , 표준공기: 11, 최소요구착수일: 2023-11-10, 최선착수일: 2023-11-03, gap: 8, 사이즈: (19, 13)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25']
# 0: ['2023-10-27', '2023-11-03']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-11
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-12
# --- g: 0, k: 10, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-03
# 조회기간 최소면적: 701, 블록면적: 247
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S21 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-02 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-02 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-17, , 표준공기: 8, 최소요구착수일: 2023-11-09, 최선착수일: 2023-11-02, gap: 8, 사이즈: (17, 15)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-02
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-02, 레이아웃검토날짜: 2023-11-09
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-02
# 조회기간 최소면적: 296, 블록면적: 255
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S17 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-03 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-14, , 표준공기: 8, 최소요구착수일: 2023-11-06, 최선착수일: 2023-11-03, gap: 4, 사이즈: (15, 13)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21', 'S17']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-03']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 1
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-04']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-11
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 2
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-05']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-12
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-06']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-07']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-14
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 5
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-08']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-15
# 레이아웃적합도모음: ['부적합', '부적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 6
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-09']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S17 of height 15 width 13 could not be placed.
# -----2차검토 부적합 - Block S17 of height 13 width 15 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-16
# 레이아웃적합도모음: ['부적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 7
# 1: ['S19', 'S25', 'S21', 'S17']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-16
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-17
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-10
# 조회기간 최소면적: 929, 블록면적: 195
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S32 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-10 00:00:00'), 'A': Timestamp('2023-11-10 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-10 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-27, , 표준공기: 10, 최소요구착수일: 2023-11-17, 최선착수일: 2023-11-10, gap: 8, 사이즈: (17, 15)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21', 'S17', 'S32']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-10']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-10
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-14
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-15
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-16
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-17
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-18
# --- g: 0, k: 9, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-19
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 1
# 1: ['S19', 'S25', 'S21', 'S17', 'S32']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-11']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-11
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-16
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-17
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 8, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 9, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-20
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 2
# 1: ['S19', 'S25', 'S21', 'S17', 'S32']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-12']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-12
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-16
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-17
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 8, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 9, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-21
# 레이아웃적합도모음: ['부적합', '부적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S19', 'S25', 'S21', 'S17', 'S32']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-13']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-13
# -----1차검토 부적합 - Block S32 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S32 of height 15 width 17 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-16
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-17
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 8, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-21
# --- g: 1, k: 9, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-22
# 레이아웃적합도모음: ['부적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S19', 'S25', 'S21', 'S17', 'S32']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-14
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-15
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-16
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-17
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-21
# --- g: 1, k: 8, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-22
# --- g: 1, k: 9, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-23
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-14
# 조회기간 최소면적: 981, 블록면적: 255
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S18 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-03 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-03 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-15, , 표준공기: 9, 최소요구착수일: 2023-11-06, 최선착수일: 2023-11-03, gap: 4, 사이즈: (14, 7)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24', 'S33', 'S16', 'S18']
# 0: ['2023-10-27', '2023-11-02', '2023-11-07', '2023-10-27', '2023-11-03']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# --- g: 0, k: 8, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-11
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-11-03
# 조회기간 최소면적: 127, 블록면적: 98
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S14 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-10-26 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-10-26 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-09, , 표준공기: 7, 최소요구착수일: 2023-11-02, 최선착수일: 2023-10-26, gap: 8, 사이즈: (13, 13)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24', 'S33', 'S16', 'S18', 'S14']
# 0: ['2023-10-27', '2023-11-02', '2023-11-07', '2023-10-27', '2023-11-03', '2023-10-26']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-26
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-27
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-28
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-29
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-30
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-10-31
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-10-26, 레이아웃검토날짜: 2023-11-01
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2023-10-26
# 조회기간 최소면적: 187, 블록면적: 169
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S13 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-07 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2023-11-06 00:00:00'))
# *** 최선정반: B, 납기: 2023-11-08, , 표준공기: 6, 최소요구착수일: 2023-11-02, 최선착수일: 2023-11-06, gap: -3, 사이즈: (15, 14)
# ================================================================================
#
# ***** 검토대상블록: S20 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-03 00:00:00'))
# *** 최선정반: A, 납기: 2023-11-15, , 표준공기: 8, 최소요구착수일: 2023-11-07, 최선착수일: 2023-11-03, gap: 5, 사이즈: (14, 13)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-03']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-03
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2023-11-03, 레이아웃검토날짜: 2023-11-10
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 1
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-04']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-04
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-04, 레이아웃검토날짜: 2023-11-11
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 2
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-05']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-05
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-05, 레이아웃검토날짜: 2023-11-12
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 3
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-06']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-06
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-06, 레이아웃검토날짜: 2023-11-13
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 4
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-07']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-07
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-07, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '적합', '적합', '적합', '적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 5
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-08']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-08
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-08, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '적합', '적합', '적합', '적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 6
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-09']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-09
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-09, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# 레이아웃적합도모음: ['부적합', '적합', '적합', '적합', '적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 7
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-10']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-10
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-10, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 8
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-11']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-11
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-11, 레이아웃검토날짜: 2023-11-18
# 레이아웃적합도모음: ['적합', '적합', '적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 9
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-12']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-12
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-12, 레이아웃검토날짜: 2023-11-19
# 레이아웃적합도모음: ['적합', '적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 10
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-13']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-13
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-13, 레이아웃검토날짜: 2023-11-20
# 레이아웃적합도모음: ['적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 11
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-14']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-14
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-14, 레이아웃검토날짜: 2023-11-21
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 12
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-15']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-15
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-21
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-15, 레이아웃검토날짜: 2023-11-22
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 13
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-16']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-16
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-21
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-22
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-16, 레이아웃검토날짜: 2023-11-23
# 레이아웃적합도모음: ['부적합', '부적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 14
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-17']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-17
# -----1차검토 부적합 - Block S20 of height 14 width 13 could not be placed.
# -----2차검토 부적합 - Block S20 of height 13 width 14 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-18
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-19
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-20
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-21
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-22
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-23
# --- g: 1, k: 7, 레이아웃배치검토시작일: 2023-11-17, 레이아웃검토날짜: 2023-11-24
# 레이아웃적합도모음: ['부적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 부적합
#
# ================================================================================
#
# ***** 검토대상블록: S22 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2023-11-06 00:00:00'), 'A': Timestamp('2023-11-03 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2023-11-03 00:00:00'))
# ...
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-23
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-24
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-25
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-26
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-27
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-22, 레이아웃검토날짜: 2024-03-28
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '부적합']
# 부적합
#
# >>>> 레이아웃검토: 22
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20', 'S22', 'S23', 'S27', 'S35', 'S45', 'S41', 'S46', 'S40', 'S47', 'S38', 'S51', 'S62', 'S43', 'S37', 'S59', 'S56', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S74', 'S83', 'S73', 'S72', 'S90', 'S80', 'S60', 'S96', 'S99', 'S87', 'S98', 'S103', 'S85', 'S89', 'S112', 'S93', 'S92', 'S91', 'S109', 'S107', 'S119', 'S127', 'S135', 'S134', 'S113', 'S124', 'S132', 'S100', 'S133', 'S122', 'S117', 'S130']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-17', '2023-11-03', '2023-11-03', '2023-11-18', '2023-11-25', '2023-11-26', '2023-11-22', '2023-11-29', '2023-11-21', '2023-11-30', '2023-11-20', '2023-12-07', '2023-12-13', '2023-11-27', '2023-12-02', '2023-12-11', '2023-12-15', '2023-12-19', '2023-12-06', '2023-12-06', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-11', '2024-01-16', '2024-01-22', '2023-12-29', '2023-12-29', '2024-01-31', '2024-01-23', '2023-12-20', '2024-01-22', '2024-01-30', '2024-01-31', '2024-02-06', '2024-01-26', '2024-01-12', '2024-01-15', '2024-02-09', '2024-02-08', '2024-01-18', '2024-01-18', '2024-02-12', '2024-02-12', '2024-02-16', '2024-02-22', '2024-02-26', '2024-03-06', '2024-02-12', '2024-03-10', '2024-03-17', '2024-02-07', '2024-03-22', '2024-03-20', '2024-02-20', '2024-03-23']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-23
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-24
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-25
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-26
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-27
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-28
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-23, 레이아웃검토날짜: 2024-03-29
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '부적합', '적합']
# 부적합
#
# >>>> 레이아웃검토: 23
# 1: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20', 'S22', 'S23', 'S27', 'S35', 'S45', 'S41', 'S46', 'S40', 'S47', 'S38', 'S51', 'S62', 'S43', 'S37', 'S59', 'S56', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S74', 'S83', 'S73', 'S72', 'S90', 'S80', 'S60', 'S96', 'S99', 'S87', 'S98', 'S103', 'S85', 'S89', 'S112', 'S93', 'S92', 'S91', 'S109', 'S107', 'S119', 'S127', 'S135', 'S134', 'S113', 'S124', 'S132', 'S100', 'S133', 'S122', 'S117', 'S130']
# 1: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-17', '2023-11-03', '2023-11-03', '2023-11-18', '2023-11-25', '2023-11-26', '2023-11-22', '2023-11-29', '2023-11-21', '2023-11-30', '2023-11-20', '2023-12-07', '2023-12-13', '2023-11-27', '2023-12-02', '2023-12-11', '2023-12-15', '2023-12-19', '2023-12-06', '2023-12-06', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-11', '2024-01-16', '2024-01-22', '2023-12-29', '2023-12-29', '2024-01-31', '2024-01-23', '2023-12-20', '2024-01-22', '2024-01-30', '2024-01-31', '2024-02-06', '2024-01-26', '2024-01-12', '2024-01-15', '2024-02-09', '2024-02-08', '2024-01-18', '2024-01-18', '2024-02-12', '2024-02-12', '2024-02-16', '2024-02-22', '2024-02-26', '2024-03-06', '2024-02-12', '2024-03-10', '2024-03-17', '2024-02-07', '2024-03-22', '2024-03-20', '2024-02-20', '2024-03-24']
# --- g: 1, k: 0, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-24
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 1, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-25
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 2, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-26
# -----1차검토 부적합 - Block S122 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S122 of height 15 width 27 could not be placed.
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 3, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-27
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 4, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-28
# -----1차검토 부적합 - Block S130 of height 27 width 15 could not be placed.
# -----2차검토 부적합 - Block S130 of height 15 width 27 could not be placed.
# --- g: 1, k: 5, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-29
# --- g: 1, k: 6, 레이아웃배치검토시작일: 2024-03-24, 레이아웃검토날짜: 2024-03-30
# 레이아웃적합도모음: ['부적합', '부적합', '부적합', '부적합', '부적합', '적합', '적합']
# 부적합
#
# ================================================================================
#
# ***** 검토대상블록: S129 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2024-03-04 00:00:00'), 'A': Timestamp('2024-03-04 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2024-03-04 00:00:00'))
# *** 최선정반: A, 납기: 2024-03-19, , 표준공기: 8, 최소요구착수일: 2024-03-11, 최선착수일: 2024-03-04, gap: 8, 사이즈: (16, 12)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20', 'S22', 'S23', 'S27', 'S35', 'S45', 'S41', 'S46', 'S40', 'S47', 'S38', 'S51', 'S62', 'S43', 'S37', 'S59', 'S56', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S74', 'S83', 'S73', 'S72', 'S90', 'S80', 'S60', 'S96', 'S99', 'S87', 'S98', 'S103', 'S85', 'S89', 'S112', 'S93', 'S92', 'S91', 'S109', 'S107', 'S119', 'S127', 'S135', 'S134', 'S113', 'S124', 'S132', 'S100', 'S133', 'S122', 'S117', 'S130', 'S129']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-17', '2023-11-03', '2023-11-03', '2023-11-18', '2023-11-25', '2023-11-26', '2023-11-22', '2023-11-29', '2023-11-21', '2023-11-30', '2023-11-20', '2023-12-07', '2023-12-13', '2023-11-27', '2023-12-02', '2023-12-11', '2023-12-15', '2023-12-19', '2023-12-06', '2023-12-06', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-11', '2024-01-16', '2024-01-22', '2023-12-29', '2023-12-29', '2024-01-31', '2024-01-23', '2023-12-20', '2024-01-22', '2024-01-30', '2024-01-31', '2024-02-06', '2024-01-26', '2024-01-12', '2024-01-15', '2024-02-09', '2024-02-08', '2024-01-18', '2024-01-18', '2024-02-12', '2024-02-12', '2024-02-16', '2024-02-22', '2024-02-26', '2024-03-06', '2024-02-12', '2024-03-10', '2024-03-17', '2024-02-07', '2024-03-22', '2024-03-20', '2024-02-20', '2024-03-24', '2024-03-04']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-04
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-05
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-06
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-07
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-08
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-09
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-10
# --- g: 0, k: 7, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-11
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2024-03-04
# 조회기간 최소면적: 672, 블록면적: 192
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S123 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2024-02-26 00:00:00'), 'A': Timestamp('2024-02-26 00:00:00')}
# 최선조기착수대상: ('A', Timestamp('2024-02-26 00:00:00'))
# *** 최선정반: A, 납기: 2024-03-11, , 표준공기: 7, 최소요구착수일: 2024-03-04, 최선착수일: 2024-02-26, gap: 8, 사이즈: (16, 12)
# >>>> 레이아웃검토: 0
# 0: ['S19', 'S25', 'S21', 'S17', 'S32', 'S20', 'S22', 'S23', 'S27', 'S35', 'S45', 'S41', 'S46', 'S40', 'S47', 'S38', 'S51', 'S62', 'S43', 'S37', 'S59', 'S56', 'S69', 'S54', 'S53', 'S81', 'S82', 'S71', 'S86', 'S74', 'S83', 'S73', 'S72', 'S90', 'S80', 'S60', 'S96', 'S99', 'S87', 'S98', 'S103', 'S85', 'S89', 'S112', 'S93', 'S92', 'S91', 'S109', 'S107', 'S119', 'S127', 'S135', 'S134', 'S113', 'S124', 'S132', 'S100', 'S133', 'S122', 'S117', 'S130', 'S129', 'S123']
# 0: ['2023-10-27', '2023-11-03', '2023-11-02', '2023-11-10', '2023-11-14', '2023-11-17', '2023-11-03', '2023-11-03', '2023-11-18', '2023-11-25', '2023-11-26', '2023-11-22', '2023-11-29', '2023-11-21', '2023-11-30', '2023-11-20', '2023-12-07', '2023-12-13', '2023-11-27', '2023-12-02', '2023-12-11', '2023-12-15', '2023-12-19', '2023-12-06', '2023-12-06', '2024-01-04', '2024-01-04', '2023-12-29', '2024-01-11', '2024-01-16', '2024-01-22', '2023-12-29', '2023-12-29', '2024-01-31', '2024-01-23', '2023-12-20', '2024-01-22', '2024-01-30', '2024-01-31', '2024-02-06', '2024-01-26', '2024-01-12', '2024-01-15', '2024-02-09', '2024-02-08', '2024-01-18', '2024-01-18', '2024-02-12', '2024-02-12', '2024-02-16', '2024-02-22', '2024-02-26', '2024-03-06', '2024-02-12', '2024-03-10', '2024-03-17', '2024-02-07', '2024-03-22', '2024-03-20', '2024-02-20', '2024-03-24', '2024-03-04', '2024-02-26']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-02-26
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-02-27
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-02-28
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-02-29
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-03-01
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-03-02
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2024-02-26, 레이아웃검토날짜: 2024-03-03
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2024-02-26
# 조회기간 최소면적: 672, 블록면적: 192
# 면적달력 업데이트 결과: True
# ================================================================================
#
# ***** 검토대상블록: S131 ---------------------------------------------
# 최선착수일후보: {'B': Timestamp('2024-03-04 00:00:00'), 'A': Timestamp('2024-03-04 00:00:00')}
# 최선조기착수대상: ('B', Timestamp('2024-03-04 00:00:00'))
# *** 최선정반: B, 납기: 2024-03-18, , 표준공기: 7, 최소요구착수일: 2024-03-11, 최선착수일: 2024-03-04, gap: 8, 사이즈: (16, 12)
# >>>> 레이아웃검토: 0
# 0: ['S15', 'S24', 'S33', 'S16', 'S18', 'S14', 'S13', 'S26', 'S36', 'S49', 'S34', 'S39', 'S52', 'S50', 'S57', 'S67', 'S30', 'S28', 'S29', 'S31', 'S44', 'S64', 'S63', 'S42', 'S58', 'S55', 'S70', 'S48', 'S68', 'S65', 'S66', 'S75', 'S94', 'S77', 'S97', 'S76', 'S105', 'S61', 'S84', 'S78', 'S79', 'S102', 'S104', 'S95', 'S88', 'S111', 'S108', 'S106', 'S126', 'S116', 'S115', 'S114', 'S120', 'S128', 'S110', 'S118', 'S121', 'S101', 'S125', 'S131']
# 0: ['2023-10-27', '2023-11-02', '2023-11-07', '2023-10-27', '2023-11-03', '2023-10-26', '2023-11-06', '2023-11-14', '2023-11-15', '2023-11-30', '2023-11-14', '2023-11-21', '2023-12-04', '2023-12-12', '2023-12-06', '2023-12-14', '2023-11-15', '2023-11-15', '2023-11-15', '2023-11-15', '2023-11-27', '2023-12-12', '2023-12-18', '2023-11-27', '2023-12-27', '2023-12-06', '2023-12-20', '2023-12-04', '2023-12-19', '2023-12-18', '2023-12-20', '2024-01-02', '2024-01-18', '2024-01-04', '2024-01-19', '2024-01-01', '2024-01-26', '2023-12-20', '2024-01-10', '2024-01-05', '2024-01-09', '2024-02-06', '2024-01-31', '2024-02-13', '2024-01-16', '2024-02-16', '2024-02-07', '2024-02-06', '2024-02-22', '2024-02-27', '2024-03-06', '2024-02-14', '2024-03-06', '2024-03-06', '2024-02-12', '2024-03-06', '2024-02-21', '2024-02-06', '2024-03-15', '2024-03-04']
# --- g: 0, k: 0, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-04
# --- g: 0, k: 1, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-05
# --- g: 0, k: 2, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-06
# -----1차검토 부적합 - Block S128 of height 15 width 13 could not be placed.
# -----1차검토 부적합 - Block S118 of height 16 width 13 could not be placed.
# --- g: 0, k: 3, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-07
# -----1차검토 부적합 - Block S128 of height 15 width 13 could not be placed.
# -----1차검토 부적합 - Block S118 of height 16 width 13 could not be placed.
# --- g: 0, k: 4, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-08
# -----1차검토 부적합 - Block S128 of height 15 width 13 could not be placed.
# -----1차검토 부적합 - Block S118 of height 16 width 13 could not be placed.
# --- g: 0, k: 5, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-09
# -----1차검토 부적합 - Block S128 of height 15 width 13 could not be placed.
# -----1차검토 부적합 - Block S118 of height 16 width 13 could not be placed.
# --- g: 0, k: 6, 레이아웃배치검토시작일: 2024-03-04, 레이아웃검토날짜: 2024-03-10
# -----1차검토 부적합 - Block S128 of height 15 width 13 could not be placed.
# -----1차검토 부적합 - Block S118 of height 16 width 13 could not be placed.
# 레이아웃적합도모음: ['적합', '적합', '적합', '적합', '적합', '적합', '적합']
# 레이아웃검토후최선착수일:  2024-03-04
# 조회기간 최소면적: 381, 블록면적: 192
# 면적달력 업데이트 결과: True
# ================================================================================

# %%
len(배치상태), 배치상태.count("정상배치"), 배치상태.count("배치불가")
# Out:
# (123, 119, 4)

# %%
배치후데이터 = 블록데이터.copy()
배치후데이터["배치결과"] = 배치상태
배치후데이터["착수일자"] = 착수일자
배치후데이터['최소착수요구일'] = pd.to_datetime(배치후데이터['최소착수요구일'])
배치후데이터['착수일자'] = pd.to_datetime(배치후데이터['착수일자'])
배치후데이터["델타"] = 배치후데이터['착수일자'] - 배치후데이터['최소착수요구일']
배치후데이터
# Out:
#       블록명   중량  표준공기          납기       사이즈  최대길이   면적    최소착수요구일   날짜순서  \
# 2     S15  139    10  2023-11-13  (15, 14)    15  210 2023-11-03    4.0
# 11    S24   56    12  2023-11-21  (18, 14)    18  252 2023-11-09    9.5
# 20    S33   33    13  2023-11-27  (19, 15)    19  285 2023-11-14   14.5
# 6     S19   21    12  2023-11-15   (14, 7)    14   98 2023-11-03    4.0
# 3     S16   24    11  2023-11-14   (14, 5)    14   70 2023-11-03    4.0
# 12    S25   98    11  2023-11-21  (19, 13)    19  247 2023-11-10   12.0
# 8     S21   82     8  2023-11-17  (17, 15)    17  255 2023-11-09    9.5
# 4     S17   68     8  2023-11-14  (15, 13)    15  195 2023-11-06    6.5
# 19    S32   84    10  2023-11-27  (17, 15)    17  255 2023-11-17   17.0
# 5     S18   21     9  2023-11-15   (14, 7)    14   98 2023-11-06    6.5
# 1     S14   67     7  2023-11-09  (13, 13)    13  169 2023-11-02    1.5
# 0     S13  131     6  2023-11-08  (15, 14)    15  210 2023-11-02    1.5
# 7     S20   76     8  2023-11-15  (14, 13)    14  182 2023-11-07    8.0
# 9     S22   41    11  2023-11-21   (17, 5)    17   85 2023-11-10   12.0
# 10    S23   20    11  2023-11-21   (17, 5)    17   85 2023-11-10   12.0
# 13    S26   42     9  2023-11-23  (12, 11)    12  132 2023-11-14   14.5
# 23    S36   79     9  2023-12-01  (17, 15)    17  255 2023-11-22   21.5
# 14    S27  106     8  2023-11-23  (19, 13)    19  247 2023-11-15   16.0
# 22    S35   67     7  2023-11-29  (17, 15)    17  255 2023-11-22   21.5
# 32    S45   93    11  2023-12-12  (15, 13)    15  195 2023-12-01   30.0
# 36    S49   56    12  2023-12-19  (18, 14)    18  252 2023-12-07   35.5
# 28    S41  101     9  2023-12-08  (14, 14)    14  196 2023-11-29   29.0
# 21    S34   39     7  2023-11-27  (12, 11)    12  132 2023-11-20   18.0
# 26    S39   85     8  2023-12-06  (14, 14)    14  196 2023-11-28   27.0
# 33    S46   38    12  2023-12-18   (15, 8)    15  120 2023-12-06   34.0
# 27    S40   53     9  2023-12-07   (15, 7)    15  105 2023-11-28   27.0
# 34    S47   38    11  2023-12-18   (15, 8)    15  120 2023-12-07   35.5
# 39    S52   56     9  2023-12-20  (18, 14)    18  252 2023-12-11   38.5
# 25    S38   53     7  2023-12-04   (15, 7)    15  105 2023-11-27   25.0
# 38    S51   67     8  2023-12-19  (17, 15)    17  255 2023-12-11   38.5
# 37    S50   79     8  2023-12-19  (17, 15)    17  255 2023-12-11   38.5
# 44    S57   67    12  2023-12-25  (13, 13)    13  169 2023-12-13   42.5
# 54    S67   56    15  2024-01-05  (18, 14)    18  252 2023-12-21   51.0
# 49    S62   56    13  2024-01-02  (18, 14)    18  252 2023-12-20   50.0
# 17    S30   10     5  2023-11-27   (14, 4)    14   56 2023-11-22   21.5
# 15    S28   10     5  2023-11-27   (14, 4)    14   56 2023-11-22   21.5
# 16    S29    9     5  2023-11-27    (6, 4)     6   24 2023-11-22   21.5
# 18    S31    9     5  2023-11-27    (6, 4)     6   24 2023-11-22   21.5
# 30    S43   41     8  2023-12-12   (17, 5)    17   85 2023-12-04   32.0
# 31    S44   20     8  2023-12-12   (17, 5)    17   85 2023-12-04   32.0
# 24    S37   37     6  2023-12-04   (14, 9)    14  126 2023-11-28   27.0
# 51    S64   38    15  2024-01-03   (15, 8)    15  120 2023-12-19   48.0
# 50    S63   38    15  2024-01-03   (15, 8)    15  120 2023-12-19   48.0
# 29    S42   57     4  2023-12-08  (14, 12)    14  168 2023-12-04   32.0
# 45    S58   84     8  2023-12-27  (17, 15)    17  255 2023-12-19   48.0
# 42    S55   66     8  2023-12-21  (13, 13)    13  169 2023-12-13   42.5
# 46    S59   53    10  2023-12-28   (15, 7)    15  105 2023-12-18   45.5
# 57    S70   85    13  2024-01-09  (14, 14)    14  196 2023-12-27   57.0
# 43    S56   82     7  2023-12-25  (17, 15)    17  255 2023-12-18   45.5
# 35    S48   63     7  2023-12-18   (14, 8)    14  112 2023-12-11   38.5
# 55    S68  101    10  2024-01-05  (14, 14)    14  196 2023-12-26   54.5
# 52    S65   41    11  2024-01-05   (17, 5)    17   85 2023-12-25   52.5
# 53    S66   20    11  2024-01-05   (17, 5)    17   85 2023-12-25   52.5
# 56    S69   53    10  2024-01-05   (15, 7)    15  105 2023-12-26   54.5
# 41    S54   10     7  2023-12-20   (14, 4)    14   56 2023-12-13   42.5
# 40    S53   10     7  2023-12-20   (14, 4)    14   56 2023-12-13   42.5
# 68    S81   38    12  2024-01-23   (15, 8)    15  120 2024-01-11   66.5
# 69    S82   38    12  2024-01-23   (15, 8)    15  120 2024-01-11   66.5
# 58    S71   82     7  2024-01-12  (17, 15)    17  255 2024-01-05   60.0
# 73    S86   56    11  2024-01-29  (18, 14)    18  252 2024-01-18   73.0
# 62    S75   67     7  2024-01-15  (17, 15)    17  255 2024-01-08   63.0
# 61    S74   79     7  2024-01-15  (17, 15)    17  255 2024-01-08   63.0
# 70    S83   31     9  2024-01-24  (16, 13)    16  208 2024-01-15   69.0
# 60    S73   66     7  2024-01-12  (13, 13)    13  169 2024-01-05   60.0
# 59    S72   67     7  2024-01-12  (13, 13)    13  169 2024-01-05   60.0
# 77    S90   81     9  2024-01-31  (31, 12)    31  372 2024-01-22   76.0
# 81    S94   23    19  2024-02-13  (15, 10)    15  150 2024-01-25   80.0
# 64    S77   84     6  2024-01-16  (17, 15)    17  255 2024-01-10   65.0
# 84    S97   59    19  2024-02-14  (14, 11)    14  154 2024-01-26   82.0
# 63    S76   52     7  2024-01-15   (15, 7)    15  105 2024-01-08   63.0
# 67    S80   56     7  2024-01-23  (18, 14)    18  252 2024-01-16   70.5
# 47    S60    9     2  2023-12-29    (6, 4)     6   24 2023-12-27   57.0
# 92   S105   32    18  2024-02-20  (15, 13)    15  195 2024-02-02   87.0
# 48    S61    9     2  2023-12-29    (6, 4)     6   24 2023-12-27   57.0
# 71    S84   53     8  2024-01-25  (15, 10)    15  150 2024-01-17   72.0
# 83    S96   28    15  2024-02-13   (13, 9)    13  117 2024-01-29   83.5
# 86    S99   23    15  2024-02-14  (15, 10)    15  150 2024-01-30   85.0
# 74    S87   84     7  2024-01-29  (17, 15)    17  255 2024-01-22   76.0
# 65    S78   52     7  2024-01-19   (15, 7)    15  105 2024-01-12   68.0
# 85    S98   32    12  2024-02-14  (15, 13)    15  195 2024-02-02   87.0
# 66    S79   31     4  2024-01-20  (16, 13)    16  208 2024-01-16   70.5
# 90   S103   27    13  2024-02-15   (13, 9)    13  117 2024-02-02   87.0
# 89   S102   79    10  2024-02-15  (17, 15)    17  255 2024-02-05   89.5
# 72    S85   53     7  2024-01-26  (15, 10)    15  150 2024-01-19   74.0
# 76    S89   67     7  2024-01-29  (13, 13)    13  169 2024-01-22   76.0
# 91   S104   74    12  2024-02-19  (14, 10)    14  140 2024-02-07   91.0
# 82    S95   67     8  2024-02-13  (17, 15)    17  255 2024-02-05   89.5
# 99   S112   87    11  2024-02-26  (31, 12)    31  372 2024-02-15   98.5
# 75    S88   66     6  2024-01-29  (13, 13)    13  169 2024-01-23   78.0
# 80    S93   82     4  2024-02-02  (17, 15)    17  255 2024-01-29   83.5
# 98   S111   36    11  2024-02-26  (16, 13)    16  208 2024-02-15   98.5
# 79    S92   20     7  2024-02-01   (17, 5)    17   85 2024-01-25   80.0
# 78    S91   41     7  2024-02-01   (17, 5)    17   85 2024-01-25   80.0
# 95   S108   55     9  2024-02-23  (18, 11)    18  198 2024-02-14   96.0
# 96   S109   59     9  2024-02-23   (14, 8)    14  112 2024-02-14   96.0
# 94   S107   24     9  2024-02-23   (14, 5)    14   70 2024-02-14   96.0
# 93   S106   53     7  2024-02-20  (17, 11)    17  187 2024-02-13   93.0
# 106  S119   33    10  2024-03-04  (16, 13)    16  208 2024-02-23  105.5
# 114  S127   56    13  2024-03-13  (18, 14)    18  252 2024-02-29  113.0
# 113  S126   56    13  2024-03-13  (18, 14)    18  252 2024-02-29  113.0
# 122  S135   56    13  2024-03-13  (18, 14)    18  252 2024-02-29  113.0
# 121  S134   56    13  2024-03-13  (18, 14)    18  252 2024-02-29  113.0
# 100  S113   24     8  2024-02-27  (14, 14)    14  196 2024-02-19  101.0
# 103  S116  106     8  2024-02-29  (19, 13)    19  247 2024-02-21  103.0
# 102  S115  129     8  2024-02-29  (15, 14)    15  210 2024-02-21  103.0
# 111  S124  131    12  2024-03-12  (15, 14)    15  210 2024-02-29  113.0
# 101  S114   24     8  2024-02-29  (14, 14)    14  196 2024-02-21  103.0
# 107  S120   91     9  2024-03-06  (15, 13)    15  195 2024-02-26  107.5
# 119  S132  131    12  2024-03-13  (15, 14)    15  210 2024-03-01  116.0
# 115  S128   91     9  2024-03-08  (15, 13)    15  195 2024-02-28  109.5
# 97   S110   59     7  2024-02-23   (14, 8)    14  112 2024-02-16  100.0
# 105  S118   32     7  2024-03-01  (16, 13)    16  208 2024-02-23  105.5
# 108  S121   74     8  2024-03-07  (16, 12)    16  192 2024-02-28  109.5
# 88   S101    2     2  2024-02-15    (6, 3)     6   18 2024-02-13   93.0
# 87   S100    2     2  2024-02-15    (6, 3)     6   18 2024-02-13   93.0
# 112  S125   33     8  2024-03-12  (19, 15)    19  285 2024-03-04  118.0
# 120  S133   33     8  2024-03-18  (19, 15)    19  285 2024-03-10  121.0
# 109  S122   83     7  2024-03-11  (27, 15)    27  405 2024-03-04  118.0
# 104  S117   68     4  2024-03-01  (15, 13)    15  195 2024-02-26  107.5
# 117  S130   83     7  2024-03-15  (27, 15)    27  405 2024-03-08  120.0
# 116  S129   74     8  2024-03-19  (16, 12)    16  192 2024-03-11  122.5
# 110  S123   74     7  2024-03-11  (16, 12)    16  192 2024-03-04  118.0
# 118  S131   74     7  2024-03-18  (16, 12)    16  192 2024-03-11  122.5
#
#       공기순서   크기순서  우선순위  배치결과       착수일자      델타
# 2     42.0   40.0   5.5  정상배치 2023-10-27 -7 days
# 11    22.0   29.0   5.6  정상배치 2023-11-02 -7 days
# 20    12.5    6.0   5.9  정상배치 2023-11-07 -7 days
# 6     22.0  102.5   6.2  정상배치 2023-10-27 -7 days
# 3     33.0  112.5   7.3  정상배치 2023-10-27 -7 days
# 12    33.0   36.0   7.4  정상배치 2023-11-03 -7 days
# 8     69.0   15.5   8.3  정상배치 2023-11-02 -7 days
# 4     69.0   58.0   8.7  정상배치 2023-11-10  4 days
# 19    42.0   15.5   9.0  정상배치 2023-11-14 -3 days
# 5     52.0  102.5   9.0  정상배치 2023-11-03 -3 days
# 1     93.5   71.0   9.1  정상배치 2023-10-26 -7 days
# 0    109.5   40.0   9.1  정상배치 2023-10-26 -7 days
# 7     69.0   67.0   9.5  배치불가        NaT     NaT
# 9     33.0  107.5   9.8  정상배치 2023-11-03 -7 days
# 10    33.0  107.5   9.8  정상배치 2023-11-03 -7 days
# 13    52.0   82.5  11.0  정상배치 2023-11-14  0 days
# 23    52.0   15.5  11.1  정상배치 2023-11-15 -7 days
# 14    69.0   36.0  11.1  정상배치 2023-11-18  3 days
# 22    93.5   15.5  13.9  정상배치 2023-11-25  3 days
# 32    33.0   58.0  14.1  정상배치 2023-11-26 -5 days
# 36    22.0   29.0  14.3  정상배치 2023-11-30 -7 days
# 28    52.0   51.5  14.8  정상배치 2023-11-22 -7 days
# 21    93.5   82.5  15.0  정상배치 2023-11-14 -6 days
# 26    69.0   51.5  15.3  정상배치 2023-11-21 -7 days
# 33    22.0   87.5  15.7  정상배치 2023-11-29 -7 days
# 27    52.0   98.5  15.8  정상배치 2023-11-21 -7 days
# 34    33.0   87.5  17.0  정상배치 2023-11-30 -7 days
# 39    52.0   29.0  17.3  정상배치 2023-12-04 -7 days
# 25    93.5   98.5  17.8  정상배치 2023-11-20 -7 days
# 38    69.0   15.5  18.0  정상배치 2023-12-07 -4 days
# 37    69.0   15.5  18.0  정상배치 2023-12-12  1 days
# 44    22.0   71.0  18.0  정상배치 2023-12-06 -7 days
# 54     6.0   29.0  18.4  정상배치 2023-12-14 -7 days
# 49    12.5   29.0  18.5  정상배치 2023-12-13 -7 days
# 17   113.5  115.5  18.6  정상배치 2023-11-15 -7 days
# 15   113.5  115.5  18.6  정상배치 2023-11-15 -7 days
# 16   113.5  119.5  18.7  정상배치 2023-11-15 -7 days
# 18   113.5  119.5  18.7  정상배치 2023-11-15 -7 days
# 30    69.0  107.5  18.8  정상배치 2023-11-27 -7 days
# 31    69.0  107.5  18.8  정상배치 2023-11-27 -7 days
# 24   109.5   84.0  19.1  정상배치 2023-12-02  4 days
# 51     6.0   87.5  19.3  정상배치 2023-12-12 -7 days
# 50     6.0   87.5  19.3  정상배치 2023-12-18 -1 days
# 29   117.5   75.0  21.0  정상배치 2023-11-27 -7 days
# 45    69.0   15.5  21.1  정상배치 2023-12-27  8 days
# 42    69.0   71.0  21.1  정상배치 2023-12-06 -7 days
# 46    42.0   98.5  21.2  정상배치 2023-12-11 -7 days
# 57    12.5   51.5  21.6  정상배치 2023-12-20 -7 days
# 43    93.5   15.5  21.9  정상배치 2023-12-15 -3 days
# 35    93.5   94.0  22.2  정상배치 2023-12-04 -7 days
# 55    42.0   51.5  22.7  정상배치 2023-12-19 -7 days
# 52    33.0  107.5  23.3  정상배치 2023-12-18 -7 days
# 53    33.0  107.5  23.3  정상배치 2023-12-20 -5 days
# 56    42.0   98.5  24.2  정상배치 2023-12-19 -7 days
# 41    93.5  115.5  24.2  정상배치 2023-12-06 -7 days
# 40    93.5  115.5  24.2  정상배치 2023-12-06 -7 days
# 68    22.0   87.5  26.6  정상배치 2024-01-04 -7 days
# 69    22.0   87.5  26.6  정상배치 2024-01-04 -7 days
# 58    93.5   15.5  26.8  정상배치 2023-12-29 -7 days
# 73    33.0   29.0  27.5  정상배치 2024-01-11 -7 days
# 62    93.5   15.5  27.8  정상배치 2024-01-02 -6 days
# 61    93.5   15.5  27.8  정상배치 2024-01-16  8 days
# 70    52.0   45.0  28.0  정상배치 2024-01-22  7 days
# 60    93.5   71.0  28.6  정상배치 2023-12-29 -7 days
# 59    93.5   71.0  28.6  정상배치 2023-12-29 -7 days
# 77    52.0    3.5  28.9  정상배치 2024-01-31  9 days
# 81     1.5   78.5  29.4  정상배치 2024-01-18 -7 days
# 64   109.5   15.5  29.5  정상배치 2024-01-04 -6 days
# 84     1.5   76.0  30.0  정상배치 2024-01-19 -7 days
# 63    93.5   98.5  30.5  정상배치 2024-01-01 -7 days
# 67    93.5   29.0  30.7  정상배치 2024-01-23  7 days
# 47   121.5  119.5  31.1  정상배치 2023-12-20 -7 days
# 92     3.0   58.0  31.1  정상배치 2024-01-26 -7 days
# 48   121.5  119.5  31.1  정상배치 2023-12-20 -7 days
# 71    69.0   78.5  31.2  정상배치 2024-01-10 -7 days
# 83     6.0   91.5  31.3  정상배치 2024-01-22 -7 days
# 86     6.0   78.5  31.4  정상배치 2024-01-30  0 days
# 74    93.5   15.5  32.1  정상배치 2024-01-31  9 days
# 65    93.5   98.5  32.2  정상배치 2024-01-05 -7 days
# 85    22.0   58.0  32.4  정상배치 2024-02-06  4 days
# 66   117.5   45.0  32.8  정상배치 2024-01-09 -7 days
# 90    12.5   91.5  32.9  정상배치 2024-01-26 -7 days
# 89    42.0   15.5  33.2  정상배치 2024-02-06  1 days
# 72    93.5   78.5  33.5  정상배치 2024-01-12 -7 days
# 76    93.5   71.0  33.9  정상배치 2024-01-15 -7 days
# 91    22.0   81.0  34.5  정상배치 2024-01-31 -7 days
# 82    69.0   15.5  34.9  정상배치 2024-02-13  8 days
# 99    33.0    3.5  35.2  정상배치 2024-02-09 -6 days
# 75   109.5   71.0  35.7  정상배치 2024-01-16 -7 days
# 80   117.5   15.5  36.2  정상배치 2024-02-08 10 days
# 98    33.0   45.0  36.5  정상배치 2024-02-16  1 days
# 79    93.5  107.5  36.5  정상배치 2024-01-18 -7 days
# 78    93.5  107.5  36.5  정상배치 2024-01-18 -7 days
# 95    52.0   48.0  37.1  정상배치 2024-02-07 -7 days
# 96    52.0   94.0  38.6  정상배치 2024-02-12 -2 days
# 94    52.0  112.5  39.2  정상배치 2024-02-12 -2 days
# 93    93.5   66.0  39.4  정상배치 2024-02-06 -7 days
# 106   42.0   45.0  39.5  정상배치 2024-02-16 -7 days
# 114   12.5   29.0  39.5  정상배치 2024-02-22 -7 days
# 113   12.5   29.0  39.5  정상배치 2024-02-22 -7 days
# 122   12.5   29.0  39.5  정상배치 2024-02-26 -3 days
# 121   12.5   29.0  39.5  정상배치 2024-03-06  6 days
# 100   69.0   51.5  40.0  정상배치 2024-02-12 -7 days
# 103   69.0   36.0  40.1  정상배치 2024-02-27  6 days
# 102   69.0   40.0  40.3  정상배치 2024-03-06 14 days
# 111   22.0   40.0  40.5  정상배치 2024-03-10 10 days
# 101   69.0   51.5  40.6  정상배치 2024-02-14 -7 days
# 107   52.0   58.0  41.2  정상배치 2024-03-06  9 days
# 119   22.0   40.0  41.5  배치불가        NaT     NaT
# 115   52.0   58.0  41.9  정상배치 2024-03-06  7 days
# 97    93.5   94.0  42.7  정상배치 2024-02-12 -4 days
# 105   93.5   45.0  42.9  정상배치 2024-03-06 12 days
# 108   69.0   63.5  43.2  정상배치 2024-02-21 -7 days
# 88   121.5  122.5  43.2  정상배치 2024-02-06 -7 days
# 87   121.5  122.5  43.2  정상배치 2024-02-07 -6 days
# 112   69.0    6.0  44.1  정상배치 2024-03-15 11 days
# 120   69.0    6.0  45.1  정상배치 2024-03-22 12 days
# 109   93.5    1.5  45.6  배치불가        NaT     NaT
# 104  117.5   58.0  45.6  정상배치 2024-02-20 -6 days
# 117   93.5    1.5  46.3  배치불가        NaT     NaT
# 116   69.0   63.5  47.6  정상배치 2024-03-04 -7 days
# 110   93.5   63.5  47.7  정상배치 2024-02-26 -7 days
# 118   93.5   63.5  49.2  정상배치 2024-03-04 -7 days

# %%
블록명달력
# Out:
#                                     B                               A
# 2023-10-01                         []                              []
# 2023-10-02                         []                              []
# 2023-10-03                         []                              []
# 2023-10-04                         []                              []
# 2023-10-05                         []                              []
# 2023-10-06                         []                              []
# 2023-10-07                         []                              []
# 2023-10-08                         []                              []
# 2023-10-09                         []                              []
# 2023-10-10                         []                              []
# 2023-10-11                         []                              []
# 2023-10-12                         []                              []
# 2023-10-13                         []                              []
# 2023-10-14                         []                              []
# 2023-10-15                         []                              []
# 2023-10-16                         []                              []
# 2023-10-17                         []                              []
# 2023-10-18                         []                              []
# 2023-10-19                         []                              []
# 2023-10-20                         []                              []
# 2023-10-21                         []                              []
# 2023-10-22                         []                              []
# 2023-10-23                         []                              []
# 2023-10-24                         []                              []
# 2023-10-25                         []                              []
# 2023-10-26                      [S14]                           [S13]
# 2023-10-27            [S14, S19, S16]                           [S13]
# 2023-10-28            [S14, S19, S16]                           [S13]
# 2023-10-29            [S14, S19, S16]                           [S13]
# 2023-10-30            [S14, S19, S16]                           [S13]
# 2023-10-31            [S14, S19, S16]                           [S13]
# 2023-11-01       [S14, S19, S16, S17]                           [S15]
# 2023-11-02       [S19, S16, S17, S20]                      [S15, S18]
# 2023-11-03  [S19, S16, S17, S20, S22]            [S15, S18, S21, S23]
# 2023-11-04  [S19, S16, S17, S20, S22]            [S15, S18, S21, S23]
# 2023-11-05  [S19, S16, S17, S20, S22]            [S15, S18, S21, S23]
# 2023-11-06  [S19, S16, S17, S20, S22]            [S15, S18, S21, S23]
# 2023-11-07  [S19, S17, S24, S20, S22]            [S15, S18, S21, S23]
# 2023-11-08       [S17, S24, S20, S22]            [S15, S18, S21, S23]
# 2023-11-09            [S24, S20, S22]            [S15, S18, S21, S23]
# 2023-11-10            [S24, S22, S32]            [S15, S18, S21, S23]
# 2023-11-11            [S24, S22, S32]                 [S25, S33, S23]
# 2023-11-12            [S24, S22, S32]                 [S25, S33, S23]
# 2023-11-13       [S24, S22, S32, S34]                 [S25, S33, S23]
# 2023-11-14            [S24, S32, S34]                 [S25, S33, S26]
# 2023-11-15       [S24, S32, S34, S31]  [S25, S33, S26, S28, S29, S30]
# 2023-11-16       [S24, S32, S34, S31]  [S25, S33, S26, S28, S29, S30]
# 2023-11-17       [S24, S32, S34, S31]  [S25, S33, S26, S28, S29, S30]
# 2023-11-18       [S24, S32, S34, S31]  [S25, S33, S26, S28, S29, S30]
# 2023-11-19       [S32, S34, S35, S31]  [S25, S33, S26, S28, S29, S30]
# 2023-11-20                      [S35]                 [S25, S33, S26]
# 2023-11-21                 [S35, S37]                 [S25, S33, S26]
# 2023-11-22                 [S35, S37]                 [S33, S26, S27]
# 2023-11-23                 [S35, S37]                      [S33, S27]
# 2023-11-24                 [S35, S37]                      [S27, S36]
# 2023-11-25                 [S35, S37]                      [S27, S36]
# 2023-11-26                      [S37]                      [S27, S36]
# 2023-11-27                         []                      [S27, S36]
# 2023-11-28                         []                      [S27, S36]
# 2023-11-29                         []                      [S27, S36]
# 2023-11-30                         []                           [S36]
# 2023-12-01                         []                           [S36]
# 2023-12-02                         []                           [S36]
# 2023-12-03                         []                              []
# 2023-12-04                         []                              []
# 2023-12-05                         []                              []
# 2023-12-06                         []                              []
# 2023-12-07                         []                              []
# 2023-12-08                         []                              []
# 2023-12-09                         []                              []
# 2023-12-10                         []                              []
# 2023-12-11                         []                              []
# 2023-12-12                         []                              []
# 2023-12-13                         []                              []
# 2023-12-14                         []                              []
# 2023-12-15                         []                              []
# 2023-12-16                         []                              []
# 2023-12-17                         []                              []
# 2023-12-18                         []                              []
# 2023-12-19                         []                              []
# 2023-12-20                         []                              []
# 2023-12-21                         []                              []
# 2023-12-22                         []                              []
# 2023-12-23                         []                              []
# 2023-12-24                         []                              []
# 2023-12-25                         []                              []
# 2023-12-26                         []                              []
# 2023-12-27                         []                              []
# 2023-12-28                         []                              []
# 2023-12-29                         []                              []
# 2023-12-30                         []                              []
# 2023-12-31                         []                              []
# 2024-01-01                         []                              []
# 2024-01-02                         []                              []
# 2024-01-03                         []                              []
# 2024-01-04                         []                              []
# 2024-01-05                         []                              []
# 2024-01-06                         []                              []
# 2024-01-07                         []                              []
# 2024-01-08                         []                              []
# 2024-01-09                         []                              []
# 2024-01-10                         []                              []
# 2024-01-11                         []                              []
# 2024-01-12                         []                              []
# 2024-01-13                         []                              []
# 2024-01-14                         []                              []
# 2024-01-15                         []                              []
# 2024-01-16                         []                              []
# 2024-01-17                         []                              []
# 2024-01-18                         []                              []
# 2024-01-19                         []                              []
# 2024-01-20                         []                              []
# 2024-01-21                         []                              []
# 2024-01-22                         []                              []
# 2024-01-23                         []                              []
# 2024-01-24                         []                              []
# 2024-01-25                         []                              []
# 2024-01-26                         []                              []
# 2024-01-27                         []                              []
# 2024-01-28                         []                              []
# 2024-01-29                         []                              []
# 2024-01-30                         []                              []
# 2024-01-31                         []                              []
# 2024-02-01                         []                              []
# 2024-02-02                         []                              []
# 2024-02-03                         []                              []
# 2024-02-04                         []                              []
# 2024-02-05                         []                              []
# 2024-02-06                         []                              []
# 2024-02-07                         []                              []
# 2024-02-08                         []                              []
# 2024-02-09                         []                              []
# 2024-02-10                         []                              []
# 2024-02-11                         []                              []
# 2024-02-12                         []                              []
# 2024-02-13                         []                              []
# 2024-02-14                         []                              []
# 2024-02-15                         []                              []
# 2024-02-16                         []                              []
# 2024-02-17                         []                              []
# 2024-02-18                         []                              []
# 2024-02-19                         []                              []
# 2024-02-20                         []                              []
# 2024-02-21                         []                              []
# 2024-02-22                         []                              []
# 2024-02-23                         []                              []
# 2024-02-24                         []                              []
# 2024-02-25                         []                              []
# 2024-02-26                         []                              []
# 2024-02-27                         []                              []
# 2024-02-28                         []                              []
# 2024-02-29                         []                              []
# 2024-03-01                         []                              []
# 2024-03-02                         []                              []
# 2024-03-03                         []                              []
# 2024-03-04                         []                              []
# 2024-03-05                         []                              []
# 2024-03-06                         []                              []
# 2024-03-07                         []                              []
# 2024-03-08                         []                              []
# 2024-03-09                         []                              []
# 2024-03-10                         []                              []
# 2024-03-11                         []                              []
# 2024-03-12                         []                              []
# 2024-03-13                         []                              []
# 2024-03-14                         []                              []
# 2024-03-15                         []                              []
# 2024-03-16                         []                              []
# 2024-03-17                         []                              []
# 2024-03-18                         []                              []
# 2024-03-19                         []                              []
# 2024-03-20                         []                              []
# 2024-03-21                         []                              []
# 2024-03-22                         []                              []
# 2024-03-23                         []                              []
# 2024-03-24                         []                              []
# 2024-03-25                         []                              []
# 2024-03-26                         []                              []
# 2024-03-27                         []                              []
# 2024-03-28                         []                              []
# 2024-03-29                         []                              []
# 2024-03-30                         []                              []
# 2024-03-31                         []                              []

# %%
사이즈달력
# Out:
#                                                            B  \
# 2023-10-01                                                []
# 2023-10-02                                                []
# 2023-10-03                                                []
# 2023-10-04                                                []
# 2023-10-05                                                []
# 2023-10-06                                                []
# 2023-10-07                                                []
# 2023-10-08                                                []
# 2023-10-09                                                []
# 2023-10-10                                                []
# 2023-10-11                                                []
# 2023-10-12                                                []
# 2023-10-13                                                []
# 2023-10-14                                                []
# 2023-10-15                                                []
# 2023-10-16                                                []
# 2023-10-17                                                []
# 2023-10-18                                                []
# 2023-10-19                                                []
# 2023-10-20                                                []
# 2023-10-21                                                []
# 2023-10-22                                                []
# 2023-10-23                                                []
# 2023-10-24                                                []
# 2023-10-25                                                []
# 2023-10-26                                        [(13, 13)]
# 2023-10-27                      [(13, 13), (14, 7), (14, 5)]
# 2023-10-28                      [(13, 13), (14, 7), (14, 5)]
# 2023-10-29                      [(13, 13), (14, 7), (14, 5)]
# 2023-10-30                      [(13, 13), (14, 7), (14, 5)]
# 2023-10-31                      [(13, 13), (14, 7), (14, 5)]
# 2023-11-01            [(13, 13), (14, 7), (14, 5), (15, 13)]
# 2023-11-02            [(14, 7), (14, 5), (15, 13), (14, 13)]
# 2023-11-03   [(14, 7), (14, 5), (15, 13), (14, 13), (17, 5)]
# 2023-11-04   [(14, 7), (14, 5), (15, 13), (14, 13), (17, 5)]
# 2023-11-05   [(14, 7), (14, 5), (15, 13), (14, 13), (17, 5)]
# 2023-11-06   [(14, 7), (14, 5), (15, 13), (14, 13), (17, 5)]
# 2023-11-07  [(14, 7), (15, 13), (18, 14), (14, 13), (17, 5)]
# 2023-11-08           [(15, 13), (18, 14), (14, 13), (17, 5)]
# 2023-11-09                     [(18, 14), (14, 13), (17, 5)]
# 2023-11-10                     [(18, 14), (17, 5), (17, 15)]
# 2023-11-11                     [(18, 14), (17, 5), (17, 15)]
# 2023-11-12                     [(18, 14), (17, 5), (17, 15)]
# 2023-11-13           [(18, 14), (17, 5), (17, 15), (12, 11)]
# 2023-11-14                    [(18, 14), (17, 15), (12, 11)]
# 2023-11-15            [(18, 14), (17, 15), (12, 11), (6, 4)]
# 2023-11-16            [(18, 14), (17, 15), (12, 11), (6, 4)]
# 2023-11-17            [(18, 14), (17, 15), (12, 11), (6, 4)]
# 2023-11-18            [(18, 14), (17, 15), (12, 11), (6, 4)]
# 2023-11-19            [(17, 15), (12, 11), (17, 15), (6, 4)]
# 2023-11-20                                        [(17, 15)]
# 2023-11-21                               [(17, 15), (14, 9)]
# 2023-11-22                               [(17, 15), (14, 9)]
# 2023-11-23                               [(17, 15), (14, 9)]
# 2023-11-24                               [(17, 15), (14, 9)]
# 2023-11-25                               [(17, 15), (14, 9)]
# 2023-11-26                                         [(14, 9)]
# 2023-11-27                                                []
# 2023-11-28                                                []
# 2023-11-29                                                []
# 2023-11-30                                                []
# 2023-12-01                                                []
# 2023-12-02                                                []
# 2023-12-03                                                []
# 2023-12-04                                                []
# 2023-12-05                                                []
# 2023-12-06                                                []
# 2023-12-07                                                []
# 2023-12-08                                                []
# 2023-12-09                                                []
# 2023-12-10                                                []
# 2023-12-11                                                []
# 2023-12-12                                                []
# 2023-12-13                                                []
# 2023-12-14                                                []
# 2023-12-15                                                []
# 2023-12-16                                                []
# 2023-12-17                                                []
# 2023-12-18                                                []
# 2023-12-19                                                []
# 2023-12-20                                                []
# 2023-12-21                                                []
# 2023-12-22                                                []
# 2023-12-23                                                []
# 2023-12-24                                                []
# 2023-12-25                                                []
# 2023-12-26                                                []
# 2023-12-27                                                []
# 2023-12-28                                                []
# 2023-12-29                                                []
# 2023-12-30                                                []
# 2023-12-31                                                []
# 2024-01-01                                                []
# 2024-01-02                                                []
# 2024-01-03                                                []
# 2024-01-04                                                []
# 2024-01-05                                                []
# 2024-01-06                                                []
# 2024-01-07                                                []
# 2024-01-08                                                []
# 2024-01-09                                                []
# 2024-01-10                                                []
# 2024-01-11                                                []
# 2024-01-12                                                []
# 2024-01-13                                                []
# 2024-01-14                                                []
# 2024-01-15                                                []
# 2024-01-16                                                []
# 2024-01-17                                                []
# 2024-01-18                                                []
# 2024-01-19                                                []
# 2024-01-20                                                []
# 2024-01-21                                                []
# 2024-01-22                                                []
# 2024-01-23                                                []
# 2024-01-24                                                []
# 2024-01-25                                                []
# 2024-01-26                                                []
# 2024-01-27                                                []
# 2024-01-28                                                []
# 2024-01-29                                                []
# 2024-01-30                                                []
# 2024-01-31                                                []
# 2024-02-01                                                []
# 2024-02-02                                                []
# 2024-02-03                                                []
# 2024-02-04                                                []
# 2024-02-05                                                []
# 2024-02-06                                                []
# 2024-02-07                                                []
# 2024-02-08                                                []
# 2024-02-09                                                []
# 2024-02-10                                                []
# 2024-02-11                                                []
# 2024-02-12                                                []
# 2024-02-13                                                []
# 2024-02-14                                                []
# 2024-02-15                                                []
# 2024-02-16                                                []
# 2024-02-17                                                []
# 2024-02-18                                                []
# 2024-02-19                                                []
# 2024-02-20                                                []
# 2024-02-21                                                []
# 2024-02-22                                                []
# 2024-02-23                                                []
# 2024-02-24                                                []
# 2024-02-25                                                []
# 2024-02-26                                                []
# 2024-02-27                                                []
# 2024-02-28                                                []
# 2024-02-29                                                []
# 2024-03-01                                                []
# 2024-03-02                                                []
# 2024-03-03                                                []
# 2024-03-04                                                []
# 2024-03-05                                                []
# 2024-03-06                                                []
# 2024-03-07                                                []
# 2024-03-08                                                []
# 2024-03-09                                                []
# 2024-03-10                                                []
# 2024-03-11                                                []
# 2024-03-12                                                []
# 2024-03-13                                                []
# 2024-03-14                                                []
# 2024-03-15                                                []
# 2024-03-16                                                []
# 2024-03-17                                                []
# 2024-03-18                                                []
# 2024-03-19                                                []
# 2024-03-20                                                []
# 2024-03-21                                                []
# 2024-03-22                                                []
# 2024-03-23                                                []
# 2024-03-24                                                []
# 2024-03-25                                                []
# 2024-03-26                                                []
# 2024-03-27                                                []
# 2024-03-28                                                []
# 2024-03-29                                                []
# 2024-03-30                                                []
# 2024-03-31                                                []
#
#                                                             A
# 2023-10-01                                                 []
# 2023-10-02                                                 []
# 2023-10-03                                                 []
# 2023-10-04                                                 []
# 2023-10-05                                                 []
# 2023-10-06                                                 []
# 2023-10-07                                                 []
# 2023-10-08                                                 []
# 2023-10-09                                                 []
# 2023-10-10                                                 []
# 2023-10-11                                                 []
# 2023-10-12                                                 []
# 2023-10-13                                                 []
# 2023-10-14                                                 []
# 2023-10-15                                                 []
# 2023-10-16                                                 []
# 2023-10-17                                                 []
# 2023-10-18                                                 []
# 2023-10-19                                                 []
# 2023-10-20                                                 []
# 2023-10-21                                                 []
# 2023-10-22                                                 []
# 2023-10-23                                                 []
# 2023-10-24                                                 []
# 2023-10-25                                                 []
# 2023-10-26                                         [(15, 14)]
# 2023-10-27                                         [(15, 14)]
# 2023-10-28                                         [(15, 14)]
# 2023-10-29                                         [(15, 14)]
# 2023-10-30                                         [(15, 14)]
# 2023-10-31                                         [(15, 14)]
# 2023-11-01                                         [(15, 14)]
# 2023-11-02                                [(15, 14), (14, 7)]
# 2023-11-03             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-04             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-05             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-06             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-07             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-08             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-09             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-10             [(15, 14), (14, 7), (17, 15), (17, 5)]
# 2023-11-11                      [(19, 13), (19, 15), (17, 5)]
# 2023-11-12                      [(19, 13), (19, 15), (17, 5)]
# 2023-11-13                      [(19, 13), (19, 15), (17, 5)]
# 2023-11-14                     [(19, 13), (19, 15), (12, 11)]
# 2023-11-15  [(19, 13), (19, 15), (12, 11), (14, 4), (6, 4)...
# 2023-11-16  [(19, 13), (19, 15), (12, 11), (14, 4), (6, 4)...
# 2023-11-17  [(19, 13), (19, 15), (12, 11), (14, 4), (6, 4)...
# 2023-11-18  [(19, 13), (19, 15), (12, 11), (14, 4), (6, 4)...
# 2023-11-19  [(19, 13), (19, 15), (12, 11), (14, 4), (6, 4)...
# 2023-11-20                     [(19, 13), (19, 15), (12, 11)]
# 2023-11-21                     [(19, 13), (19, 15), (12, 11)]
# 2023-11-22                     [(19, 15), (12, 11), (19, 13)]
# 2023-11-23                               [(19, 15), (19, 13)]
# 2023-11-24                               [(19, 13), (17, 15)]
# 2023-11-25                               [(19, 13), (17, 15)]
# 2023-11-26                               [(19, 13), (17, 15)]
# 2023-11-27                               [(19, 13), (17, 15)]
# 2023-11-28                               [(19, 13), (17, 15)]
# 2023-11-29                               [(19, 13), (17, 15)]
# 2023-11-30                                         [(17, 15)]
# 2023-12-01                                         [(17, 15)]
# 2023-12-02                                         [(17, 15)]
# 2023-12-03                                                 []
# 2023-12-04                                                 []
# 2023-12-05                                                 []
# 2023-12-06                                                 []
# 2023-12-07                                                 []
# 2023-12-08                                                 []
# 2023-12-09                                                 []
# 2023-12-10                                                 []
# 2023-12-11                                                 []
# 2023-12-12                                                 []
# 2023-12-13                                                 []
# 2023-12-14                                                 []
# 2023-12-15                                                 []
# 2023-12-16                                                 []
# 2023-12-17                                                 []
# 2023-12-18                                                 []
# 2023-12-19                                                 []
# 2023-12-20                                                 []
# 2023-12-21                                                 []
# 2023-12-22                                                 []
# 2023-12-23                                                 []
# 2023-12-24                                                 []
# 2023-12-25                                                 []
# 2023-12-26                                                 []
# 2023-12-27                                                 []
# 2023-12-28                                                 []
# 2023-12-29                                                 []
# 2023-12-30                                                 []
# 2023-12-31                                                 []
# 2024-01-01                                                 []
# 2024-01-02                                                 []
# 2024-01-03                                                 []
# 2024-01-04                                                 []
# 2024-01-05                                                 []
# 2024-01-06                                                 []
# 2024-01-07                                                 []
# 2024-01-08                                                 []
# 2024-01-09                                                 []
# 2024-01-10                                                 []
# 2024-01-11                                                 []
# 2024-01-12                                                 []
# 2024-01-13                                                 []
# 2024-01-14                                                 []
# 2024-01-15                                                 []
# 2024-01-16                                                 []
# 2024-01-17                                                 []
# 2024-01-18                                                 []
# 2024-01-19                                                 []
# 2024-01-20                                                 []
# 2024-01-21                                                 []
# 2024-01-22                                                 []
# 2024-01-23                                                 []
# 2024-01-24                                                 []
# 2024-01-25                                                 []
# 2024-01-26                                                 []
# 2024-01-27                                                 []
# 2024-01-28                                                 []
# 2024-01-29                                                 []
# 2024-01-30                                                 []
# 2024-01-31                                                 []
# 2024-02-01                                                 []
# 2024-02-02                                                 []
# 2024-02-03                                                 []
# 2024-02-04                                                 []
# 2024-02-05                                                 []
# 2024-02-06                                                 []
# 2024-02-07                                                 []
# 2024-02-08                                                 []
# 2024-02-09                                                 []
# 2024-02-10                                                 []
# 2024-02-11                                                 []
# 2024-02-12                                                 []
# 2024-02-13                                                 []
# 2024-02-14                                                 []
# 2024-02-15                                                 []
# 2024-02-16                                                 []
# 2024-02-17                                                 []
# 2024-02-18                                                 []
# 2024-02-19                                                 []
# 2024-02-20                                                 []
# 2024-02-21                                                 []
# 2024-02-22                                                 []
# 2024-02-23                                                 []
# 2024-02-24                                                 []
# 2024-02-25                                                 []
# 2024-02-26                                                 []
# 2024-02-27                                                 []
# 2024-02-28                                                 []
# 2024-02-29                                                 []
# 2024-03-01                                                 []
# 2024-03-02                                                 []
# 2024-03-03                                                 []
# 2024-03-04                                                 []
# 2024-03-05                                                 []
# 2024-03-06                                                 []
# 2024-03-07                                                 []
# 2024-03-08                                                 []
# 2024-03-09                                                 []
# 2024-03-10                                                 []
# 2024-03-11                                                 []
# 2024-03-12                                                 []
# 2024-03-13                                                 []
# 2024-03-14                                                 []
# 2024-03-15                                                 []
# 2024-03-16                                                 []
# 2024-03-17                                                 []
# 2024-03-18                                                 []
# 2024-03-19                                                 []
# 2024-03-20                                                 []
# 2024-03-21                                                 []
# 2024-03-22                                                 []
# 2024-03-23                                                 []
# 2024-03-24                                                 []
# 2024-03-25                                                 []
# 2024-03-26                                                 []
# 2024-03-27                                                 []
# 2024-03-28                                                 []
# 2024-03-29                                                 []
# 2024-03-30                                                 []
# 2024-03-31                                                 []

# %%
면적달력
# Out:
#                B     A
# 2023-10-01  1189  1176
# 2023-10-02  1189  1176
# 2023-10-03  1189  1176
# 2023-10-04  1189  1176
# 2023-10-05  1189  1176
# 2023-10-06  1189  1176
# 2023-10-07  1189  1176
# 2023-10-08  1189  1176
# 2023-10-09  1189  1176
# 2023-10-10  1189  1176
# 2023-10-11  1189  1176
# 2023-10-12  1189  1176
# 2023-10-13  1189  1176
# 2023-10-14  1189  1176
# 2023-10-15  1189  1176
# 2023-10-16  1114  1176
# 2023-10-17  1039  1176
# 2023-10-18  1039  1176
# 2023-10-19  1039  1176
# 2023-10-20  1039  1176
# 2023-10-21  1039  1176
# 2023-10-22  1039  1176
# 2023-10-23  1039  1071
# 2023-10-24  1039   966
# 2023-10-25   927   854
# 2023-10-26   758   436
# 2023-10-27   382    31
# 2023-10-28   382    31
# 2023-10-29   382    31
# 2023-10-30   130    31
# 2023-10-31   130    31
# 2023-11-01    15    72
# 2023-11-02     2    86
# 2023-11-03    29   151
# 2023-11-04    29   151
# 2023-11-05    29   151
# 2023-11-06    29   151
# 2023-11-07    55   359
# 2023-11-08   153   359
# 2023-11-09   348   359
# 2023-11-10   527   528
# 2023-11-11   527   559
# 2023-11-12   527   559
# 2023-11-13   465   559
# 2023-11-14   550   512
# 2023-11-15   526   376
# 2023-11-16   526   376
# 2023-11-17   526   376
# 2023-11-18   526   376
# 2023-11-19   523   376
# 2023-11-20   934   512
# 2023-11-21   808   512
# 2023-11-22   808   512
# 2023-11-23   808   644
# 2023-11-24   808   674
# 2023-11-25   808   674
# 2023-11-26  1063   674
# 2023-11-27  1189   674
# 2023-11-28  1189   674
# 2023-11-29  1189   674
# 2023-11-30  1189   921
# 2023-12-01  1189   921
# 2023-12-02  1189   921
# 2023-12-03  1189  1176
# 2023-12-04  1189  1176
# 2023-12-05  1189  1176
# 2023-12-06  1189  1176
# 2023-12-07  1189  1176
# 2023-12-08  1189  1176
# 2023-12-09  1189  1176
# 2023-12-10  1189  1176
# 2023-12-11  1189  1176
# 2023-12-12  1189  1176
# 2023-12-13  1189  1176
# 2023-12-14  1189  1176
# 2023-12-15  1189  1176
# 2023-12-16  1189  1176
# 2023-12-17  1189  1176
# 2023-12-18  1189  1176
# 2023-12-19  1189  1176
# 2023-12-20  1189  1176
# 2023-12-21  1189  1176
# 2023-12-22  1189  1176
# 2023-12-23  1189  1176
# 2023-12-24  1189  1176
# 2023-12-25  1189  1176
# 2023-12-26  1189  1176
# 2023-12-27  1189  1176
# 2023-12-28  1189  1176
# 2023-12-29  1189  1176
# 2023-12-30  1189  1176
# 2023-12-31  1189  1176
# 2024-01-01  1189  1176
# 2024-01-02  1189  1176
# 2024-01-03  1189  1176
# 2024-01-04  1189  1176
# 2024-01-05  1189  1176
# 2024-01-06  1189  1176
# 2024-01-07  1189  1176
# 2024-01-08  1189  1176
# 2024-01-09  1189  1176
# 2024-01-10  1189  1176
# 2024-01-11  1189  1176
# 2024-01-12  1189  1176
# 2024-01-13  1189  1176
# 2024-01-14  1189  1176
# 2024-01-15  1189  1176
# 2024-01-16  1189  1176
# 2024-01-17  1189  1176
# 2024-01-18  1189  1176
# 2024-01-19  1189  1176
# 2024-01-20  1189  1176
# 2024-01-21  1189  1176
# 2024-01-22  1189  1176
# 2024-01-23  1189  1176
# 2024-01-24  1189  1176
# 2024-01-25  1189  1176
# 2024-01-26  1189  1176
# 2024-01-27  1189  1176
# 2024-01-28  1189  1176
# 2024-01-29  1189  1176
# 2024-01-30  1189  1176
# 2024-01-31  1189  1176
# 2024-02-01  1189  1176
# 2024-02-02  1189  1176
# 2024-02-03  1189  1176
# 2024-02-04  1189  1176
# 2024-02-05  1189  1176
# 2024-02-06  1189  1176
# 2024-02-07  1189  1176
# 2024-02-08  1189  1176
# 2024-02-09  1189  1176
# 2024-02-10  1189  1176
# 2024-02-11  1189  1176
# 2024-02-12  1189  1176
# 2024-02-13  1189  1176
# 2024-02-14  1189  1176
# 2024-02-15  1189  1176
# 2024-02-16  1189  1176
# 2024-02-17  1189  1176
# 2024-02-18  1189  1176
# 2024-02-19  1189  1176
# 2024-02-20  1189  1176
# 2024-02-21  1189  1176
# 2024-02-22  1189  1176
# 2024-02-23  1189  1176
# 2024-02-24  1189  1176
# 2024-02-25  1189  1176
# 2024-02-26  1189  1176
# 2024-02-27  1189  1176
# 2024-02-28  1189  1176
# 2024-02-29  1189  1176
# 2024-03-01  1189  1176
# 2024-03-02  1189  1176
# 2024-03-03  1189  1176
# 2024-03-04  1189  1176
# 2024-03-05  1189  1176
# 2024-03-06  1189  1176
# 2024-03-07  1189  1176
# 2024-03-08  1189  1176
# 2024-03-09  1189  1176
# 2024-03-10  1189  1176
# 2024-03-11  1189  1176
# 2024-03-12  1189  1176
# 2024-03-13  1189  1176
# 2024-03-14  1189  1176
# 2024-03-15  1189  1176
# 2024-03-16  1189  1176
# 2024-03-17  1189  1176
# 2024-03-18  1189  1176
# 2024-03-19  1189  1176
# 2024-03-20  1189  1176
# 2024-03-21  1189  1176
# 2024-03-22  1189  1176
# 2024-03-23  1189  1176
# 2024-03-24  1189  1176
# 2024-03-25  1189  1176
# 2024-03-26  1189  1176
# 2024-03-27  1189  1176
# 2024-03-28  1189  1176
# 2024-03-29  1189  1176
# 2024-03-30  1189  1176
# 2024-03-31  1189  1176

# %%
# Out:
#     블록명   중량  표준공기          납기       사이즈  최대길이   면적     최소착수요구일  날짜순서  공기순서  \
# 1   S14   67     7  2023-11-09  (13, 13)    13  169  2023-11-02   1.5  18.0
# 6   S19   21    12  2023-11-15   (14, 7)    14   98  2023-11-03   4.0   2.5
# 0   S13  131     6  2023-11-08  (15, 14)    15  210  2023-11-02   1.5  20.5
# 2   S15  139    10  2023-11-13  (15, 14)    15  210  2023-11-03   4.0   8.5
# 3   S16   24    11  2023-11-14   (14, 5)    14   70  2023-11-03   4.0   5.5
# 4   S17   68     8  2023-11-14  (15, 13)    15  195  2023-11-06   6.5  14.5
# 5   S18   21     9  2023-11-15   (14, 7)    14   98  2023-11-06   6.5  11.0
# 11  S24   56    12  2023-11-21  (18, 14)    18  252  2023-11-09   9.5   2.5
# 7   S20   76     8  2023-11-15  (14, 13)    14  182  2023-11-07   8.0  14.5
# 8   S21   82     8  2023-11-17  (17, 15)    17  255  2023-11-09   9.5  14.5
# 12  S25   98    11  2023-11-21  (19, 13)    19  247  2023-11-10  12.0   5.5
# 20  S33   33    13  2023-11-27  (19, 15)    19  285  2023-11-14  14.5   1.0
# 9   S22   41    11  2023-11-21   (17, 5)    17   85  2023-11-10  12.0   5.5
# 10  S23   20    11  2023-11-21   (17, 5)    17   85  2023-11-10  12.0   5.5
# 13  S26   42     9  2023-11-23  (12, 11)    12  132  2023-11-14  14.5  11.0
# 19  S32   84    10  2023-11-27  (17, 15)    17  255  2023-11-17  17.0   8.5
# 14  S27  106     8  2023-11-23  (19, 13)    19  247  2023-11-15  16.0  14.5
# 21  S34   39     7  2023-11-27  (12, 11)    12  132  2023-11-20  18.0  18.0
# 23  S36   79     9  2023-12-01  (17, 15)    17  255  2023-11-22  21.5  11.0
# 22  S35   67     7  2023-11-29  (17, 15)    17  255  2023-11-22  21.5  18.0
# 15  S28   10     5  2023-11-27   (14, 4)    14   56  2023-11-22  21.5  23.5
# 16  S29    9     5  2023-11-27    (6, 4)     6   24  2023-11-22  21.5  23.5
# 17  S30   10     5  2023-11-27   (14, 4)    14   56  2023-11-22  21.5  23.5
# 18  S31    9     5  2023-11-27    (6, 4)     6   24  2023-11-22  21.5  23.5
# 24  S37   37     6  2023-12-04   (14, 9)    14  126  2023-11-28  25.0  20.5
#
#     크기순서  우선순위  배치결과        착수일자
# 1   13.0   2.1  정상배치  2023-10-26
# 6   17.5   2.1  정상배치  2023-10-27
# 0    9.5   2.2  정상배치  2023-10-26
# 2    9.5   2.2  정상배치  2023-11-01
# 3   21.0   2.4  정상배치  2023-10-27
# 4   11.0   3.5  정상배치  2023-11-01
# 5   17.5   3.5  정상배치  2023-11-02
# 11   6.0   3.5  정상배치  2023-11-03
# 7   12.0   4.0  정상배치  2023-11-02
# 8    3.5   4.2  정상배치  2023-11-07
# 12   7.5   4.6  정상배치  2023-11-09
# 20   1.0   4.9  정상배치  2023-11-15
# 9   19.5   5.0  정상배치  2023-11-03
# 10  19.5   5.0  정상배치  2023-11-03
# 13  14.5   6.0  정상배치  2023-11-14
# 19   3.5   6.4  정상배치  2023-11-20
# 14   7.5   6.6  정상배치  2023-11-11
# 21  14.5   7.7  정상배치  2023-11-13
# 23   3.5   8.0  정상배치  2023-11-15
# 22   3.5   8.5  정상배치  2023-11-20
# 15  22.5   9.5  정상배치  2023-11-15
# 16  24.5   9.5  정상배치  2023-11-15
# 17  22.5   9.5  정상배치  2023-11-15
# 18  24.5   9.5  정상배치  2023-11-15
# 24  16.0  10.2  정상배치  2023-11-21

# %% [markdown]
# # 레이아웃 조회

# %%
# 연속조회
idx, 조회일수 = 34, 50
정반 = "A"
for 조회날짜 in 면적달력.index.strftime('%Y-%m-%d')[idx:idx+조회일수]:
    print(조회날짜)
    정반배치레이아웃(정반, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)
# Out:
# 2023-11-04
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-05
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-06
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-07
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-08
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-09
# -----1차검토 부적합 - Block S25 of height 19 width 13 could not be placed.
# -----1차검토 부적합 - Block S23 of height 17 width 5 could not be placed.
# 2023-11-10
# 2023-11-11
# 2023-11-12
# 2023-11-13
# 2023-11-14
# 2023-11-15
# -----1차검토 부적합 - Block S28 of height 14 width 4 could not be placed.
# 2023-11-16
# -----1차검토 부적합 - Block S28 of height 14 width 4 could not be placed.
# 2023-11-17
# -----1차검토 부적합 - Block S28 of height 14 width 4 could not be placed.
# 2023-11-18
# 2023-11-19
# 2023-11-20
# 2023-11-21
# 2023-11-22
# -----1차검토 부적합 - Block S35 of height 17 width 15 could not be placed.
# -----2차검토 부적합 - Block S35 of height 15 width 17 could not be placed.
# 2023-11-23
# 2023-11-24
# 2023-11-25
# 2023-11-26
# 2023-11-27
# 2023-11-28
# 2023-11-29
# 2023-11-30
# 2023-12-01
# 2023-12-02
# 2023-12-03
# 2023-12-04
# 2023-12-05
# 2023-12-06
# 2023-12-07
# 2023-12-08
# 2023-12-09
# 2023-12-10
# 2023-12-11
# 2023-12-12
# 2023-12-13
# 2023-12-14
# 2023-12-15
# 2023-12-16
# 2023-12-17
# 2023-12-18
# 2023-12-19
# 2023-12-20
# 2023-12-21
# 2023-12-22
# 2023-12-23

# %%
# 개별조회
정반명 = "A"
조회날짜 =  "2023-11-14"
정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)

# %%
# 개별조회
정반명 = "B"
조회날짜 =  조회날짜
정반배치레이아웃(정반명, 정반데이터, 조회날짜, 블록명달력, 사이즈달력)
